# %%
import os, re, json
import numpy as np

# plotting styles
import matplotlib as mpl
from matplotlib import pyplot as plt

# %matplotlib inline

mpl.rcParams['figure.dpi'] = 150

# change to the root folder
base_dir = "/Users/jibanmac/Documents/GitHub/gpy_dla_detection/"
os.chdir(base_dir)

try:
    assert "null_gp.py" in os.listdir("gpy_dla_detection")
except Exception as e:
    print(e)
    print(
        "[Warning] Change the directory of base_dir to the path of your gpy_dla_detection repository."
    )

# %%
# The test selection file includes a list of 100 quasar spectra and their redshifts
from tests import test_selection

# The module to read spectrum, which also helps us to download the file (for SDSS DR12 spectrum)
from gpy_dla_detection.read_spec import read_spec, retrieve_raw_spec

# %%
# My current favourite style
import arviz as az

az.style.use("arviz-viridish")

# %%
with open(
    "data/dla_catalogs/dr12q_gp/predictions_multi_DLAs_lyseries_a03.json", "r"
) as f:
    dr12q_catalog = json.load(f)

# %%
def download_and_read(
    plate: int,
    mjd: int,
    fiber_id: int,
):
    filename = "spec-{:d}-{:d}-{:04d}.fits".format(plate, mjd, fiber_id)

    # If we haven't downloaded the file, this cell will help you download the file from SDSS database
    if not os.path.exists(filename):
        # This line gets the plate, mjd, and fiber_id from the given filename
        # Note: re is the regex.
        plate, mjd, fiber_id = re.findall(
            r"spec-([0-9]+)-([0-9]+)-([0-9]+).fits",
            filename,
        )[0]
        # Download the file using the given plate, mjd, and fiber_id
        retrieve_raw_spec(int(plate), int(mjd), int(fiber_id))

    # make sure the file exists
    assert os.path.exists(filename) == True

    # Read the raw spectrum: This line reads the spectrum file into four numpy arrays
    wavelengths, flux, noise_variance, pixel_mask = read_spec(filename)
    # simulated data
    # you have : wavelengths (velocities), flux
    # noise_variance : you need to inject your own noise
    # pixel_mask : you don't have. pixel_mask is the invalid pixel in spectrum
    return wavelengths, flux, noise_variance, pixel_mask

# %%
real_index = np.where(
    [
        (spec["p_dla"] > 0.9 and spec["snr"] > 8 and spec["z_qso"] > 3)
        for spec in dr12q_catalog
    ]
)[0]
real_index
# Out:
# array([    51,     76,    101, ..., 158780, 158811, 158824])

# %%
ith = 0

spec_dict = dr12q_catalog[real_index[ith]]

# extract info
plate = spec_dict["plate"]
mjd = spec_dict["mjd"]
fiber_id = spec_dict["fiber_id"]

z_qso = spec_dict["z_qso"]

# dla detection
dlas_dict = spec_dict["dlas"]
num_dlas = len(dlas_dict)
z_dlas = []
log_nhis = []
for j in range(num_dlas):
    z_dlas.append(dlas_dict[j]["z_dla"])
    log_nhis.append(dlas_dict[j]["log_nhi"])

spec_dict
# Out:
# {'p_dla': 0.9999999999999999,
#  'p_no_dla': 2.024344498834639e-32,
#  'max_model_posterior': 0.9988940794493255,
#  'num_dlas': 2,
#  'min_z_dla': 2.030863372651819,
#  'max_z_dla': 3.0179441471631363,
#  'snr': 26.150687052443182,
#  'ra': 0.06321446111104478,
#  'dec': 0.8092482880234474,
#  'plate': 4216,
#  'mjd': 55477,
#  'fiber_id': 718,
#  'thing_id': 113606237,
#  'z_qso': 3.027761220932007,
#  'dlas': [{'log_nhi': 20.755368819510455, 'z_dla': 2.1359937407867218},
#   {'log_nhi': 20.72436622286896, 'z_dla': 2.5236808003558338}]}

# %%
wavelengths, flux, noise_variance, pixel_mask = download_and_read(plate, mjd, fiber_id)

# %%
rest_wavelengths = wavelengths / (1 + z_qso)

plt.figure(figsize=(16, 5))
# I did a normalization in this step to make the plot esier to see
plt.plot(rest_wavelengths, flux / np.mean(flux))
plt.xlabel("Rest-frame Wavelengths [$\AA$]")
plt.ylabel("Normalized Flux")
plt.ylim(-1, 5)
# Out:
# (-1.0, 5.0)

# %% [markdown]
# ## Create the Bayesian model

# %%
from gpy_dla_detection.set_parameters import Parameters

# Note: these parameters are used during training. Change these parameters here won't change your
# trained GP model unless you re-train your GP model.
param = Parameters(
    loading_min_lambda=800,  # range of rest wavelengths to load  Å
    loading_max_lambda=1550,
    # normalization parameters
    normalization_min_lambda=1425,  # range of rest wavelengths to use   Å
    normalization_max_lambda=1475,  #   for flux normalization
    # null model parameters
    min_lambda=850.75,  # range of rest wavelengths to       Å
    max_lambda=1420.75,  #   model
    dlambda=0.25,  # separation of wavelength grid      Å
    k=20,  # rank of non-diagonal contribution
    max_noise_variance=3**2,  # maximum pixel noise allowed during model training
)

# BOSS DR12 effective optical depth
param.tau_0_mu = 0.00554  # meanflux suppression for τ₀
param.tau_0_sigma = 0.00064  # meanflux suppression for τ₀
param.beta_mu = 3.182  # meanflux suppression for β
param.beta_sigma = 0.074  # meanflux suppression for β

param
# Out:
# {'loading_min_lambda': 800, 'loading_max_lambda': 1550, 'z_qso_cut': 2.15, 'min_num_pixels': 200, 'normalization_min_lambda': 1425, 'normalization_max_lambda': 1475, 'min_lambda': 850.75, 'max_lambda': 1420.75, 'dlambda': 0.25, 'k': 20, 'max_noise_variance': 9, 'initial_c_0': 0.1, 'initial_tau_0': 0.0023, 'initial_beta': 3.65, 'minFunc_options': {'MaxIter': 2000, 'MaxFunEvals': 4000}, 'num_dla_samples': 10000, 'alpha': 0.97, 'uniform_min_log_nhi': 20.0, 'uniform_max_log_nhi': 23.0, 'fit_min_log_nhi': 20.0, 'fit_max_log_nhi': 22.0, 'prior_z_qso_increase': 0.10006922855944561, 'width': 3, 'pixel_spacing': 0.0001, 'num_lines': 3, 'max_z_cut': 0.010006922855944561, 'min_z_cut': 0.010006922855944561, 'num_forest_lines': 31, 'tau_0_mu': 0.00554, 'tau_0_sigma': 0.00064, 'beta_mu': 3.182, 'beta_sigma': 0.074}

# %%
from gpy_dla_detection.model_priors import PriorCatalog

# Note: you need to follow the README to download these files!
prior = PriorCatalog(
    param,
    "data/dr12q/processed/catalog.mat",
    "data/dla_catalogs/dr9q_concordance/processed/los_catalog",
    "data/dla_catalogs/dr9q_concordance/processed/dla_catalog",
)
prior

# %%
from gpy_dla_detection.null_gp import NullGP
from gpy_dla_detection.dla_gp import DLAGP

# Use h5py to read the learned GP model
import h5py


# Null model GP : a GP model without any DLA intervening.
# Note that it's model without DLAs, so the noise term might still include some
# LLS or subDLAs
class NullGPDR12(NullGP):
    """
    Load learned model from SDSS DR12 data without DLAs

    params: globla parameters used to train the model and some parameters define to priors of the model.
    prior: the prior catalog based on SDSS DR9 Lya catalog (We haven't switch to DR12 DLA catalog, we could
        use Ho-Bird-Garnett 2020 catalog). You can change the definition of self.log_prior
        to overwrite the prior from prior catalog.
    learned_file: the input .MAT file for the learned GP model.
    prev_tau_0: tau_0 to change the meanflux of the GP mean function. The effective meanflux model is
        tau = tau_0 * exp( -(1 + z)^beta ). Details see gpy_dla_detection/effective_optical_depth.py
    prev_beta: beta to change the meanflux of thte GP mean function.
    """

    def __init__(
        self,
        params: Parameters,
        prior: PriorCatalog,
        learned_file: str = "learned_qso_model_lyseries_variance_kim_dr9q_minus_concordance.mat",
        prev_tau_0: float = 0.0023,
        prev_beta: float = 3.65,
    ):
        with h5py.File(learned_file, "r") as learned:
            rest_wavelengths = learned["rest_wavelengths"][:, 0]
            mu = learned["mu"][:, 0]
            M = learned["M"][()].T
            log_omega = learned["log_omega"][:, 0]
            log_c_0 = learned["log_c_0"][0, 0]
            log_tau_0 = learned["log_tau_0"][0, 0]
            log_beta = learned["log_beta"][0, 0]

        super().__init__(
            params,
            prior,
            rest_wavelengths,
            mu,
            M,
            log_omega,
            log_c_0,
            log_tau_0,
            log_beta,
            prev_tau_0=prev_tau_0,
            prev_beta=prev_beta,
        )


# get the instance of GP null model
gp = NullGPDR12(
    params=param,
    prior=prior,
    # you should put your downloaded file in this directory
    learned_file="data/dr12q/processed/learned_qso_model_lyseries_variance_wmu_boss_dr16q_minus_dr12q_gp_851-1421.mat",
    # SDSS/BOSS DR12 meanflux effective optical depth for Lyman alpha forest
    prev_tau_0=0.00554,  # suppression: tau
    prev_beta=3.182,  # suppression: beta
)

# Make the GP model interpolated onto the observed quasar spectum
gp.set_data(rest_wavelengths, flux, noise_variance, pixel_mask, z_qso, build_model=True)

# %%
plt.figure(figsize=(16, 3))

# Mean function
plt.plot(
    gp.X,  # quasar spectrum's rest-frame wavelengths
    gp.Y,  # quasar spectrum's flux
    label="Data",
)
plt.fill_between(
    gp.X,
    gp.Y - 2 * np.sqrt(gp.v),
    gp.Y + 2 * np.sqrt(gp.v),
    label="SDSS Instrumental Uncertainty (95%)",
    color="C0",
    alpha=0.3,
)
plt.plot(
    gp.rest_wavelengths,
    gp.mu,
    label="GP null model (mu = continuum)",
    color="C3",
    ls="--",
)
plt.plot(
    gp.X, gp.this_mu, label="GP null model (mu = meanflux)"  # GP model's mean function
)
plt.xlabel("Rest-frame Wavelengths [$\AA$]")
plt.ylabel("Normalized Flux")
plt.legend(loc="upper right")
plt.ylim(-1, 5)
plt.tight_layout()
plt.savefig("poster-plot.png", format="png", dpi=300, transparent=True)

# %%
from gpy_dla_detection.dla_gp import DLAGP
from gpy_dla_detection.dla_samples import DLASamplesMAT


# Strong Lyman Alpha model GP : a GP model with at least one strong Lyman alpha absorption.
class LyaGPDR12(DLAGP):
    """
    Load learned model from SDSS DR12 data without DLAs, and parameterize the Voigt profile + include
    the parameter priors (NHI, zLya) for sampling the Voigt profile

    Parameters:
    ---
    lya_samples: the Monte Carlo samples of the prior (NHI, zLya) you will be using to search for the
        strong Lya absorbers.

    params: globla parameters used to train the model and some parameters define to priors of the model.
    prior: the prior catalog based on SDSS DR9 Lya catalog. You can change the definition of self.log_prior
        to overwrite the prior from prior catalog.
    learned_file: the input .MAT file for the learned GP model.
    prev_tau_0: tau_0 to change the meanflux of the GP mean function. The effective meanflux model is
        tau = tau_0 * exp( -(1 + z)^beta ). Details see gpy_dla_detection/effective_optical_depth.py
    prev_beta: beta to change the meanflux of thte GP mean function.
    """

    def __init__(
        self,
        params: Parameters,
        prior: PriorCatalog,
        lya_samples: DLASamplesMAT,
        learned_file: str = "learned_qso_model_lyseries_variance_kim_dr9q_minus_concordance.mat",
        prev_tau_0: float = 0.0023,
        prev_beta: float = 3.65,
        min_z_separation: float = 3000.0,  # km/s
        broadening: bool = True,
    ):
        with h5py.File(learned_file, "r") as learned:
            rest_wavelengths = learned["rest_wavelengths"][:, 0]
            mu = learned["mu"][:, 0]
            M = learned["M"][()].T
            log_omega = learned["log_omega"][:, 0]
            log_c_0 = learned["log_c_0"][0, 0]
            log_tau_0 = learned["log_tau_0"][0, 0]
            log_beta = learned["log_beta"][0, 0]

        super().__init__(
            params,
            prior,
            lya_samples,
            rest_wavelengths,
            mu,
            M,
            log_omega,
            log_c_0,
            log_tau_0,
            log_beta,
            prev_tau_0=prev_tau_0,
            prev_beta=prev_beta,
            min_z_separation=min_z_separation,
            broadening=broadening,
        )

# %%
from scipy.integrate import (
    quad,
)  # to get the normalization constant for the probability density function
from scipy.stats.qmc import Halton
from scipy.interpolate import interp1d

# %%
# directly use the fitted poly values in the Garnett (2017)
unnormalized_dla_pdf = lambda log_nhi: (
    np.exp(-1.2695 * log_nhi**2 + 50.863 * log_nhi - 509.33)
)
# add a flat prior at the low column density end
unnormalized_pdf = lambda log_nhi: (
    unnormalized_dla_pdf(log_nhi) * (log_nhi >= 20.03)
    + unnormalized_dla_pdf(20.03)
    * (
        log_nhi < 20.03
    )  # This part, you can get the prior from large simulations. But now is uniform
)

Z = quad(unnormalized_pdf, 17, 23.0)[0]

normalized_pdf = lambda log_nhi: unnormalized_pdf(log_nhi) / Z


log_nhis = np.linspace(17, 23, num=1000)

fig, ax = plt.subplots(1, 2, figsize=(12, 4))

ax[0].plot(log_nhis, normalized_pdf(log_nhis))
ax[0].set_xlabel("log NHI")
ax[0].set_ylabel("Probability density function")

# Make sure the probability density is summed to one
print("Sum of the PDF:")
np.sum(normalized_pdf(log_nhis) * (log_nhis[1] - log_nhis[0]))


# We want Monte Carlo samples - here to use Halton sequence to speed up the convergence
sampler = Halton(
    d=2,  # dimension of parameter space
    scramble=True,
)

num_samples = 50000
halton_sequence = sampler.random(num_samples)


# Inver transform sampling
# https://en.wikipedia.org/wiki/Inverse_transform_sampling
# code ref:
# https://gist.github.com/amarvutha/c2a3ea9d42d238551c694480019a6ce1
def sample(g, min_lognhi=17, max_lognhi=23):
    x = np.linspace(
        min_lognhi,
        max_lognhi,
        num=int(1e8),  # if you see interpolation error, increase this number
    )
    y = g(x)  # probability density function, pdf
    cdf_y = np.cumsum(y)  # cumulative distribution function, cdf
    cdf_y = cdf_y / cdf_y.max()  # takes care of normalizing cdf to 1.0
    inverse_cdf = interp1d(cdf_y, x)  # this is a function
    return inverse_cdf


def return_samples(halton_sequence: np.ndarray):
    required_samples = sample(normalized_pdf)(halton_sequence)
    return required_samples


samples_log_nhis = return_samples(
    halton_sequence[:, 0],
)

ax[1].plot(log_nhis, normalized_pdf(log_nhis), label="analytical PDF")
ax[1].set_xlabel("log NHI")
ax[1].set_ylabel("Probability density function")
ax[1].hist(
    samples_log_nhis, bins=100, density=True, alpha=0.5, label="Monte Carlo samples"
)

ax[1].legend()
# Out:
# Sum of the PDF:

# %%
from gpy_dla_detection.dla_samples import DLASamples


class LyaSamples(DLASamples):
    """
    Parameter prior (NHI, zLya) for strong Lya absorbers (logNHI = 17 - 23).

    This is a wrapper over the Monte Carlo samples already generated, so
    you should have already obtained the samples for the parameter prior
    somewhere else.

    We assume the same zLya prior as Garnett (2017):

        zLya ~ U(zmin, zmax)

        zmax = z_QSO - max_z_cut
        zmin = z_Ly∞ + min_z_cut
    """

    def __init__(
        self,
        params: Parameters,
        prior: PriorCatalog,
        offset_samples: np.ndarray,
        log_nhi_samples: np.ndarray,
        max_z_cut: float = 3000,  # km/s
        min_z_cut: float = 3000,  # km/s
    ):
        super().__init__(params, prior)

        self._offset_samples = offset_samples
        self._log_nhi_samples = log_nhi_samples
        self._nhi_samples = 10**log_nhi_samples

    @property
    def offset_samples(self) -> np.ndarray:
        return self._offset_samples

    @property
    def log_nhi_samples(self) -> np.ndarray:
        return self._log_nhi_samples

    @property
    def nhi_samples(self) -> np.ndarray:
        return self._nhi_samples

    def sample_z_dlas(self, wavelengths: np.ndarray, z_qso: float) -> np.ndarray:
        sample_z_dlas = (
            self.min_z_dla(wavelengths, z_qso)
            + (
                self.params.max_z_dla(wavelengths, z_qso)
                - self.min_z_dla(wavelengths, z_qso)
            )
            * self._offset_samples
        )

        return sample_z_dlas

    def min_z_dla(self, wavelengths: np.ndarray, z_qso: float) -> float:
        """
        determines minimum z_DLA to search

        We only consider z_dla within the modelling range.
        """
        rest_wavelengths = self.params.emitted_wavelengths(wavelengths, z_qso)
        ind = (rest_wavelengths >= self.params.min_lambda) & (
            rest_wavelengths <= self.params.max_lambda
        )
        # Here change to Lyb minimum
        return np.max(
            [
                np.min(wavelengths[ind]) / self.params.lya_wavelength - 1,
                self.params.observed_wavelengths(self.params.lyb_wavelength, z_qso)
                / self.params.lya_wavelength
                - 1
                + self.params.min_z_cut,
            ]
        )

    def _build_pdf(self):
        """
        Benchmark PDF we used in Garnett (2017), without mixing with a uniform prior
        """
        # directly use the fitted poly values in the Garnett (2017)
        unnormalized_dla_pdf = lambda log_nhi: (
            np.exp(-1.2695 * log_nhi**2 + 50.863 * log_nhi - 509.33)
        )
        # add a flat prior at the low column density end
        unnormalized_pdf = lambda log_nhi: (
            unnormalized_dla_pdf(log_nhi) * (log_nhi >= 20.03)
            + unnormalized_dla_pdf(20.03) * (log_nhi < 20.03)
        )

        Z = quad(unnormalized_pdf, 17, 23.0)[0]

        self.normalized_pdf = lambda log_nhi: unnormalized_pdf(log_nhi) / Z

    def pdf(self, log_nhi: float) -> float:
        """
        The logNHI pdf used in Garnett (2017) paper.
        """
        return self.normalized_pdf(log_nhi)

# %%
# samples for the Monte Carlo integration to get the likelihood of an absorber
# p( D | absorber model ) = \int p( D | z_abs, NHI, absorber model) p(z_abs) p(NHI) d z_abs d NHI

# p(z_abs) p(NHI)
lya_samples = LyaSamples(
    params=param,
    prior=prior,
    # offset samples
    offset_samples=halton_sequence[:, 1],
    log_nhi_samples=samples_log_nhis,
    max_z_cut=3000,
    min_z_cut=3000,
)

# %%
# Lya Model GP : this is null model GP + Voigt profile, which is parameterised with
# {(z_lya, logNHI)}_{i=1}^{k} parameters. k stands for maximum Lya absorpbers we want to search.
# we will compute log posteriors for DLA(1), ..., DLA(k) models.

# I want the Voigt profile to use Lya series lines up to 31
param.num_lines = 3
param.num_dla_samples = len(samples_log_nhis)

lya_gp = LyaGPDR12(
    params=param,
    prior=prior,
    lya_samples=lya_samples,  # 1. you input the NHI zabs samples to integrate
    min_z_separation=2000,  # 2. you have the minimum zabs separateion, in unit of km/s
    learned_file="data/dr12q/processed/learned_qso_model_lyseries_variance_wmu_boss_dr16q_minus_dr12q_gp_851-1421.mat",
    broadening=True,
    prev_tau_0=0.00554,  # suppression: tau
    prev_beta=3.182,  # suppression: beta
)
lya_gp.set_data(
    rest_wavelengths,
    flux,
    noise_variance,
    pixel_mask,
    z_qso,
    build_model=True,
)

# %% [markdown]
# ## An example plot

# %%
# snr > 30, quite good
# snr > 31, second one good
# sort based on zQSO
real_index = np.where(
    [
        (spec["p_dla"] > 0.99 and spec["snr"] > 35 and spec["z_qso"] < 5.8)
        for spec in dr12q_catalog
    ]
)[0]

real_index_zqso_sorted = np.argsort(
    [dr12q_catalog[index]["z_qso"] for index in real_index]
)
real_index_zqso_sorted[::-1]
# Out:
# array([314,  47, 345, 176, 281, 105, 220, 178, 292, 232, 356,  61, 290,
#        141,  78, 382, 177, 181, 172, 277, 146, 349, 224, 351,  54,  46,
#        331, 136, 298, 405, 346, 151, 358, 284, 375,  72, 342, 134,   3,
#         38, 161, 311, 184, 121, 164, 221, 336, 108, 383,  74, 275, 295,
#        241, 192, 319,  51, 293, 296, 287,  82,  80, 315, 193,  23, 173,
#        271, 215,  26, 322,  89, 240, 393, 106, 144, 254, 338,  52, 412,
#        196, 409, 302, 378, 258, 392, 245, 389, 355,  28, 119, 249, 120,
#        388, 175, 148,  55, 112,  63, 406, 207, 247,  70, 321, 265, 394,
#        244, 217, 114,  62,  48,  10,  25, 299, 261, 422,  19,  96, 191,
#        399, 219, 274, 182,  75,  29, 431, 130, 425, 323,  13, 212, 325,
#        103,  94, 131,  98, 429, 116,  27, 124,   5, 213, 329,  37, 210,
#        400, 318,  84, 343, 209, 149, 398,  99, 109, 133, 306, 186, 391,
#        262, 282, 427, 283,  40,  87, 152, 216, 379, 147, 267, 332, 253,
#        263, 309, 410, 140, 291, 237, 268, 279,  42, 354, 387, 344,  18,
#        372,  81,  67, 166, 227, 362, 156, 300,  45, 423, 194, 165, 158,
#        276,  32, 396, 414, 233, 352, 286, 280,   6, 330, 171,  59, 168,
#        390,  85, 259, 139, 266, 339, 395, 211,  44,  73, 364,  35, 204,
#        377, 246, 341, 154, 402,  22, 366,  31,  60, 167,  58, 238, 380,
#        203,  17, 185, 189, 416, 381, 160, 218, 236, 169, 285,  83, 190,
#        371,  93, 255, 122,   1, 419,  56, 264,  65, 368, 228,   2, 312,
#        272, 115, 301,  71, 337,   4, 313, 420, 360, 201, 289, 385, 123,
#         21, 413, 288, 101, 223, 353, 250, 421, 104, 386, 226, 317,  49,
#        418, 350,   8, 407, 374,  24,  16, 373, 157, 359,  92,  15,  97,
#        242,  39, 365, 234,  79, 183, 195,   0, 150, 137, 214,  95, 208,
#          9, 260, 426, 408, 251, 297, 202, 269, 403, 206, 370, 304,  50,
#         88, 239, 430, 113,  77, 428,  30, 401,  11, 397,  43, 188, 305,
#         36, 135, 348, 417, 162, 159, 415, 278, 110, 111, 132, 129, 257,
#        200, 369, 155, 326, 270,  34, 310, 347, 127, 102, 273,  86, 138,
#        307, 376, 153, 145,  91, 225, 327, 118, 384, 229, 361, 404, 294,
#        252, 334,  41, 230, 117, 308, 411,  14, 179, 335, 143, 142, 357,
#        163, 324, 197, 187, 320,   7,  33, 328, 180, 174, 128, 243, 100,
#         68, 170, 424, 248,  20,  12, 256,  69, 235,  66, 231,  57, 205,
#        363, 340, 199, 303, 367,  90, 126, 222, 125,  53, 333,  76, 316,
#         64, 198, 107])

# %%
# Now you can get the model with Lya absorbers
spacing = (real_index_zqso_sorted.shape[0]) // 12
ind = np.arange(0, real_index_zqso_sorted.shape[0], spacing)

ind = ind[5]

ith = real_index_zqso_sorted[ind]

spec_dict = dr12q_catalog[real_index[ith]]

# extract info
plate = spec_dict["plate"]
mjd = spec_dict["mjd"]
fiber_id = spec_dict["fiber_id"]

# read spec
wavelengths, flux, noise_variance, pixel_mask = download_and_read(plate, mjd, fiber_id)

z_qso = spec_dict["z_qso"]
rest_wavelengths = wavelengths / (1 + z_qso)

# dla detection
dlas_dict = spec_dict["dlas"]
num_dlas = len(dlas_dict)
z_dlas = []
log_nhis = []
for j in range(num_dlas):
    z_dlas.append(dlas_dict[j]["z_dla"])
    log_nhis.append(dlas_dict[j]["log_nhi"])

# Print out the basic info
print(spec_dict)

################### Plotting the model ###################
fig, ax = plt.subplots(1, 1, figsize=(16, 7))
# from blue to red
redshift_color = "C1"
model_color = "C0"

# plotting normalization
normalization = 0

# Make the GP model interpolated onto the observed quasar spectum
gp.set_data(rest_wavelengths, flux, noise_variance, pixel_mask, z_qso, build_model=True)
# p( D | z_abs =  z_lya, NHI = nhi, absorber model)
lya_gp.set_data(
    rest_wavelengths,
    flux,
    noise_variance,
    pixel_mask,
    z_qso,
    build_model=True,
)
lya_mu, lya_M, lya_omega2 = lya_gp.this_dla_gp(
    z_dlas, [10**log_nhi for log_nhi in log_nhis]
)

################# Whole spectrum without cropping ###############
# normalize spectrum
ind_norm = (
    (rest_wavelengths >= gp.params.normalization_min_lambda)
    & (rest_wavelengths <= gp.params.normalization_max_lambda)
    & (~pixel_mask)
)
this_median = np.nanmedian(flux[ind_norm])
flux = flux / this_median
# masking pixels
wavelengths = wavelengths[~pixel_mask]
rest_wavelengths = rest_wavelengths[~pixel_mask]
flux = flux[~pixel_mask]

# Mean function
ax.plot(
    wavelengths,  # quasar spectrum's rest-frame wavelengths
    flux + normalization,  # quasar spectrum's flux
    label="Data",
    color="black",
    lw=0.6,
    alpha=0.9,
)
ax.fill_between(
    wavelengths,
    -0.5,
    flux + normalization,
    label="SDSS Instrumental Uncertainty (95%)",
    color=redshift_color,
    # alpha=0.6,
)

ax.plot(
    gp.rest_wavelengths * (1 + z_qso),
    gp.mu + normalization,
    label="GP null model (mu = continuum)",
    color=model_color,
    # ls="--",
    linewidth=2.2,
    alpha=0.9,
)

# This line plots model
ax.plot(
    gp.X * (1 + z_qso),
    lya_mu + normalization,
    color=model_color,
    label="GP Lya model (mu = meanflux)",
)  # GP model's mean function
ax.fill_between(
    gp.X * (1 + z_qso),
    lya_mu + normalization,
    gp.mu_interpolator(gp.X),
    color=model_color,
    alpha=0.7,
    label="Absorption",
    ls="--",
)
# plt.text(gp.X[200] * (1 + z_qso), lya_mu[200] * normalization, "$z_{QSO} = $" + "{:.3g}".format(z_qso))

ax.set_xlabel("Observed-frame Wavelengths [$\AA$]", fontdict={"fontsize": 16})
# ax.set_ylabel("Normalized Flux")
ax.set_xlim(3600, 1215 * (1 + z_qso))
ax.set_ylim(-0.5, 5)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["left"].set_visible(False)

# ax.axis("off")
ax.set(yticklabels=[])
fig.tight_layout()

# fig.savefig(
#     "cover_photos/demo_spec_{}_snr_35.png".format(k), dpi=150, transparent=True
# )
# Out:
# {'p_dla': 1.0, 'p_no_dla': 6.730865785537661e-58, 'max_model_posterior': 0.9999999999839596, 'num_dlas': 1, 'min_z_dla': 1.9770418238541672, 'max_z_dla': 2.9462484982416073, 'snr': 38.84027572455391, 'ra': 1.6294523340514502, 'dec': 22.43629177837918, 'plate': 6879, 'mjd': 56539, 'fiber_id': 144, 'thing_id': 306658271, 'z_qso': 2.956, 'dlas': [{'log_nhi': 20.98739284253573, 'z_dla': 2.7356542745587893}]}

# %% [markdown]
# ## Make this a function

# %%
z_dlas, log_nhis
# Out:
# ([2.7356542745587893], [20.98739284253573])

# %%
def make_plot(z_dlas=[2.7356542745587893], log_nhis=[20.98739284253573]):
    # Now you can get the model with Lya absorbers
    spacing = (real_index_zqso_sorted.shape[0]) // 12
    ind = np.arange(0, real_index_zqso_sorted.shape[0], spacing)

    ind = ind[5]

    ith = real_index_zqso_sorted[ind]

    spec_dict = dr12q_catalog[real_index[ith]]

    # extract info
    plate = spec_dict["plate"]
    mjd = spec_dict["mjd"]
    fiber_id = spec_dict["fiber_id"]

    # read spec
    wavelengths, flux, noise_variance, pixel_mask = download_and_read(
        plate, mjd, fiber_id
    )

    z_qso = spec_dict["z_qso"]
    rest_wavelengths = wavelengths / (1 + z_qso)

    # # dla detection
    # dlas_dict = spec_dict["dlas"]
    # num_dlas = len(dlas_dict)
    # z_dlas = []
    # log_nhis = []
    # for j in range(num_dlas):
    #     z_dlas.append(dlas_dict[j]["z_dla"])
    #     log_nhis.append(dlas_dict[j]["log_nhi"])

    # Print out the basic info
    # print(spec_dict)

    ################### Plotting the model ###################
    fig, ax = plt.subplots(1, 1, figsize=(16, 7))
    # from blue to red
    redshift_color = "C1"
    model_color = "C0"

    # plotting normalization
    normalization = 0

    # Make the GP model interpolated onto the observed quasar spectum
    gp.set_data(
        rest_wavelengths, flux, noise_variance, pixel_mask, z_qso, build_model=True
    )
    # p( D | z_abs =  z_lya, NHI = nhi, absorber model)
    lya_gp.set_data(
        rest_wavelengths,
        flux,
        noise_variance,
        pixel_mask,
        z_qso,
        build_model=True,
    )
    lya_mu, lya_M, lya_omega2 = lya_gp.this_dla_gp(
        z_dlas, [10**log_nhi for log_nhi in log_nhis]
    )

    ################# Whole spectrum without cropping ###############
    # normalize spectrum
    ind_norm = (
        (rest_wavelengths >= gp.params.normalization_min_lambda)
        & (rest_wavelengths <= gp.params.normalization_max_lambda)
        & (~pixel_mask)
    )
    this_median = np.nanmedian(flux[ind_norm])
    flux = flux / this_median
    # masking pixels
    wavelengths = wavelengths[~pixel_mask]
    rest_wavelengths = rest_wavelengths[~pixel_mask]
    flux = flux[~pixel_mask]

    # Mean function
    ax.plot(
        wavelengths,  # quasar spectrum's rest-frame wavelengths
        flux + normalization,  # quasar spectrum's flux
        label="Data",
        color="black",
        lw=0.6,
        alpha=0.9,
    )
    ax.fill_between(
        wavelengths,
        -0.5,
        flux + normalization,
        label="SDSS Instrumental Uncertainty (95%)",
        color=redshift_color,
        # alpha=0.6,
    )

    ax.plot(
        gp.rest_wavelengths * (1 + z_qso),
        gp.mu + normalization,
        label="GP null model (mu = continuum)",
        color=model_color,
        # ls="--",
        linewidth=2.2,
        alpha=0.9,
    )

    # This line plots model
    ax.plot(
        gp.X * (1 + z_qso),
        lya_mu + normalization,
        color=model_color,
        label="GP Lya model (mu = meanflux)",
    )  # GP model's mean function
    ax.fill_between(
        gp.X * (1 + z_qso),
        lya_mu + normalization,
        gp.mu_interpolator(gp.X),
        color=model_color,
        alpha=0.7,
        label="Absorption",
        ls="--",
    )
    # plt.text(gp.X[200] * (1 + z_qso), lya_mu[200] * normalization, "$z_{QSO} = $" + "{:.3g}".format(z_qso))

    ax.set_xlabel("Observed-frame Wavelengths [$\AA$]", fontdict={"fontsize": 16})
    # ax.set_ylabel("Normalized Flux")
    ax.set_xlim(3600, 1215 * (1 + z_qso))
    ax.set_ylim(-0.5, 5)

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)

    ax.text(
        4600,
        4,
        "$z_{DLA}$ = "
        + "{:.4g};\n".format(z_dlas[0])
        + "$\log N_\mathrm{HI}$ = "
        + "{:.4g}".format(log_nhis[0]),
        fontdict={"fontsize": 20},
    )

    # ax.axis("off")
    ax.set(yticklabels=[])
    fig.tight_layout()

    # fig.savefig(
    #     "cover_photos/demo_spec_{}_snr_35.png".format(k), dpi=150, transparent=True
    # )
    return fig

# %%
num_bins = 1000
freq = 10

plot_log_nhis = np.sin(np.linspace(-3 * freq * np.pi, 3 * freq * np.pi, num_bins)) + 21
plot_z_dlas = (
    np.sin(np.linspace(-freq * np.pi, freq * np.pi, num_bins))
    * np.exp(np.linspace(-1, -4.5, num_bins))
    + 2.7356542745587893
)

# %%
plt.plot(plot_z_dlas)

# %%
for k, (z_dla, log_nhi) in enumerate(zip(plot_z_dlas, plot_log_nhis)):
    print("[Processing] ith = ", k)
    fig = make_plot(z_dlas=[z_dla], log_nhis=[log_nhi])
    fig.savefig(
        "animation/demo_spec_{}_snr_35.png".format(str(k).zfill(4)),
        dpi=100,
        # transparent=True,
    )
    plt.close()
    plt.clf()
# Out:
# [Processing] ith =  0
# [Processing] ith =  1
# [Processing] ith =  2
# [Processing] ith =  3
# [Processing] ith =  4
# [Processing] ith =  5
# [Processing] ith =  6
# [Processing] ith =  7
# [Processing] ith =  8
# [Processing] ith =  9
# [Processing] ith =  10
# [Processing] ith =  11
# [Processing] ith =  12
# [Processing] ith =  13
# [Processing] ith =  14
# [Processing] ith =  15
# [Processing] ith =  16
# [Processing] ith =  17
# [Processing] ith =  18
# [Processing] ith =  19
# [Processing] ith =  20
# [Processing] ith =  21
# [Processing] ith =  22
# [Processing] ith =  23
# [Processing] ith =  24
# [Processing] ith =  25
# [Processing] ith =  26
# [Processing] ith =  27
# [Processing] ith =  28
# [Processing] ith =  29
# [Processing] ith =  30
# [Processing] ith =  31
# [Processing] ith =  32
# [Processing] ith =  33
# [Processing] ith =  34
# [Processing] ith =  35
# [Processing] ith =  36
# [Processing] ith =  37
# [Processing] ith =  38
# [Processing] ith =  39
# [Processing] ith =  40
# [Processing] ith =  41
# [Processing] ith =  42
# [Processing] ith =  43
# [Processing] ith =  44
# [Processing] ith =  45
# [Processing] ith =  46
# [Processing] ith =  47
# [Processing] ith =  48
# [Processing] ith =  49
# [Processing] ith =  50
# [Processing] ith =  51
# [Processing] ith =  52
# [Processing] ith =  53
# [Processing] ith =  54
# [Processing] ith =  55
# [Processing] ith =  56
# [Processing] ith =  57
# [Processing] ith =  58
# [Processing] ith =  59
# [Processing] ith =  60
# [Processing] ith =  61
# [Processing] ith =  62
# [Processing] ith =  63
# [Processing] ith =  64
# [Processing] ith =  65
# [Processing] ith =  66
# [Processing] ith =  67
# [Processing] ith =  68
# [Processing] ith =  69
# [Processing] ith =  70
# [Processing] ith =  71
# [Processing] ith =  72
# [Processing] ith =  73
# [Processing] ith =  74
# [Processing] ith =  75
# [Processing] ith =  76
# [Processing] ith =  77
# [Processing] ith =  78
# [Processing] ith =  79
# [Processing] ith =  80
# [Processing] ith =  81
# [Processing] ith =  82
# [Processing] ith =  83
# [Processing] ith =  84
# [Processing] ith =  85
# [Processing] ith =  86
# [Processing] ith =  87
# [Processing] ith =  88
# [Processing] ith =  89
# [Processing] ith =  90
# [Processing] ith =  91
# [Processing] ith =  92
# [Processing] ith =  93
# [Processing] ith =  94
# [Processing] ith =  95
# [Processing] ith =  96
# [Processing] ith =  97
# [Processing] ith =  98
# [Processing] ith =  99
# [Processing] ith =  100
# [Processing] ith =  101
# [Processing] ith =  102
# [Processing] ith =  103
# [Processing] ith =  104
# [Processing] ith =  105
# [Processing] ith =  106
# [Processing] ith =  107
# [Processing] ith =  108
# [Processing] ith =  109
# [Processing] ith =  110
# [Processing] ith =  111
# [Processing] ith =  112
# [Processing] ith =  113
# [Processing] ith =  114
# [Processing] ith =  115
# [Processing] ith =  116
# [Processing] ith =  117
# [Processing] ith =  118
# [Processing] ith =  119
# [Processing] ith =  120
# [Processing] ith =  121
# [Processing] ith =  122
# [Processing] ith =  123
# [Processing] ith =  124
# [Processing] ith =  125
# [Processing] ith =  126
# [Processing] ith =  127
# [Processing] ith =  128
# [Processing] ith =  129
# [Processing] ith =  130
# [Processing] ith =  131
# [Processing] ith =  132
# [Processing] ith =  133
# [Processing] ith =  134
# [Processing] ith =  135
# [Processing] ith =  136
# [Processing] ith =  137
# [Processing] ith =  138
# [Processing] ith =  139
# [Processing] ith =  140
# [Processing] ith =  141
# [Processing] ith =  142
# [Processing] ith =  143
# [Processing] ith =  144
# [Processing] ith =  145
# [Processing] ith =  146
# [Processing] ith =  147
# [Processing] ith =  148
# [Processing] ith =  149
# [Processing] ith =  150
# [Processing] ith =  151
# [Processing] ith =  152
# [Processing] ith =  153
# [Processing] ith =  154
# [Processing] ith =  155
# [Processing] ith =  156
# [Processing] ith =  157
# [Processing] ith =  158
# [Processing] ith =  159
# [Processing] ith =  160
# [Processing] ith =  161
# [Processing] ith =  162
# [Processing] ith =  163
# [Processing] ith =  164
# [Processing] ith =  165
# [Processing] ith =  166
# [Processing] ith =  167
# [Processing] ith =  168
# [Processing] ith =  169
# [Processing] ith =  170
# [Processing] ith =  171
# [Processing] ith =  172
# [Processing] ith =  173
# [Processing] ith =  174
# [Processing] ith =  175
# [Processing] ith =  176
# [Processing] ith =  177
# [Processing] ith =  178
# [Processing] ith =  179
# [Processing] ith =  180
# [Processing] ith =  181
# [Processing] ith =  182
# [Processing] ith =  183
# [Processing] ith =  184
# [Processing] ith =  185
# [Processing] ith =  186
# [Processing] ith =  187
# [Processing] ith =  188
# [Processing] ith =  189
# [Processing] ith =  190
# [Processing] ith =  191
# [Processing] ith =  192
# [Processing] ith =  193
# [Processing] ith =  194
# [Processing] ith =  195
# [Processing] ith =  196
# [Processing] ith =  197
# [Processing] ith =  198
# [Processing] ith =  199
# [Processing] ith =  200
# [Processing] ith =  201
# [Processing] ith =  202
# [Processing] ith =  203
# [Processing] ith =  204
# [Processing] ith =  205
# [Processing] ith =  206
# [Processing] ith =  207
# [Processing] ith =  208
# [Processing] ith =  209
# [Processing] ith =  210
# [Processing] ith =  211
# [Processing] ith =  212
# [Processing] ith =  213
# [Processing] ith =  214
# [Processing] ith =  215
# [Processing] ith =  216
# [Processing] ith =  217
# [Processing] ith =  218
# [Processing] ith =  219
# [Processing] ith =  220
# [Processing] ith =  221
# [Processing] ith =  222
# [Processing] ith =  223
# [Processing] ith =  224
# [Processing] ith =  225
# [Processing] ith =  226
# [Processing] ith =  227
# [Processing] ith =  228
# [Processing] ith =  229
# [Processing] ith =  230
# [Processing] ith =  231
# [Processing] ith =  232
# [Processing] ith =  233
# [Processing] ith =  234
# [Processing] ith =  235
# [Processing] ith =  236
# [Processing] ith =  237
# [Processing] ith =  238
# [Processing] ith =  239
# [Processing] ith =  240
# [Processing] ith =  241
# [Processing] ith =  242
# [Processing] ith =  243
# [Processing] ith =  244
# [Processing] ith =  245
# [Processing] ith =  246
# [Processing] ith =  247
# [Processing] ith =  248
# [Processing] ith =  249
# [Processing] ith =  250
# [Processing] ith =  251
# [Processing] ith =  252
# [Processing] ith =  253
# [Processing] ith =  254
# [Processing] ith =  255
# [Processing] ith =  256
# [Processing] ith =  257
# [Processing] ith =  258
# [Processing] ith =  259
# [Processing] ith =  260
# [Processing] ith =  261
# [Processing] ith =  262
# [Processing] ith =  263
# [Processing] ith =  264
# [Processing] ith =  265
# [Processing] ith =  266
# [Processing] ith =  267
# [Processing] ith =  268
# [Processing] ith =  269
# [Processing] ith =  270
# [Processing] ith =  271
# [Processing] ith =  272
# [Processing] ith =  273
# [Processing] ith =  274
# [Processing] ith =  275
# [Processing] ith =  276
# [Processing] ith =  277
# [Processing] ith =  278
# [Processing] ith =  279
# [Processing] ith =  280
# [Processing] ith =  281
# [Processing] ith =  282
# [Processing] ith =  283
# [Processing] ith =  284
# [Processing] ith =  285
# [Processing] ith =  286
# [Processing] ith =  287
# [Processing] ith =  288
# [Processing] ith =  289
# [Processing] ith =  290
# [Processing] ith =  291
# [Processing] ith =  292
# [Processing] ith =  293
# [Processing] ith =  294
# [Processing] ith =  295
# [Processing] ith =  296
# [Processing] ith =  297
# [Processing] ith =  298
# [Processing] ith =  299
# [Processing] ith =  300
# [Processing] ith =  301
# [Processing] ith =  302
# [Processing] ith =  303
# [Processing] ith =  304
# [Processing] ith =  305
# [Processing] ith =  306
# [Processing] ith =  307
# [Processing] ith =  308
# [Processing] ith =  309
# [Processing] ith =  310
# [Processing] ith =  311
# [Processing] ith =  312
# [Processing] ith =  313
# [Processing] ith =  314
# [Processing] ith =  315
# [Processing] ith =  316
# [Processing] ith =  317
# [Processing] ith =  318
# [Processing] ith =  319
# [Processing] ith =  320
# [Processing] ith =  321
# [Processing] ith =  322
# [Processing] ith =  323
# [Processing] ith =  324
# [Processing] ith =  325
# [Processing] ith =  326
# [Processing] ith =  327
# [Processing] ith =  328
# [Processing] ith =  329
# [Processing] ith =  330
# [Processing] ith =  331
# [Processing] ith =  332
# [Processing] ith =  333
# [Processing] ith =  334
# [Processing] ith =  335
# [Processing] ith =  336
# [Processing] ith =  337
# [Processing] ith =  338
# [Processing] ith =  339
# [Processing] ith =  340
# [Processing] ith =  341
# [Processing] ith =  342
# [Processing] ith =  343
# [Processing] ith =  344
# [Processing] ith =  345
# [Processing] ith =  346
# [Processing] ith =  347
# [Processing] ith =  348
# [Processing] ith =  349
# [Processing] ith =  350
# [Processing] ith =  351
# [Processing] ith =  352
# [Processing] ith =  353
# [Processing] ith =  354
# [Processing] ith =  355
# [Processing] ith =  356
# [Processing] ith =  357
# [Processing] ith =  358
# [Processing] ith =  359
# [Processing] ith =  360
# [Processing] ith =  361
# [Processing] ith =  362
# [Processing] ith =  363
# [Processing] ith =  364
# [Processing] ith =  365
# [Processing] ith =  366
# [Processing] ith =  367
# [Processing] ith =  368
# [Processing] ith =  369
# [Processing] ith =  370
# [Processing] ith =  371
# [Processing] ith =  372
# [Processing] ith =  373
# [Processing] ith =  374
# [Processing] ith =  375
# [Processing] ith =  376
# [Processing] ith =  377
# [Processing] ith =  378
# [Processing] ith =  379
# [Processing] ith =  380
# [Processing] ith =  381
# [Processing] ith =  382
# [Processing] ith =  383
# [Processing] ith =  384
# [Processing] ith =  385
# [Processing] ith =  386
# [Processing] ith =  387
# [Processing] ith =  388
# [Processing] ith =  389
# [Processing] ith =  390
# [Processing] ith =  391
# [Processing] ith =  392
# [Processing] ith =  393
# [Processing] ith =  394
# [Processing] ith =  395
# [Processing] ith =  396
# [Processing] ith =  397
# [Processing] ith =  398
# [Processing] ith =  399
# [Processing] ith =  400
# [Processing] ith =  401
# [Processing] ith =  402
# [Processing] ith =  403
# [Processing] ith =  404
# [Processing] ith =  405
# [Processing] ith =  406
# [Processing] ith =  407
# [Processing] ith =  408
# [Processing] ith =  409
# [Processing] ith =  410
# [Processing] ith =  411
# [Processing] ith =  412
# [Processing] ith =  413
# [Processing] ith =  414
# [Processing] ith =  415
# [Processing] ith =  416
# [Processing] ith =  417
# [Processing] ith =  418
# [Processing] ith =  419
# [Processing] ith =  420
# [Processing] ith =  421
# [Processing] ith =  422
# [Processing] ith =  423
# [Processing] ith =  424
# [Processing] ith =  425
# [Processing] ith =  426
# [Processing] ith =  427
# [Processing] ith =  428
# [Processing] ith =  429
# [Processing] ith =  430
# [Processing] ith =  431
# [Processing] ith =  432
# [Processing] ith =  433
# [Processing] ith =  434
# [Processing] ith =  435
# [Processing] ith =  436
# [Processing] ith =  437
# [Processing] ith =  438
# [Processing] ith =  439
# [Processing] ith =  440
# [Processing] ith =  441
# [Processing] ith =  442
# [Processing] ith =  443
# [Processing] ith =  444
# [Processing] ith =  445
# [Processing] ith =  446
# [Processing] ith =  447
# [Processing] ith =  448
# [Processing] ith =  449
# [Processing] ith =  450
# [Processing] ith =  451
# [Processing] ith =  452
# [Processing] ith =  453
# [Processing] ith =  454
# [Processing] ith =  455
# [Processing] ith =  456
# [Processing] ith =  457
# [Processing] ith =  458
# [Processing] ith =  459
# [Processing] ith =  460
# [Processing] ith =  461
# [Processing] ith =  462
# [Processing] ith =  463
# [Processing] ith =  464
# [Processing] ith =  465
# [Processing] ith =  466
# [Processing] ith =  467
# [Processing] ith =  468
# [Processing] ith =  469
# [Processing] ith =  470
# [Processing] ith =  471
# [Processing] ith =  472
# [Processing] ith =  473
# [Processing] ith =  474
# [Processing] ith =  475
# [Processing] ith =  476
# [Processing] ith =  477
# [Processing] ith =  478
# [Processing] ith =  479
# [Processing] ith =  480
# [Processing] ith =  481
# [Processing] ith =  482
# [Processing] ith =  483
# [Processing] ith =  484
# [Processing] ith =  485
# [Processing] ith =  486
# [Processing] ith =  487
# [Processing] ith =  488
# [Processing] ith =  489
# [Processing] ith =  490
# [Processing] ith =  491
# [Processing] ith =  492
# [Processing] ith =  493
# [Processing] ith =  494
# [Processing] ith =  495
# [Processing] ith =  496
# [Processing] ith =  497
# [Processing] ith =  498
# [Processing] ith =  499
# [Processing] ith =  500
# [Processing] ith =  501
# [Processing] ith =  502
# [Processing] ith =  503
# [Processing] ith =  504
# [Processing] ith =  505
# [Processing] ith =  506
# [Processing] ith =  507
# [Processing] ith =  508
# [Processing] ith =  509
# [Processing] ith =  510
# [Processing] ith =  511
# [Processing] ith =  512
# [Processing] ith =  513
# [Processing] ith =  514
# [Processing] ith =  515
# [Processing] ith =  516
# [Processing] ith =  517
# [Processing] ith =  518
# [Processing] ith =  519
# [Processing] ith =  520
# [Processing] ith =  521
# [Processing] ith =  522
# [Processing] ith =  523
# [Processing] ith =  524
# [Processing] ith =  525
# [Processing] ith =  526
# [Processing] ith =  527
# [Processing] ith =  528
# [Processing] ith =  529
# [Processing] ith =  530
# [Processing] ith =  531
# [Processing] ith =  532
# [Processing] ith =  533
# [Processing] ith =  534
# [Processing] ith =  535
# [Processing] ith =  536
# [Processing] ith =  537
# [Processing] ith =  538
# [Processing] ith =  539
# [Processing] ith =  540
# [Processing] ith =  541
# [Processing] ith =  542
# [Processing] ith =  543
# [Processing] ith =  544
# [Processing] ith =  545
# [Processing] ith =  546
# [Processing] ith =  547
# [Processing] ith =  548
# [Processing] ith =  549
# [Processing] ith =  550
# [Processing] ith =  551
# [Processing] ith =  552
# [Processing] ith =  553
# [Processing] ith =  554
# [Processing] ith =  555
# [Processing] ith =  556
# [Processing] ith =  557
# [Processing] ith =  558
# [Processing] ith =  559
# [Processing] ith =  560
# [Processing] ith =  561
# [Processing] ith =  562
# [Processing] ith =  563
# [Processing] ith =  564
# [Processing] ith =  565
# [Processing] ith =  566
# [Processing] ith =  567
# [Processing] ith =  568
# [Processing] ith =  569
# [Processing] ith =  570
# [Processing] ith =  571
# [Processing] ith =  572
# [Processing] ith =  573
# [Processing] ith =  574
# [Processing] ith =  575
# [Processing] ith =  576
# [Processing] ith =  577
# [Processing] ith =  578
# [Processing] ith =  579
# [Processing] ith =  580
# [Processing] ith =  581
# [Processing] ith =  582
# [Processing] ith =  583
# [Processing] ith =  584
# [Processing] ith =  585
# [Processing] ith =  586
# [Processing] ith =  587
# [Processing] ith =  588
# [Processing] ith =  589
# [Processing] ith =  590
# [Processing] ith =  591
# [Processing] ith =  592
# [Processing] ith =  593
# [Processing] ith =  594
# [Processing] ith =  595
# [Processing] ith =  596
# [Processing] ith =  597
# [Processing] ith =  598
# [Processing] ith =  599
# [Processing] ith =  600
# [Processing] ith =  601
# [Processing] ith =  602
# [Processing] ith =  603
# [Processing] ith =  604
# [Processing] ith =  605
# [Processing] ith =  606
# [Processing] ith =  607
# [Processing] ith =  608
# [Processing] ith =  609
# [Processing] ith =  610
# [Processing] ith =  611
# [Processing] ith =  612
# [Processing] ith =  613
# [Processing] ith =  614
# [Processing] ith =  615
# [Processing] ith =  616
# [Processing] ith =  617
# [Processing] ith =  618
# [Processing] ith =  619
# [Processing] ith =  620
# [Processing] ith =  621
# [Processing] ith =  622
# [Processing] ith =  623
# [Processing] ith =  624
# [Processing] ith =  625
# [Processing] ith =  626
# [Processing] ith =  627
# [Processing] ith =  628
# [Processing] ith =  629
# [Processing] ith =  630
# [Processing] ith =  631
# [Processing] ith =  632
# [Processing] ith =  633
# [Processing] ith =  634
# [Processing] ith =  635
# [Processing] ith =  636
# [Processing] ith =  637
# [Processing] ith =  638
# [Processing] ith =  639
# [Processing] ith =  640
# [Processing] ith =  641
# [Processing] ith =  642
# [Processing] ith =  643
# [Processing] ith =  644
# [Processing] ith =  645
# [Processing] ith =  646
# [Processing] ith =  647
# [Processing] ith =  648
# [Processing] ith =  649
# [Processing] ith =  650
# [Processing] ith =  651
# [Processing] ith =  652
# [Processing] ith =  653
# [Processing] ith =  654
# [Processing] ith =  655
# [Processing] ith =  656
# [Processing] ith =  657
# [Processing] ith =  658
# [Processing] ith =  659
# [Processing] ith =  660
# [Processing] ith =  661
# [Processing] ith =  662
# [Processing] ith =  663
# [Processing] ith =  664
# [Processing] ith =  665
# [Processing] ith =  666
# [Processing] ith =  667
# [Processing] ith =  668
# [Processing] ith =  669
# [Processing] ith =  670
# [Processing] ith =  671
# [Processing] ith =  672
# [Processing] ith =  673
# [Processing] ith =  674
# [Processing] ith =  675
# [Processing] ith =  676
# [Processing] ith =  677
# [Processing] ith =  678
# [Processing] ith =  679
# [Processing] ith =  680
# [Processing] ith =  681
# [Processing] ith =  682
# [Processing] ith =  683
# [Processing] ith =  684
# [Processing] ith =  685
# [Processing] ith =  686
# [Processing] ith =  687
# [Processing] ith =  688
# [Processing] ith =  689
# [Processing] ith =  690
# [Processing] ith =  691
# [Processing] ith =  692
# [Processing] ith =  693
# [Processing] ith =  694
# [Processing] ith =  695
# [Processing] ith =  696
# [Processing] ith =  697
# [Processing] ith =  698
# [Processing] ith =  699
# [Processing] ith =  700
# [Processing] ith =  701
# [Processing] ith =  702
# [Processing] ith =  703
# [Processing] ith =  704
# [Processing] ith =  705
# [Processing] ith =  706
# [Processing] ith =  707
# [Processing] ith =  708
# [Processing] ith =  709
# [Processing] ith =  710
# [Processing] ith =  711
# [Processing] ith =  712
# [Processing] ith =  713
# [Processing] ith =  714
# [Processing] ith =  715
# [Processing] ith =  716
# [Processing] ith =  717
# [Processing] ith =  718
# [Processing] ith =  719
# [Processing] ith =  720
# [Processing] ith =  721
# [Processing] ith =  722
# [Processing] ith =  723
# [Processing] ith =  724
# [Processing] ith =  725
# [Processing] ith =  726
# [Processing] ith =  727
# [Processing] ith =  728
# [Processing] ith =  729
# [Processing] ith =  730
# [Processing] ith =  731
# [Processing] ith =  732
# [Processing] ith =  733
# [Processing] ith =  734
# [Processing] ith =  735
# [Processing] ith =  736
# [Processing] ith =  737
# [Processing] ith =  738
# [Processing] ith =  739
# [Processing] ith =  740
# [Processing] ith =  741
# [Processing] ith =  742
# [Processing] ith =  743
# [Processing] ith =  744
# [Processing] ith =  745
# [Processing] ith =  746
# [Processing] ith =  747
# [Processing] ith =  748
# [Processing] ith =  749
# [Processing] ith =  750
# [Processing] ith =  751
# [Processing] ith =  752
# [Processing] ith =  753
# [Processing] ith =  754
# [Processing] ith =  755
# [Processing] ith =  756
# [Processing] ith =  757
# [Processing] ith =  758
# [Processing] ith =  759
# [Processing] ith =  760
# [Processing] ith =  761
# [Processing] ith =  762
# [Processing] ith =  763
# [Processing] ith =  764
# [Processing] ith =  765
# [Processing] ith =  766
# [Processing] ith =  767
# [Processing] ith =  768
# [Processing] ith =  769
# [Processing] ith =  770
# [Processing] ith =  771
# [Processing] ith =  772
# [Processing] ith =  773
# [Processing] ith =  774
# [Processing] ith =  775
# [Processing] ith =  776
# [Processing] ith =  777
# [Processing] ith =  778
# [Processing] ith =  779
# [Processing] ith =  780
# [Processing] ith =  781
# [Processing] ith =  782
# [Processing] ith =  783
# [Processing] ith =  784
# [Processing] ith =  785
# [Processing] ith =  786
# [Processing] ith =  787
# [Processing] ith =  788
# [Processing] ith =  789
# [Processing] ith =  790
# [Processing] ith =  791
# [Processing] ith =  792
# [Processing] ith =  793
# [Processing] ith =  794
# [Processing] ith =  795
# [Processing] ith =  796
# [Processing] ith =  797
# [Processing] ith =  798
# [Processing] ith =  799
# [Processing] ith =  800
# [Processing] ith =  801
# [Processing] ith =  802
# [Processing] ith =  803
# [Processing] ith =  804
# [Processing] ith =  805
# [Processing] ith =  806
# [Processing] ith =  807
# [Processing] ith =  808
# [Processing] ith =  809
# [Processing] ith =  810
# [Processing] ith =  811
# [Processing] ith =  812
# [Processing] ith =  813
# [Processing] ith =  814
# [Processing] ith =  815
# [Processing] ith =  816
# [Processing] ith =  817
# [Processing] ith =  818
# [Processing] ith =  819
# [Processing] ith =  820
# [Processing] ith =  821
# [Processing] ith =  822
# [Processing] ith =  823
# [Processing] ith =  824
# [Processing] ith =  825
# [Processing] ith =  826
# [Processing] ith =  827
# [Processing] ith =  828
# [Processing] ith =  829
# [Processing] ith =  830
# [Processing] ith =  831
# [Processing] ith =  832
# [Processing] ith =  833
# [Processing] ith =  834
# [Processing] ith =  835
# [Processing] ith =  836
# [Processing] ith =  837
# [Processing] ith =  838
# [Processing] ith =  839
# [Processing] ith =  840
# [Processing] ith =  841
# [Processing] ith =  842
# [Processing] ith =  843
# [Processing] ith =  844
# [Processing] ith =  845
# [Processing] ith =  846
# [Processing] ith =  847
# [Processing] ith =  848
# [Processing] ith =  849
# [Processing] ith =  850
# [Processing] ith =  851
# [Processing] ith =  852
# [Processing] ith =  853
# [Processing] ith =  854
# [Processing] ith =  855
# [Processing] ith =  856
# [Processing] ith =  857
# [Processing] ith =  858
# [Processing] ith =  859
# [Processing] ith =  860
# [Processing] ith =  861
# [Processing] ith =  862
# [Processing] ith =  863
# [Processing] ith =  864
# [Processing] ith =  865
# [Processing] ith =  866
# [Processing] ith =  867
# [Processing] ith =  868
# [Processing] ith =  869
# [Processing] ith =  870
# [Processing] ith =  871
# [Processing] ith =  872
# [Processing] ith =  873
# [Processing] ith =  874
# [Processing] ith =  875
# [Processing] ith =  876
# [Processing] ith =  877
# [Processing] ith =  878
# [Processing] ith =  879
# [Processing] ith =  880
# [Processing] ith =  881
# [Processing] ith =  882
# [Processing] ith =  883
# [Processing] ith =  884
# [Processing] ith =  885
# [Processing] ith =  886
# [Processing] ith =  887
# [Processing] ith =  888
# [Processing] ith =  889
# [Processing] ith =  890
# [Processing] ith =  891
# [Processing] ith =  892
# [Processing] ith =  893
# [Processing] ith =  894
# [Processing] ith =  895
# [Processing] ith =  896
# [Processing] ith =  897
# [Processing] ith =  898
# [Processing] ith =  899
# [Processing] ith =  900
# [Processing] ith =  901
# [Processing] ith =  902
# [Processing] ith =  903
# [Processing] ith =  904
# [Processing] ith =  905
# [Processing] ith =  906
# [Processing] ith =  907
# [Processing] ith =  908
# [Processing] ith =  909
# [Processing] ith =  910
# [Processing] ith =  911
# [Processing] ith =  912
# [Processing] ith =  913
# [Processing] ith =  914
# [Processing] ith =  915
# [Processing] ith =  916
# [Processing] ith =  917
# [Processing] ith =  918
# [Processing] ith =  919
# [Processing] ith =  920
# [Processing] ith =  921
# [Processing] ith =  922
# [Processing] ith =  923
# [Processing] ith =  924
# [Processing] ith =  925
# [Processing] ith =  926
# [Processing] ith =  927
# [Processing] ith =  928
# [Processing] ith =  929
# [Processing] ith =  930
# [Processing] ith =  931
# [Processing] ith =  932
# [Processing] ith =  933
# [Processing] ith =  934
# [Processing] ith =  935
# [Processing] ith =  936
# [Processing] ith =  937
# [Processing] ith =  938
# [Processing] ith =  939
# [Processing] ith =  940
# [Processing] ith =  941
# [Processing] ith =  942
# [Processing] ith =  943
# [Processing] ith =  944
# [Processing] ith =  945
# [Processing] ith =  946
# [Processing] ith =  947
# [Processing] ith =  948
# [Processing] ith =  949
# [Processing] ith =  950
# [Processing] ith =  951
# [Processing] ith =  952
# [Processing] ith =  953
# [Processing] ith =  954
# [Processing] ith =  955
# [Processing] ith =  956
# [Processing] ith =  957
# [Processing] ith =  958
# [Processing] ith =  959
# [Processing] ith =  960
# [Processing] ith =  961
# [Processing] ith =  962
# [Processing] ith =  963
# [Processing] ith =  964
# [Processing] ith =  965
# [Processing] ith =  966
# [Processing] ith =  967
# [Processing] ith =  968
# [Processing] ith =  969
# [Processing] ith =  970
# [Processing] ith =  971
# [Processing] ith =  972
# [Processing] ith =  973
# [Processing] ith =  974
# [Processing] ith =  975
# [Processing] ith =  976
# [Processing] ith =  977
# [Processing] ith =  978
# [Processing] ith =  979
# [Processing] ith =  980
# [Processing] ith =  981
# [Processing] ith =  982
# [Processing] ith =  983
# [Processing] ith =  984
# [Processing] ith =  985
# [Processing] ith =  986
# [Processing] ith =  987
# [Processing] ith =  988
# [Processing] ith =  989
# [Processing] ith =  990
# [Processing] ith =  991
# [Processing] ith =  992
# [Processing] ith =  993
# [Processing] ith =  994
# [Processing] ith =  995
# [Processing] ith =  996
# [Processing] ith =  997
# [Processing] ith =  998
# [Processing] ith =  999

# %% [markdown]
# Plot only change column density

# %%
freq = 50

plot_log_nhis = (
    np.sin(np.linspace(-freq * np.pi, freq * np.pi, num_bins))
    * np.exp(np.linspace(1, -3.5, num_bins))
    + 20.98739284253573
)

# %%
plt.plot(plot_log_nhis)

# %%
for k, log_nhi in enumerate(plot_log_nhis):
    print("[Processing] ith = ", k)
    fig = make_plot(z_dlas=[2.7356542745587893], log_nhis=[log_nhi])
    fig.savefig(
        "animation2/demo_spec_{}_snr_35.png".format(str(k).zfill(4)),
        dpi=100,
        # transparent=True,
    )
    plt.close()
    plt.clf()
# Out:
# [Processing] ith =  0
# [Processing] ith =  1
# [Processing] ith =  2
# [Processing] ith =  3
# [Processing] ith =  4
# [Processing] ith =  5
# [Processing] ith =  6
# [Processing] ith =  7
# [Processing] ith =  8
# [Processing] ith =  9
# [Processing] ith =  10
# [Processing] ith =  11
# [Processing] ith =  12
# [Processing] ith =  13
# [Processing] ith =  14
# [Processing] ith =  15
# [Processing] ith =  16
# [Processing] ith =  17
# [Processing] ith =  18
# [Processing] ith =  19
# [Processing] ith =  20
# [Processing] ith =  21
# [Processing] ith =  22
# [Processing] ith =  23
# [Processing] ith =  24
# [Processing] ith =  25
# [Processing] ith =  26
# [Processing] ith =  27
# [Processing] ith =  28
# [Processing] ith =  29
# [Processing] ith =  30
# [Processing] ith =  31
# [Processing] ith =  32
# [Processing] ith =  33
# [Processing] ith =  34
# [Processing] ith =  35
# [Processing] ith =  36
# [Processing] ith =  37
# [Processing] ith =  38
# [Processing] ith =  39
# [Processing] ith =  40
# [Processing] ith =  41
# [Processing] ith =  42
# [Processing] ith =  43
# [Processing] ith =  44
# [Processing] ith =  45
# [Processing] ith =  46
# [Processing] ith =  47
# [Processing] ith =  48
# [Processing] ith =  49
# [Processing] ith =  50
# [Processing] ith =  51
# [Processing] ith =  52
# [Processing] ith =  53
# [Processing] ith =  54
# [Processing] ith =  55
# [Processing] ith =  56
# [Processing] ith =  57
# [Processing] ith =  58
# [Processing] ith =  59
# [Processing] ith =  60
# [Processing] ith =  61
# [Processing] ith =  62
# [Processing] ith =  63
# [Processing] ith =  64
# [Processing] ith =  65
# [Processing] ith =  66
# [Processing] ith =  67
# [Processing] ith =  68
# [Processing] ith =  69
# [Processing] ith =  70
# [Processing] ith =  71
# [Processing] ith =  72
# [Processing] ith =  73
# [Processing] ith =  74
# [Processing] ith =  75
# [Processing] ith =  76
# [Processing] ith =  77
# [Processing] ith =  78
# [Processing] ith =  79
# [Processing] ith =  80
# [Processing] ith =  81
# [Processing] ith =  82
# [Processing] ith =  83
# [Processing] ith =  84
# [Processing] ith =  85
# [Processing] ith =  86
# [Processing] ith =  87
# [Processing] ith =  88
# [Processing] ith =  89
# [Processing] ith =  90
# [Processing] ith =  91
# [Processing] ith =  92
# [Processing] ith =  93
# [Processing] ith =  94
# [Processing] ith =  95
# [Processing] ith =  96
# [Processing] ith =  97
# [Processing] ith =  98
# [Processing] ith =  99
# [Processing] ith =  100
# [Processing] ith =  101
# [Processing] ith =  102
# [Processing] ith =  103
# [Processing] ith =  104
# [Processing] ith =  105
# [Processing] ith =  106
# [Processing] ith =  107
# [Processing] ith =  108
# [Processing] ith =  109
# [Processing] ith =  110
# [Processing] ith =  111
# [Processing] ith =  112
# [Processing] ith =  113
# [Processing] ith =  114
# [Processing] ith =  115
# [Processing] ith =  116
# [Processing] ith =  117
# [Processing] ith =  118
# [Processing] ith =  119
# [Processing] ith =  120
# [Processing] ith =  121
# [Processing] ith =  122
# [Processing] ith =  123
# [Processing] ith =  124
# [Processing] ith =  125
# [Processing] ith =  126
# [Processing] ith =  127
# [Processing] ith =  128
# [Processing] ith =  129
# [Processing] ith =  130
# [Processing] ith =  131
# [Processing] ith =  132
# [Processing] ith =  133
# [Processing] ith =  134
# [Processing] ith =  135
# [Processing] ith =  136
# [Processing] ith =  137
# [Processing] ith =  138
# [Processing] ith =  139
# [Processing] ith =  140
# [Processing] ith =  141
# [Processing] ith =  142
# [Processing] ith =  143
# [Processing] ith =  144
# [Processing] ith =  145
# [Processing] ith =  146
# [Processing] ith =  147
# [Processing] ith =  148
# [Processing] ith =  149
# [Processing] ith =  150
# [Processing] ith =  151
# [Processing] ith =  152
# [Processing] ith =  153
# [Processing] ith =  154
# [Processing] ith =  155
# [Processing] ith =  156
# [Processing] ith =  157
# [Processing] ith =  158
# [Processing] ith =  159
# [Processing] ith =  160
# [Processing] ith =  161
# [Processing] ith =  162
# [Processing] ith =  163
# [Processing] ith =  164
# [Processing] ith =  165
# [Processing] ith =  166
# [Processing] ith =  167
# [Processing] ith =  168
# [Processing] ith =  169
# [Processing] ith =  170
# [Processing] ith =  171
# [Processing] ith =  172
# [Processing] ith =  173
# [Processing] ith =  174
# [Processing] ith =  175
# [Processing] ith =  176
# [Processing] ith =  177
# [Processing] ith =  178
# [Processing] ith =  179
# [Processing] ith =  180
# [Processing] ith =  181
# [Processing] ith =  182
# [Processing] ith =  183
# [Processing] ith =  184
# [Processing] ith =  185
# [Processing] ith =  186
# [Processing] ith =  187
# [Processing] ith =  188
# [Processing] ith =  189
# [Processing] ith =  190
# [Processing] ith =  191
# [Processing] ith =  192
# [Processing] ith =  193
# [Processing] ith =  194
# [Processing] ith =  195
# [Processing] ith =  196
# [Processing] ith =  197
# [Processing] ith =  198
# [Processing] ith =  199
# [Processing] ith =  200
# [Processing] ith =  201
# [Processing] ith =  202
# [Processing] ith =  203
# [Processing] ith =  204
# [Processing] ith =  205
# [Processing] ith =  206
# [Processing] ith =  207
# [Processing] ith =  208
# [Processing] ith =  209
# [Processing] ith =  210
# [Processing] ith =  211
# [Processing] ith =  212
# [Processing] ith =  213
# [Processing] ith =  214
# [Processing] ith =  215
# [Processing] ith =  216
# [Processing] ith =  217
# [Processing] ith =  218
# [Processing] ith =  219
# [Processing] ith =  220
# [Processing] ith =  221
# [Processing] ith =  222
# [Processing] ith =  223
# [Processing] ith =  224
# [Processing] ith =  225
# [Processing] ith =  226
# [Processing] ith =  227
# [Processing] ith =  228
# [Processing] ith =  229
# [Processing] ith =  230
# [Processing] ith =  231
# [Processing] ith =  232
# [Processing] ith =  233
# [Processing] ith =  234
# [Processing] ith =  235
# [Processing] ith =  236
# [Processing] ith =  237
# [Processing] ith =  238
# [Processing] ith =  239
# [Processing] ith =  240
# [Processing] ith =  241
# [Processing] ith =  242
# [Processing] ith =  243
# [Processing] ith =  244
# [Processing] ith =  245
# [Processing] ith =  246
# [Processing] ith =  247
# [Processing] ith =  248
# [Processing] ith =  249
# [Processing] ith =  250
# [Processing] ith =  251
# [Processing] ith =  252
# [Processing] ith =  253
# [Processing] ith =  254
# [Processing] ith =  255
# [Processing] ith =  256
# [Processing] ith =  257
# [Processing] ith =  258
# [Processing] ith =  259
# [Processing] ith =  260
# [Processing] ith =  261
# [Processing] ith =  262
# [Processing] ith =  263
# [Processing] ith =  264
# [Processing] ith =  265
# [Processing] ith =  266
# [Processing] ith =  267
# [Processing] ith =  268
# [Processing] ith =  269
# [Processing] ith =  270
# [Processing] ith =  271
# [Processing] ith =  272
# [Processing] ith =  273
# [Processing] ith =  274
# [Processing] ith =  275
# [Processing] ith =  276
# [Processing] ith =  277
# [Processing] ith =  278
# [Processing] ith =  279
# [Processing] ith =  280
# [Processing] ith =  281
# [Processing] ith =  282
# [Processing] ith =  283
# [Processing] ith =  284
# [Processing] ith =  285
# [Processing] ith =  286
# [Processing] ith =  287
# [Processing] ith =  288
# [Processing] ith =  289
# [Processing] ith =  290
# [Processing] ith =  291
# [Processing] ith =  292
# [Processing] ith =  293
# [Processing] ith =  294
# [Processing] ith =  295
# [Processing] ith =  296
# [Processing] ith =  297
# [Processing] ith =  298
# [Processing] ith =  299
# [Processing] ith =  300
# [Processing] ith =  301
# [Processing] ith =  302
# [Processing] ith =  303
# [Processing] ith =  304
# [Processing] ith =  305
# [Processing] ith =  306
# [Processing] ith =  307
# [Processing] ith =  308
# [Processing] ith =  309
# [Processing] ith =  310
# [Processing] ith =  311
# [Processing] ith =  312
# [Processing] ith =  313
# [Processing] ith =  314
# [Processing] ith =  315
# [Processing] ith =  316
# [Processing] ith =  317
# [Processing] ith =  318
# [Processing] ith =  319
# [Processing] ith =  320
# [Processing] ith =  321
# [Processing] ith =  322
# [Processing] ith =  323
# [Processing] ith =  324
# [Processing] ith =  325
# [Processing] ith =  326
# [Processing] ith =  327
# [Processing] ith =  328
# [Processing] ith =  329
# [Processing] ith =  330
# [Processing] ith =  331
# [Processing] ith =  332
# [Processing] ith =  333
# [Processing] ith =  334
# [Processing] ith =  335
# [Processing] ith =  336
# [Processing] ith =  337
# [Processing] ith =  338
# [Processing] ith =  339
# [Processing] ith =  340
# [Processing] ith =  341
# [Processing] ith =  342
# [Processing] ith =  343
# [Processing] ith =  344
# [Processing] ith =  345
# [Processing] ith =  346
# [Processing] ith =  347
# [Processing] ith =  348
# [Processing] ith =  349
# [Processing] ith =  350
# [Processing] ith =  351
# [Processing] ith =  352
# [Processing] ith =  353
# [Processing] ith =  354
# [Processing] ith =  355
# [Processing] ith =  356
# [Processing] ith =  357
# [Processing] ith =  358
# [Processing] ith =  359
# [Processing] ith =  360
# [Processing] ith =  361
# [Processing] ith =  362
# [Processing] ith =  363
# [Processing] ith =  364
# [Processing] ith =  365
# [Processing] ith =  366
# [Processing] ith =  367
# [Processing] ith =  368
# [Processing] ith =  369
# [Processing] ith =  370
# [Processing] ith =  371
# [Processing] ith =  372
# [Processing] ith =  373
# [Processing] ith =  374
# [Processing] ith =  375
# [Processing] ith =  376
# [Processing] ith =  377
# [Processing] ith =  378
# [Processing] ith =  379
# [Processing] ith =  380
# [Processing] ith =  381
# [Processing] ith =  382
# [Processing] ith =  383
# [Processing] ith =  384
# [Processing] ith =  385
# [Processing] ith =  386
# [Processing] ith =  387
# [Processing] ith =  388
# [Processing] ith =  389
# [Processing] ith =  390
# [Processing] ith =  391
# [Processing] ith =  392
# [Processing] ith =  393
# [Processing] ith =  394
# [Processing] ith =  395
# [Processing] ith =  396
# [Processing] ith =  397
# [Processing] ith =  398
# [Processing] ith =  399
# [Processing] ith =  400
# [Processing] ith =  401
# [Processing] ith =  402
# [Processing] ith =  403
# [Processing] ith =  404
# [Processing] ith =  405
# [Processing] ith =  406
# [Processing] ith =  407
# [Processing] ith =  408
# [Processing] ith =  409
# [Processing] ith =  410
# [Processing] ith =  411
# [Processing] ith =  412
# [Processing] ith =  413
# [Processing] ith =  414
# [Processing] ith =  415
# [Processing] ith =  416
# [Processing] ith =  417
# [Processing] ith =  418
# [Processing] ith =  419
# [Processing] ith =  420
# [Processing] ith =  421
# [Processing] ith =  422
# [Processing] ith =  423
# [Processing] ith =  424
# [Processing] ith =  425
# [Processing] ith =  426
# [Processing] ith =  427
# [Processing] ith =  428
# [Processing] ith =  429
# [Processing] ith =  430
# [Processing] ith =  431
# [Processing] ith =  432
# [Processing] ith =  433
# [Processing] ith =  434
# [Processing] ith =  435
# [Processing] ith =  436
# [Processing] ith =  437
# [Processing] ith =  438
# [Processing] ith =  439
# [Processing] ith =  440
# [Processing] ith =  441
# [Processing] ith =  442
# [Processing] ith =  443
# [Processing] ith =  444
# [Processing] ith =  445
# [Processing] ith =  446
# [Processing] ith =  447
# [Processing] ith =  448
# [Processing] ith =  449
# [Processing] ith =  450
# [Processing] ith =  451
# [Processing] ith =  452
# [Processing] ith =  453
# [Processing] ith =  454
# [Processing] ith =  455
# [Processing] ith =  456
# [Processing] ith =  457
# [Processing] ith =  458
# [Processing] ith =  459
# [Processing] ith =  460
# [Processing] ith =  461
# [Processing] ith =  462
# [Processing] ith =  463
# [Processing] ith =  464
# [Processing] ith =  465
# [Processing] ith =  466
# [Processing] ith =  467
# [Processing] ith =  468
# [Processing] ith =  469
# [Processing] ith =  470
# [Processing] ith =  471
# [Processing] ith =  472
# [Processing] ith =  473
# [Processing] ith =  474
# [Processing] ith =  475
# [Processing] ith =  476
# [Processing] ith =  477
# [Processing] ith =  478
# [Processing] ith =  479
# [Processing] ith =  480
# [Processing] ith =  481
# [Processing] ith =  482
# [Processing] ith =  483
# [Processing] ith =  484
# [Processing] ith =  485
# [Processing] ith =  486
# [Processing] ith =  487
# [Processing] ith =  488
# [Processing] ith =  489
# [Processing] ith =  490
# [Processing] ith =  491
# [Processing] ith =  492
# [Processing] ith =  493
# [Processing] ith =  494
# [Processing] ith =  495
# [Processing] ith =  496
# [Processing] ith =  497
# [Processing] ith =  498
# [Processing] ith =  499
# [Processing] ith =  500
# [Processing] ith =  501
# [Processing] ith =  502
# [Processing] ith =  503
# [Processing] ith =  504
# [Processing] ith =  505
# [Processing] ith =  506
# [Processing] ith =  507
# [Processing] ith =  508
# [Processing] ith =  509
# [Processing] ith =  510
# [Processing] ith =  511
# [Processing] ith =  512
# [Processing] ith =  513
# [Processing] ith =  514
# [Processing] ith =  515
# [Processing] ith =  516
# [Processing] ith =  517
# [Processing] ith =  518
# [Processing] ith =  519
# [Processing] ith =  520
# [Processing] ith =  521
# [Processing] ith =  522
# [Processing] ith =  523
# [Processing] ith =  524
# [Processing] ith =  525
# [Processing] ith =  526
# [Processing] ith =  527
# [Processing] ith =  528
# [Processing] ith =  529
# [Processing] ith =  530
# [Processing] ith =  531
# [Processing] ith =  532
# [Processing] ith =  533
# [Processing] ith =  534
# [Processing] ith =  535
# [Processing] ith =  536
# [Processing] ith =  537
# [Processing] ith =  538
# [Processing] ith =  539
# [Processing] ith =  540
# [Processing] ith =  541
# [Processing] ith =  542
# [Processing] ith =  543
# [Processing] ith =  544
# [Processing] ith =  545
# [Processing] ith =  546
# [Processing] ith =  547
# [Processing] ith =  548
# [Processing] ith =  549
# [Processing] ith =  550
# [Processing] ith =  551
# [Processing] ith =  552
# [Processing] ith =  553
# [Processing] ith =  554
# [Processing] ith =  555
# [Processing] ith =  556
# [Processing] ith =  557
# [Processing] ith =  558
# [Processing] ith =  559
# [Processing] ith =  560
# [Processing] ith =  561
# [Processing] ith =  562
# [Processing] ith =  563
# [Processing] ith =  564
# [Processing] ith =  565
# [Processing] ith =  566
# [Processing] ith =  567
# [Processing] ith =  568
# [Processing] ith =  569
# [Processing] ith =  570
# [Processing] ith =  571
# [Processing] ith =  572
# [Processing] ith =  573
# [Processing] ith =  574
# [Processing] ith =  575
# [Processing] ith =  576
# [Processing] ith =  577
# [Processing] ith =  578
# [Processing] ith =  579
# [Processing] ith =  580
# [Processing] ith =  581
# [Processing] ith =  582
# [Processing] ith =  583
# [Processing] ith =  584
# [Processing] ith =  585
# [Processing] ith =  586
# [Processing] ith =  587
# [Processing] ith =  588
# [Processing] ith =  589
# [Processing] ith =  590
# [Processing] ith =  591
# [Processing] ith =  592
# [Processing] ith =  593
# [Processing] ith =  594
# [Processing] ith =  595
# [Processing] ith =  596
# [Processing] ith =  597
# [Processing] ith =  598
# [Processing] ith =  599
# [Processing] ith =  600
# [Processing] ith =  601
# [Processing] ith =  602
# [Processing] ith =  603
# [Processing] ith =  604
# [Processing] ith =  605
# [Processing] ith =  606
# [Processing] ith =  607
# [Processing] ith =  608
# [Processing] ith =  609
# [Processing] ith =  610
# [Processing] ith =  611
# [Processing] ith =  612
# [Processing] ith =  613
# [Processing] ith =  614
# [Processing] ith =  615
# [Processing] ith =  616
# [Processing] ith =  617
# [Processing] ith =  618
# [Processing] ith =  619
# [Processing] ith =  620
# [Processing] ith =  621
# [Processing] ith =  622
# [Processing] ith =  623
# [Processing] ith =  624
# [Processing] ith =  625
# [Processing] ith =  626
# [Processing] ith =  627
# [Processing] ith =  628
# [Processing] ith =  629
# [Processing] ith =  630
# [Processing] ith =  631
# [Processing] ith =  632
# [Processing] ith =  633
# [Processing] ith =  634
# [Processing] ith =  635
# [Processing] ith =  636
# [Processing] ith =  637
# [Processing] ith =  638
# [Processing] ith =  639
# [Processing] ith =  640
# [Processing] ith =  641
# [Processing] ith =  642
# [Processing] ith =  643
# [Processing] ith =  644
# [Processing] ith =  645
# [Processing] ith =  646
# [Processing] ith =  647
# [Processing] ith =  648
# [Processing] ith =  649
# [Processing] ith =  650
# [Processing] ith =  651
# [Processing] ith =  652
# [Processing] ith =  653
# [Processing] ith =  654
# [Processing] ith =  655
# [Processing] ith =  656
# [Processing] ith =  657
# [Processing] ith =  658
# [Processing] ith =  659
# [Processing] ith =  660
# [Processing] ith =  661
# [Processing] ith =  662
# [Processing] ith =  663
# [Processing] ith =  664
# [Processing] ith =  665
# [Processing] ith =  666
# [Processing] ith =  667
# [Processing] ith =  668
# [Processing] ith =  669
# [Processing] ith =  670
# [Processing] ith =  671
# [Processing] ith =  672
# [Processing] ith =  673
# [Processing] ith =  674
# [Processing] ith =  675
# [Processing] ith =  676
# [Processing] ith =  677
# [Processing] ith =  678
# [Processing] ith =  679
# [Processing] ith =  680
# [Processing] ith =  681
# [Processing] ith =  682
# [Processing] ith =  683
# [Processing] ith =  684
# [Processing] ith =  685
# [Processing] ith =  686
# [Processing] ith =  687
# [Processing] ith =  688
# [Processing] ith =  689
# [Processing] ith =  690
# [Processing] ith =  691
# [Processing] ith =  692
# [Processing] ith =  693
# [Processing] ith =  694
# [Processing] ith =  695
# [Processing] ith =  696
# [Processing] ith =  697
# [Processing] ith =  698
# [Processing] ith =  699
# [Processing] ith =  700
# [Processing] ith =  701
# [Processing] ith =  702
# [Processing] ith =  703
# [Processing] ith =  704
# [Processing] ith =  705
# [Processing] ith =  706
# [Processing] ith =  707
# [Processing] ith =  708
# [Processing] ith =  709
# [Processing] ith =  710
# [Processing] ith =  711
# [Processing] ith =  712
# [Processing] ith =  713
# [Processing] ith =  714
# [Processing] ith =  715
# [Processing] ith =  716
# [Processing] ith =  717
# [Processing] ith =  718
# [Processing] ith =  719
# [Processing] ith =  720
# [Processing] ith =  721
# [Processing] ith =  722
# [Processing] ith =  723
# [Processing] ith =  724
# [Processing] ith =  725
# [Processing] ith =  726
# [Processing] ith =  727
# [Processing] ith =  728
# [Processing] ith =  729
# [Processing] ith =  730
# [Processing] ith =  731
# [Processing] ith =  732
# [Processing] ith =  733
# [Processing] ith =  734
# [Processing] ith =  735
# [Processing] ith =  736
# [Processing] ith =  737
# [Processing] ith =  738
# [Processing] ith =  739
# [Processing] ith =  740
# [Processing] ith =  741
# [Processing] ith =  742
# [Processing] ith =  743
# [Processing] ith =  744
# [Processing] ith =  745
# [Processing] ith =  746
# [Processing] ith =  747
# [Processing] ith =  748
# [Processing] ith =  749
# [Processing] ith =  750
# [Processing] ith =  751
# [Processing] ith =  752
# [Processing] ith =  753
# [Processing] ith =  754
# [Processing] ith =  755
# [Processing] ith =  756
# [Processing] ith =  757
# [Processing] ith =  758
# [Processing] ith =  759
# [Processing] ith =  760
# [Processing] ith =  761
# [Processing] ith =  762
# [Processing] ith =  763
# [Processing] ith =  764
# [Processing] ith =  765
# [Processing] ith =  766
# [Processing] ith =  767
# [Processing] ith =  768
# [Processing] ith =  769
# [Processing] ith =  770
# [Processing] ith =  771
# [Processing] ith =  772
# [Processing] ith =  773
# [Processing] ith =  774
# [Processing] ith =  775
# [Processing] ith =  776
# [Processing] ith =  777
# [Processing] ith =  778
# [Processing] ith =  779
# [Processing] ith =  780
# [Processing] ith =  781
# [Processing] ith =  782
# [Processing] ith =  783
# [Processing] ith =  784
# [Processing] ith =  785
# [Processing] ith =  786
# [Processing] ith =  787
# [Processing] ith =  788
# [Processing] ith =  789
# [Processing] ith =  790
# [Processing] ith =  791
# [Processing] ith =  792
# [Processing] ith =  793
# [Processing] ith =  794
# [Processing] ith =  795
# [Processing] ith =  796
# [Processing] ith =  797
# [Processing] ith =  798
# [Processing] ith =  799
# [Processing] ith =  800
# [Processing] ith =  801
# [Processing] ith =  802
# [Processing] ith =  803
# [Processing] ith =  804
# [Processing] ith =  805
# [Processing] ith =  806
# [Processing] ith =  807
# [Processing] ith =  808
# [Processing] ith =  809
# [Processing] ith =  810
# [Processing] ith =  811
# [Processing] ith =  812
# [Processing] ith =  813
# [Processing] ith =  814
# [Processing] ith =  815
# [Processing] ith =  816
# [Processing] ith =  817
# [Processing] ith =  818
# [Processing] ith =  819
# [Processing] ith =  820
# [Processing] ith =  821
# [Processing] ith =  822
# [Processing] ith =  823
# [Processing] ith =  824
# [Processing] ith =  825
# [Processing] ith =  826
# [Processing] ith =  827
# [Processing] ith =  828
# [Processing] ith =  829
# [Processing] ith =  830
# [Processing] ith =  831
# [Processing] ith =  832
# [Processing] ith =  833
# [Processing] ith =  834
# [Processing] ith =  835
# [Processing] ith =  836
# [Processing] ith =  837
# [Processing] ith =  838
# [Processing] ith =  839
# [Processing] ith =  840
# [Processing] ith =  841
# [Processing] ith =  842
# [Processing] ith =  843
# [Processing] ith =  844
# [Processing] ith =  845
# [Processing] ith =  846
# [Processing] ith =  847
# [Processing] ith =  848
# [Processing] ith =  849
# [Processing] ith =  850
# [Processing] ith =  851
# [Processing] ith =  852
# [Processing] ith =  853
# [Processing] ith =  854
# [Processing] ith =  855
# [Processing] ith =  856
# [Processing] ith =  857
# [Processing] ith =  858
# [Processing] ith =  859
# [Processing] ith =  860
# [Processing] ith =  861
# [Processing] ith =  862
# [Processing] ith =  863
# [Processing] ith =  864
# [Processing] ith =  865
# [Processing] ith =  866
# [Processing] ith =  867
# [Processing] ith =  868
# [Processing] ith =  869
# [Processing] ith =  870
# [Processing] ith =  871
# [Processing] ith =  872
# [Processing] ith =  873
# [Processing] ith =  874
# [Processing] ith =  875
# [Processing] ith =  876
# [Processing] ith =  877
# [Processing] ith =  878
# [Processing] ith =  879
# [Processing] ith =  880
# [Processing] ith =  881
# [Processing] ith =  882
# [Processing] ith =  883
# [Processing] ith =  884
# [Processing] ith =  885
# [Processing] ith =  886
# [Processing] ith =  887
# [Processing] ith =  888
# [Processing] ith =  889
# [Processing] ith =  890
# [Processing] ith =  891
# [Processing] ith =  892
# [Processing] ith =  893
# [Processing] ith =  894
# [Processing] ith =  895
# [Processing] ith =  896
# [Processing] ith =  897
# [Processing] ith =  898
# [Processing] ith =  899
# [Processing] ith =  900
# [Processing] ith =  901
# [Processing] ith =  902
# [Processing] ith =  903
# [Processing] ith =  904
# [Processing] ith =  905
# [Processing] ith =  906
# [Processing] ith =  907
# [Processing] ith =  908
# [Processing] ith =  909
# [Processing] ith =  910
# [Processing] ith =  911
# [Processing] ith =  912
# [Processing] ith =  913
# [Processing] ith =  914
# [Processing] ith =  915
# [Processing] ith =  916
# [Processing] ith =  917
# [Processing] ith =  918
# [Processing] ith =  919
# [Processing] ith =  920
# [Processing] ith =  921
# [Processing] ith =  922
# [Processing] ith =  923
# [Processing] ith =  924
# [Processing] ith =  925
# [Processing] ith =  926
# [Processing] ith =  927
# [Processing] ith =  928
# [Processing] ith =  929
# [Processing] ith =  930
# [Processing] ith =  931
# [Processing] ith =  932
# [Processing] ith =  933
# [Processing] ith =  934
# [Processing] ith =  935
# [Processing] ith =  936
# [Processing] ith =  937
# [Processing] ith =  938
# [Processing] ith =  939
# [Processing] ith =  940
# [Processing] ith =  941
# [Processing] ith =  942
# [Processing] ith =  943
# [Processing] ith =  944
# [Processing] ith =  945
# [Processing] ith =  946
# [Processing] ith =  947
# [Processing] ith =  948
# [Processing] ith =  949
# [Processing] ith =  950
# [Processing] ith =  951
# [Processing] ith =  952
# [Processing] ith =  953
# [Processing] ith =  954
# [Processing] ith =  955
# [Processing] ith =  956
# [Processing] ith =  957
# [Processing] ith =  958
# [Processing] ith =  959
# [Processing] ith =  960
# [Processing] ith =  961
# [Processing] ith =  962
# [Processing] ith =  963
# [Processing] ith =  964
# [Processing] ith =  965
# [Processing] ith =  966
# [Processing] ith =  967
# [Processing] ith =  968
# [Processing] ith =  969
# [Processing] ith =  970
# [Processing] ith =  971
# [Processing] ith =  972
# [Processing] ith =  973
# [Processing] ith =  974
# [Processing] ith =  975
# [Processing] ith =  976
# [Processing] ith =  977
# [Processing] ith =  978
# [Processing] ith =  979
# [Processing] ith =  980
# [Processing] ith =  981
# [Processing] ith =  982
# [Processing] ith =  983
# [Processing] ith =  984
# [Processing] ith =  985
# [Processing] ith =  986
# [Processing] ith =  987
# [Processing] ith =  988
# [Processing] ith =  989
# [Processing] ith =  990
# [Processing] ith =  991
# [Processing] ith =  992
# [Processing] ith =  993
# [Processing] ith =  994
# [Processing] ith =  995
# [Processing] ith =  996
# [Processing] ith =  997
# [Processing] ith =  998
# [Processing] ith =  999

# %% [markdown]
# Also vary redshift

# %%
z_qso
# Out:
# 2.956

# %%
def make_plot(z_dlas=[2.7356542745587893], log_nhis=[20.98739284253573], z_qso=2.956):
    # Now you can get the model with Lya absorbers
    spacing = (real_index_zqso_sorted.shape[0]) // 12
    ind = np.arange(0, real_index_zqso_sorted.shape[0], spacing)

    ind = ind[5]

    ith = real_index_zqso_sorted[ind]

    spec_dict = dr12q_catalog[real_index[ith]]

    # extract info
    plate = spec_dict["plate"]
    mjd = spec_dict["mjd"]
    fiber_id = spec_dict["fiber_id"]

    # read spec
    wavelengths, flux, noise_variance, pixel_mask = download_and_read(
        plate, mjd, fiber_id
    )

    # z_qso = spec_dict["z_qso"]
    rest_wavelengths = wavelengths / (1 + z_qso)

    # # dla detection
    # dlas_dict = spec_dict["dlas"]
    # num_dlas = len(dlas_dict)
    # z_dlas = []
    # log_nhis = []
    # for j in range(num_dlas):
    #     z_dlas.append(dlas_dict[j]["z_dla"])
    #     log_nhis.append(dlas_dict[j]["log_nhi"])

    # Print out the basic info
    # print(spec_dict)

    ################### Plotting the model ###################
    fig, ax = plt.subplots(1, 1, figsize=(16, 7))
    # from blue to red
    redshift_color = "C1"
    model_color = "C0"

    # plotting normalization
    normalization = 0

    # Make the GP model interpolated onto the observed quasar spectum
    gp.set_data(
        rest_wavelengths, flux, noise_variance, pixel_mask, z_qso, build_model=True
    )
    # p( D | z_abs =  z_lya, NHI = nhi, absorber model)
    lya_gp.set_data(
        rest_wavelengths,
        flux,
        noise_variance,
        pixel_mask,
        z_qso,
        build_model=True,
    )
    lya_mu, lya_M, lya_omega2 = lya_gp.this_dla_gp(
        z_dlas, [10**log_nhi for log_nhi in log_nhis]
    )

    ################# Whole spectrum without cropping ###############
    # normalize spectrum
    ind_norm = (
        (rest_wavelengths >= gp.params.normalization_min_lambda)
        & (rest_wavelengths <= gp.params.normalization_max_lambda)
        & (~pixel_mask)
    )
    this_median = np.nanmedian(flux[ind_norm])
    flux = flux / this_median
    # masking pixels
    wavelengths = wavelengths[~pixel_mask]
    rest_wavelengths = rest_wavelengths[~pixel_mask]
    flux = flux[~pixel_mask]

    # Mean function
    ax.plot(
        wavelengths,  # quasar spectrum's rest-frame wavelengths
        flux + normalization,  # quasar spectrum's flux
        label="Data",
        color="black",
        lw=0.6,
        alpha=0.9,
    )
    ax.fill_between(
        wavelengths,
        -0.5,
        flux + normalization,
        label="SDSS Instrumental Uncertainty (95%)",
        color=redshift_color,
        # alpha=0.6,
    )

    ax.plot(
        gp.rest_wavelengths * (1 + z_qso),
        gp.mu + normalization,
        label="GP null model (mu = continuum)",
        color=model_color,
        # ls="--",
        linewidth=2.2,
        alpha=0.9,
    )

    # This line plots model
    ax.plot(
        gp.X * (1 + z_qso),
        lya_mu + normalization,
        color=model_color,
        label="GP Lya model (mu = meanflux)",
    )  # GP model's mean function
    ax.fill_between(
        gp.X * (1 + z_qso),
        lya_mu + normalization,
        gp.mu_interpolator(gp.X),
        color=model_color,
        alpha=0.7,
        label="Absorption",
        ls="--",
    )
    # plt.text(gp.X[200] * (1 + z_qso), lya_mu[200] * normalization, "$z_{QSO} = $" + "{:.3g}".format(z_qso))

    ax.set_xlabel("Observed-frame Wavelengths [$\AA$]", fontdict={"fontsize": 16})
    # ax.set_ylabel("Normalized Flux")
    ax.set_xlim(3600, 4800)
    ax.set_ylim(-0.5, 5)

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)

    ax.text(
        4600,
        4,
        "$z_{DLA}$ = "
        + "{:.4g};\n".format(z_dlas[0])
        + "$\log N_\mathrm{HI}$ = "
        + "{:.4g};\n".format(log_nhis[0])
        + "$z_{QSO}$ = "
        + "{:.4g};".format(z_qso),
        fontdict={"fontsize": 20},
    )

    # ax.axis("off")
    ax.set(yticklabels=[])
    fig.tight_layout()

    # fig.savefig(
    #     "cover_photos/demo_spec_{}_snr_35.png".format(k), dpi=150, transparent=True
    # )
    return fig

# %%
make_plot(z_qso=3.1)

# %% [markdown]
# ## Sampling from Gaussian process

# %%
sample = np.random.multivariate_normal(gp.mu, gp.K, size=1000)

# %%
plt.style.use("dark_background")

# %%
def make_gp_sample_plot(i):
    fig, ax = plt.subplots(1, 1, figsize=(16, 3))
    ax.plot(gp.rest_wavelengths, gp.mu)
    ax.plot(gp.rest_wavelengths, sample[i, :], color="C1", alpha=0.9)
    ax.fill_between(gp.rest_wavelengths, sample[i, :], gp.mu, color="C1", alpha=0.1)

    ax.set_ylim(-1, 6)
    ax.set(yticklabels=[])

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)

    ax.set_xlabel("Rest-frame Wavelengths [$\AA$]", fontdict={"fontsize": 16})

    fig.tight_layout()

    return fig

# %%
sort_index = np.argsort(sample.mean(axis=1))[::-1]

for i in range(1000):
    print("[Processing] ith = ", i)
    # ind = np.random.randint(0, 1000, size=5)
    fig = make_gp_sample_plot(sort_index[i])
    fig.savefig(
        "gp_animation/gp_{}.png".format(str(i).zfill(4)),
        dpi=100,
        # transparent=True,
    )
    plt.close()
    plt.clf()
# Out:
# [Processing] ith =  0
# [Processing] ith =  1
# [Processing] ith =  2
# [Processing] ith =  3
# [Processing] ith =  4
# [Processing] ith =  5
# [Processing] ith =  6
# [Processing] ith =  7
# [Processing] ith =  8
# [Processing] ith =  9
# [Processing] ith =  10
# [Processing] ith =  11
# [Processing] ith =  12
# [Processing] ith =  13
# [Processing] ith =  14
# [Processing] ith =  15
# [Processing] ith =  16
# [Processing] ith =  17
# [Processing] ith =  18
# [Processing] ith =  19
# [Processing] ith =  20
# [Processing] ith =  21
# [Processing] ith =  22
# [Processing] ith =  23
# [Processing] ith =  24
# [Processing] ith =  25
# [Processing] ith =  26
# [Processing] ith =  27
# [Processing] ith =  28
# [Processing] ith =  29
# [Processing] ith =  30
# [Processing] ith =  31
# [Processing] ith =  32
# [Processing] ith =  33
# [Processing] ith =  34
# [Processing] ith =  35
# [Processing] ith =  36
# [Processing] ith =  37
# [Processing] ith =  38
# [Processing] ith =  39
# [Processing] ith =  40
# [Processing] ith =  41
# [Processing] ith =  42
# [Processing] ith =  43
# [Processing] ith =  44
# [Processing] ith =  45
# [Processing] ith =  46
# [Processing] ith =  47
# [Processing] ith =  48
# [Processing] ith =  49
# [Processing] ith =  50
# [Processing] ith =  51
# [Processing] ith =  52
# [Processing] ith =  53
# [Processing] ith =  54
# [Processing] ith =  55
# [Processing] ith =  56
# [Processing] ith =  57
# [Processing] ith =  58
# [Processing] ith =  59
# [Processing] ith =  60
# [Processing] ith =  61
# [Processing] ith =  62
# [Processing] ith =  63
# [Processing] ith =  64
# [Processing] ith =  65
# [Processing] ith =  66
# [Processing] ith =  67
# [Processing] ith =  68
# [Processing] ith =  69
# [Processing] ith =  70
# [Processing] ith =  71
# [Processing] ith =  72
# [Processing] ith =  73
# [Processing] ith =  74
# [Processing] ith =  75
# [Processing] ith =  76
# [Processing] ith =  77
# [Processing] ith =  78
# [Processing] ith =  79
# [Processing] ith =  80
# [Processing] ith =  81
# [Processing] ith =  82
# [Processing] ith =  83
# [Processing] ith =  84
# [Processing] ith =  85
# [Processing] ith =  86
# [Processing] ith =  87
# [Processing] ith =  88
# [Processing] ith =  89
# [Processing] ith =  90
# [Processing] ith =  91
# [Processing] ith =  92
# [Processing] ith =  93
# [Processing] ith =  94
# [Processing] ith =  95
# [Processing] ith =  96
# [Processing] ith =  97
# [Processing] ith =  98
# [Processing] ith =  99
# [Processing] ith =  100
# [Processing] ith =  101
# [Processing] ith =  102
# [Processing] ith =  103
# [Processing] ith =  104
# [Processing] ith =  105
# [Processing] ith =  106
# [Processing] ith =  107
# [Processing] ith =  108
# [Processing] ith =  109
# [Processing] ith =  110
# [Processing] ith =  111
# [Processing] ith =  112
# [Processing] ith =  113
# [Processing] ith =  114
# [Processing] ith =  115
# [Processing] ith =  116
# [Processing] ith =  117
# [Processing] ith =  118
# [Processing] ith =  119
# [Processing] ith =  120
# [Processing] ith =  121
# [Processing] ith =  122
# [Processing] ith =  123
# [Processing] ith =  124
# [Processing] ith =  125
# [Processing] ith =  126
# [Processing] ith =  127
# [Processing] ith =  128
# [Processing] ith =  129
# [Processing] ith =  130
# [Processing] ith =  131
# [Processing] ith =  132
# [Processing] ith =  133
# [Processing] ith =  134
# [Processing] ith =  135
# [Processing] ith =  136
# [Processing] ith =  137
# [Processing] ith =  138
# [Processing] ith =  139
# [Processing] ith =  140
# [Processing] ith =  141
# [Processing] ith =  142
# [Processing] ith =  143
# [Processing] ith =  144
# [Processing] ith =  145
# [Processing] ith =  146
# [Processing] ith =  147
# [Processing] ith =  148
# [Processing] ith =  149
# [Processing] ith =  150
# [Processing] ith =  151
# [Processing] ith =  152
# [Processing] ith =  153
# [Processing] ith =  154
# [Processing] ith =  155
# [Processing] ith =  156
# [Processing] ith =  157
# [Processing] ith =  158
# [Processing] ith =  159
# [Processing] ith =  160
# [Processing] ith =  161
# [Processing] ith =  162
# [Processing] ith =  163
# [Processing] ith =  164
# [Processing] ith =  165
# [Processing] ith =  166
# [Processing] ith =  167
# [Processing] ith =  168
# [Processing] ith =  169
# [Processing] ith =  170
# [Processing] ith =  171
# [Processing] ith =  172
# [Processing] ith =  173
# [Processing] ith =  174
# [Processing] ith =  175
# [Processing] ith =  176
# [Processing] ith =  177
# [Processing] ith =  178
# [Processing] ith =  179
# [Processing] ith =  180
# [Processing] ith =  181
# [Processing] ith =  182
# [Processing] ith =  183
# [Processing] ith =  184
# [Processing] ith =  185
# [Processing] ith =  186
# [Processing] ith =  187
# [Processing] ith =  188
# [Processing] ith =  189
# [Processing] ith =  190
# [Processing] ith =  191
# [Processing] ith =  192
# [Processing] ith =  193
# [Processing] ith =  194
# [Processing] ith =  195
# [Processing] ith =  196
# [Processing] ith =  197
# [Processing] ith =  198
# [Processing] ith =  199
# [Processing] ith =  200
# [Processing] ith =  201
# [Processing] ith =  202
# [Processing] ith =  203
# [Processing] ith =  204
# [Processing] ith =  205
# [Processing] ith =  206
# [Processing] ith =  207
# [Processing] ith =  208
# [Processing] ith =  209
# [Processing] ith =  210
# [Processing] ith =  211
# [Processing] ith =  212
# [Processing] ith =  213
# [Processing] ith =  214
# [Processing] ith =  215
# [Processing] ith =  216
# [Processing] ith =  217
# [Processing] ith =  218
# [Processing] ith =  219
# [Processing] ith =  220
# [Processing] ith =  221
# [Processing] ith =  222
# [Processing] ith =  223
# [Processing] ith =  224
# [Processing] ith =  225
# [Processing] ith =  226
# [Processing] ith =  227
# [Processing] ith =  228
# [Processing] ith =  229
# [Processing] ith =  230
# [Processing] ith =  231
# [Processing] ith =  232
# [Processing] ith =  233
# [Processing] ith =  234
# [Processing] ith =  235
# [Processing] ith =  236
# [Processing] ith =  237
# [Processing] ith =  238
# [Processing] ith =  239
# [Processing] ith =  240
# [Processing] ith =  241
# [Processing] ith =  242
# [Processing] ith =  243
# [Processing] ith =  244
# [Processing] ith =  245
# [Processing] ith =  246
# [Processing] ith =  247
# [Processing] ith =  248
# [Processing] ith =  249
# [Processing] ith =  250
# [Processing] ith =  251
# [Processing] ith =  252
# [Processing] ith =  253
# [Processing] ith =  254
# [Processing] ith =  255
# [Processing] ith =  256
# [Processing] ith =  257
# [Processing] ith =  258
# [Processing] ith =  259
# [Processing] ith =  260
# [Processing] ith =  261
# [Processing] ith =  262
# [Processing] ith =  263
# [Processing] ith =  264
# [Processing] ith =  265
# [Processing] ith =  266
# [Processing] ith =  267
# [Processing] ith =  268
# [Processing] ith =  269
# [Processing] ith =  270
# [Processing] ith =  271
# [Processing] ith =  272
# [Processing] ith =  273
# [Processing] ith =  274
# [Processing] ith =  275
# [Processing] ith =  276
# [Processing] ith =  277
# [Processing] ith =  278
# [Processing] ith =  279
# [Processing] ith =  280
# [Processing] ith =  281
# [Processing] ith =  282
# [Processing] ith =  283
# [Processing] ith =  284
# [Processing] ith =  285
# [Processing] ith =  286
# [Processing] ith =  287
# [Processing] ith =  288
# [Processing] ith =  289
# [Processing] ith =  290
# [Processing] ith =  291
# [Processing] ith =  292
# [Processing] ith =  293
# [Processing] ith =  294
# [Processing] ith =  295
# [Processing] ith =  296
# [Processing] ith =  297
# [Processing] ith =  298
# [Processing] ith =  299
# [Processing] ith =  300
# [Processing] ith =  301
# [Processing] ith =  302
# [Processing] ith =  303
# [Processing] ith =  304
# [Processing] ith =  305
# [Processing] ith =  306
# [Processing] ith =  307
# [Processing] ith =  308
# [Processing] ith =  309
# [Processing] ith =  310
# [Processing] ith =  311
# [Processing] ith =  312
# [Processing] ith =  313
# [Processing] ith =  314
# [Processing] ith =  315
# [Processing] ith =  316
# [Processing] ith =  317
# [Processing] ith =  318
# [Processing] ith =  319
# [Processing] ith =  320
# [Processing] ith =  321
# [Processing] ith =  322
# [Processing] ith =  323
# [Processing] ith =  324
# [Processing] ith =  325
# [Processing] ith =  326
# [Processing] ith =  327
# [Processing] ith =  328
# [Processing] ith =  329
# [Processing] ith =  330
# [Processing] ith =  331
# [Processing] ith =  332
# [Processing] ith =  333
# [Processing] ith =  334
# [Processing] ith =  335
# [Processing] ith =  336
# [Processing] ith =  337
# [Processing] ith =  338
# [Processing] ith =  339
# [Processing] ith =  340
# [Processing] ith =  341
# [Processing] ith =  342
# [Processing] ith =  343
# [Processing] ith =  344
# [Processing] ith =  345
# [Processing] ith =  346
# [Processing] ith =  347
# [Processing] ith =  348
# [Processing] ith =  349
# [Processing] ith =  350
# [Processing] ith =  351
# [Processing] ith =  352
# [Processing] ith =  353
# [Processing] ith =  354
# [Processing] ith =  355
# [Processing] ith =  356
# [Processing] ith =  357
# [Processing] ith =  358
# [Processing] ith =  359
# [Processing] ith =  360
# [Processing] ith =  361
# [Processing] ith =  362
# [Processing] ith =  363
# [Processing] ith =  364
# [Processing] ith =  365
# [Processing] ith =  366
# [Processing] ith =  367
# [Processing] ith =  368
# [Processing] ith =  369
# [Processing] ith =  370
# [Processing] ith =  371
# [Processing] ith =  372
# [Processing] ith =  373
# [Processing] ith =  374
# [Processing] ith =  375
# [Processing] ith =  376
# [Processing] ith =  377
# [Processing] ith =  378
# [Processing] ith =  379
# [Processing] ith =  380
# [Processing] ith =  381
# [Processing] ith =  382
# [Processing] ith =  383
# [Processing] ith =  384
# [Processing] ith =  385
# [Processing] ith =  386
# [Processing] ith =  387
# [Processing] ith =  388
# [Processing] ith =  389
# [Processing] ith =  390
# [Processing] ith =  391
# [Processing] ith =  392
# [Processing] ith =  393
# [Processing] ith =  394
# [Processing] ith =  395
# [Processing] ith =  396
# [Processing] ith =  397
# [Processing] ith =  398
# [Processing] ith =  399
# [Processing] ith =  400
# [Processing] ith =  401
# [Processing] ith =  402
# [Processing] ith =  403
# [Processing] ith =  404
# [Processing] ith =  405
# [Processing] ith =  406
# [Processing] ith =  407
# [Processing] ith =  408
# [Processing] ith =  409
# [Processing] ith =  410
# [Processing] ith =  411
# [Processing] ith =  412
# [Processing] ith =  413
# [Processing] ith =  414
# [Processing] ith =  415
# [Processing] ith =  416
# [Processing] ith =  417
# [Processing] ith =  418
# [Processing] ith =  419
# [Processing] ith =  420
# [Processing] ith =  421
# [Processing] ith =  422
# [Processing] ith =  423
# [Processing] ith =  424
# [Processing] ith =  425
# [Processing] ith =  426
# [Processing] ith =  427
# [Processing] ith =  428
# [Processing] ith =  429
# [Processing] ith =  430
# [Processing] ith =  431
# [Processing] ith =  432
# [Processing] ith =  433
# [Processing] ith =  434
# [Processing] ith =  435
# [Processing] ith =  436
# [Processing] ith =  437
# [Processing] ith =  438
# [Processing] ith =  439
# [Processing] ith =  440
# [Processing] ith =  441
# [Processing] ith =  442
# [Processing] ith =  443
# [Processing] ith =  444
# [Processing] ith =  445
# [Processing] ith =  446
# [Processing] ith =  447
# [Processing] ith =  448
# [Processing] ith =  449
# [Processing] ith =  450
# [Processing] ith =  451
# [Processing] ith =  452
# [Processing] ith =  453
# [Processing] ith =  454
# [Processing] ith =  455
# [Processing] ith =  456
# [Processing] ith =  457
# [Processing] ith =  458
# [Processing] ith =  459
# [Processing] ith =  460
# [Processing] ith =  461
# [Processing] ith =  462
# [Processing] ith =  463
# [Processing] ith =  464
# [Processing] ith =  465
# [Processing] ith =  466
# [Processing] ith =  467
# [Processing] ith =  468
# [Processing] ith =  469
# [Processing] ith =  470
# [Processing] ith =  471
# [Processing] ith =  472
# [Processing] ith =  473
# [Processing] ith =  474
# [Processing] ith =  475
# [Processing] ith =  476
# [Processing] ith =  477
# [Processing] ith =  478
# [Processing] ith =  479
# [Processing] ith =  480
# [Processing] ith =  481
# [Processing] ith =  482
# [Processing] ith =  483
# [Processing] ith =  484
# [Processing] ith =  485
# [Processing] ith =  486
# [Processing] ith =  487
# [Processing] ith =  488
# [Processing] ith =  489
# [Processing] ith =  490
# [Processing] ith =  491
# [Processing] ith =  492
# [Processing] ith =  493
# [Processing] ith =  494
# [Processing] ith =  495
# [Processing] ith =  496
# [Processing] ith =  497
# [Processing] ith =  498
# [Processing] ith =  499
# [Processing] ith =  500
# [Processing] ith =  501
# [Processing] ith =  502
# [Processing] ith =  503
# [Processing] ith =  504
# [Processing] ith =  505
# [Processing] ith =  506
# [Processing] ith =  507
# [Processing] ith =  508
# [Processing] ith =  509
# [Processing] ith =  510
# [Processing] ith =  511
# [Processing] ith =  512
# [Processing] ith =  513
# [Processing] ith =  514
# [Processing] ith =  515
# [Processing] ith =  516
# [Processing] ith =  517
# [Processing] ith =  518
# [Processing] ith =  519
# [Processing] ith =  520
# [Processing] ith =  521
# [Processing] ith =  522
# [Processing] ith =  523
# [Processing] ith =  524
# [Processing] ith =  525
# [Processing] ith =  526
# [Processing] ith =  527
# [Processing] ith =  528
# [Processing] ith =  529
# [Processing] ith =  530
# [Processing] ith =  531
# [Processing] ith =  532
# [Processing] ith =  533
# [Processing] ith =  534
# [Processing] ith =  535
# [Processing] ith =  536
# [Processing] ith =  537
# [Processing] ith =  538
# [Processing] ith =  539
# [Processing] ith =  540
# [Processing] ith =  541
# [Processing] ith =  542
# [Processing] ith =  543
# [Processing] ith =  544
# [Processing] ith =  545
# [Processing] ith =  546
# [Processing] ith =  547
# [Processing] ith =  548
# [Processing] ith =  549
# [Processing] ith =  550
# [Processing] ith =  551
# [Processing] ith =  552
# [Processing] ith =  553
# [Processing] ith =  554
# [Processing] ith =  555
# [Processing] ith =  556
# [Processing] ith =  557
# [Processing] ith =  558
# [Processing] ith =  559
# [Processing] ith =  560
# [Processing] ith =  561
# [Processing] ith =  562
# [Processing] ith =  563
# [Processing] ith =  564
# [Processing] ith =  565
# [Processing] ith =  566
# [Processing] ith =  567
# [Processing] ith =  568
# [Processing] ith =  569
# [Processing] ith =  570
# [Processing] ith =  571
# [Processing] ith =  572
# [Processing] ith =  573
# [Processing] ith =  574
# [Processing] ith =  575
# [Processing] ith =  576
# [Processing] ith =  577
# [Processing] ith =  578
# [Processing] ith =  579
# [Processing] ith =  580
# [Processing] ith =  581
# [Processing] ith =  582
# [Processing] ith =  583
# [Processing] ith =  584
# [Processing] ith =  585
# [Processing] ith =  586
# [Processing] ith =  587
# [Processing] ith =  588
# [Processing] ith =  589
# [Processing] ith =  590
# [Processing] ith =  591
# [Processing] ith =  592
# [Processing] ith =  593
# [Processing] ith =  594
# [Processing] ith =  595
# [Processing] ith =  596
# [Processing] ith =  597
# [Processing] ith =  598
# [Processing] ith =  599
# [Processing] ith =  600
# [Processing] ith =  601
# [Processing] ith =  602
# [Processing] ith =  603
# [Processing] ith =  604
# [Processing] ith =  605
# [Processing] ith =  606
# [Processing] ith =  607
# [Processing] ith =  608
# [Processing] ith =  609
# [Processing] ith =  610
# [Processing] ith =  611
# [Processing] ith =  612
# [Processing] ith =  613
# [Processing] ith =  614
# [Processing] ith =  615
# [Processing] ith =  616
# [Processing] ith =  617
# [Processing] ith =  618
# [Processing] ith =  619
# [Processing] ith =  620
# [Processing] ith =  621
# [Processing] ith =  622
# [Processing] ith =  623
# [Processing] ith =  624
# [Processing] ith =  625
# [Processing] ith =  626
# [Processing] ith =  627
# [Processing] ith =  628
# [Processing] ith =  629
# [Processing] ith =  630
# [Processing] ith =  631
# [Processing] ith =  632
# [Processing] ith =  633
# [Processing] ith =  634
# [Processing] ith =  635
# [Processing] ith =  636
# [Processing] ith =  637
# [Processing] ith =  638
# [Processing] ith =  639
# [Processing] ith =  640
# [Processing] ith =  641
# [Processing] ith =  642
# [Processing] ith =  643
# [Processing] ith =  644
# [Processing] ith =  645
# [Processing] ith =  646
# [Processing] ith =  647
# [Processing] ith =  648
# [Processing] ith =  649
# [Processing] ith =  650
# [Processing] ith =  651
# [Processing] ith =  652
# [Processing] ith =  653
# [Processing] ith =  654
# [Processing] ith =  655
# [Processing] ith =  656
# [Processing] ith =  657
# [Processing] ith =  658
# [Processing] ith =  659
# [Processing] ith =  660
# [Processing] ith =  661
# [Processing] ith =  662
# [Processing] ith =  663
# [Processing] ith =  664
# [Processing] ith =  665
# [Processing] ith =  666
# [Processing] ith =  667
# [Processing] ith =  668
# [Processing] ith =  669
# [Processing] ith =  670
# [Processing] ith =  671
# [Processing] ith =  672
# [Processing] ith =  673
# [Processing] ith =  674
# [Processing] ith =  675
# [Processing] ith =  676
# [Processing] ith =  677
# [Processing] ith =  678
# [Processing] ith =  679
# [Processing] ith =  680
# [Processing] ith =  681
# [Processing] ith =  682
# [Processing] ith =  683
# [Processing] ith =  684
# [Processing] ith =  685
# [Processing] ith =  686
# [Processing] ith =  687
# [Processing] ith =  688
# [Processing] ith =  689
# [Processing] ith =  690
# [Processing] ith =  691
# [Processing] ith =  692
# [Processing] ith =  693
# [Processing] ith =  694
# [Processing] ith =  695
# [Processing] ith =  696
# [Processing] ith =  697
# [Processing] ith =  698
# [Processing] ith =  699
# [Processing] ith =  700
# [Processing] ith =  701
# [Processing] ith =  702
# [Processing] ith =  703
# [Processing] ith =  704
# [Processing] ith =  705
# [Processing] ith =  706
# [Processing] ith =  707
# [Processing] ith =  708
# [Processing] ith =  709
# [Processing] ith =  710
# [Processing] ith =  711
# [Processing] ith =  712
# [Processing] ith =  713
# [Processing] ith =  714
# [Processing] ith =  715
# [Processing] ith =  716
# [Processing] ith =  717
# [Processing] ith =  718
# [Processing] ith =  719
# [Processing] ith =  720
# [Processing] ith =  721
# [Processing] ith =  722
# [Processing] ith =  723
# [Processing] ith =  724
# [Processing] ith =  725
# [Processing] ith =  726
# [Processing] ith =  727
# [Processing] ith =  728
# [Processing] ith =  729
# [Processing] ith =  730
# [Processing] ith =  731
# [Processing] ith =  732
# [Processing] ith =  733
# [Processing] ith =  734
# [Processing] ith =  735
# [Processing] ith =  736
# [Processing] ith =  737
# [Processing] ith =  738
# [Processing] ith =  739
# [Processing] ith =  740
# [Processing] ith =  741
# [Processing] ith =  742
# [Processing] ith =  743
# [Processing] ith =  744
# [Processing] ith =  745
# [Processing] ith =  746
# [Processing] ith =  747
# [Processing] ith =  748
# [Processing] ith =  749
# [Processing] ith =  750
# [Processing] ith =  751
# [Processing] ith =  752
# [Processing] ith =  753
# [Processing] ith =  754
# [Processing] ith =  755
# [Processing] ith =  756
# [Processing] ith =  757
# [Processing] ith =  758
# [Processing] ith =  759
# [Processing] ith =  760
# [Processing] ith =  761
# [Processing] ith =  762
# [Processing] ith =  763
# [Processing] ith =  764
# [Processing] ith =  765
# [Processing] ith =  766
# [Processing] ith =  767
# [Processing] ith =  768
# [Processing] ith =  769
# [Processing] ith =  770
# [Processing] ith =  771
# [Processing] ith =  772
# [Processing] ith =  773
# [Processing] ith =  774
# [Processing] ith =  775
# [Processing] ith =  776
# [Processing] ith =  777
# [Processing] ith =  778
# [Processing] ith =  779
# [Processing] ith =  780
# [Processing] ith =  781
# [Processing] ith =  782
# [Processing] ith =  783
# [Processing] ith =  784
# [Processing] ith =  785
# [Processing] ith =  786
# [Processing] ith =  787
# [Processing] ith =  788
# [Processing] ith =  789
# [Processing] ith =  790
# [Processing] ith =  791
# [Processing] ith =  792
# [Processing] ith =  793
# [Processing] ith =  794
# [Processing] ith =  795
# [Processing] ith =  796
# [Processing] ith =  797
# [Processing] ith =  798
# [Processing] ith =  799
# [Processing] ith =  800
# [Processing] ith =  801
# [Processing] ith =  802
# [Processing] ith =  803
# [Processing] ith =  804
# [Processing] ith =  805
# [Processing] ith =  806
# [Processing] ith =  807
# [Processing] ith =  808
# [Processing] ith =  809
# [Processing] ith =  810
# [Processing] ith =  811
# [Processing] ith =  812
# [Processing] ith =  813
# [Processing] ith =  814
# [Processing] ith =  815
# [Processing] ith =  816
# [Processing] ith =  817
# [Processing] ith =  818
# [Processing] ith =  819
# [Processing] ith =  820
# [Processing] ith =  821
# [Processing] ith =  822
# [Processing] ith =  823
# [Processing] ith =  824
# [Processing] ith =  825
# [Processing] ith =  826
# [Processing] ith =  827
# [Processing] ith =  828
# [Processing] ith =  829
# [Processing] ith =  830
# [Processing] ith =  831
# [Processing] ith =  832
# [Processing] ith =  833
# [Processing] ith =  834
# [Processing] ith =  835
# [Processing] ith =  836
# [Processing] ith =  837
# [Processing] ith =  838
# [Processing] ith =  839
# [Processing] ith =  840
# [Processing] ith =  841
# [Processing] ith =  842
# [Processing] ith =  843
# [Processing] ith =  844
# [Processing] ith =  845
# [Processing] ith =  846
# [Processing] ith =  847
# [Processing] ith =  848
# [Processing] ith =  849
# [Processing] ith =  850
# [Processing] ith =  851
# [Processing] ith =  852
# [Processing] ith =  853
# [Processing] ith =  854
# [Processing] ith =  855
# [Processing] ith =  856
# [Processing] ith =  857
# [Processing] ith =  858
# [Processing] ith =  859
# [Processing] ith =  860
# [Processing] ith =  861
# [Processing] ith =  862
# [Processing] ith =  863
# [Processing] ith =  864
# [Processing] ith =  865
# [Processing] ith =  866
# [Processing] ith =  867
# [Processing] ith =  868
# [Processing] ith =  869
# [Processing] ith =  870
# [Processing] ith =  871
# [Processing] ith =  872
# [Processing] ith =  873
# [Processing] ith =  874
# [Processing] ith =  875
# [Processing] ith =  876
# [Processing] ith =  877
# [Processing] ith =  878
# [Processing] ith =  879
# [Processing] ith =  880
# [Processing] ith =  881
# [Processing] ith =  882
# [Processing] ith =  883
# [Processing] ith =  884
# [Processing] ith =  885
# [Processing] ith =  886
# [Processing] ith =  887
# [Processing] ith =  888
# [Processing] ith =  889
# [Processing] ith =  890
# [Processing] ith =  891
# [Processing] ith =  892
# [Processing] ith =  893
# [Processing] ith =  894
# [Processing] ith =  895
# [Processing] ith =  896
# [Processing] ith =  897
# [Processing] ith =  898
# [Processing] ith =  899
# [Processing] ith =  900
# [Processing] ith =  901
# [Processing] ith =  902
# [Processing] ith =  903
# [Processing] ith =  904
# [Processing] ith =  905
# [Processing] ith =  906
# [Processing] ith =  907
# [Processing] ith =  908
# [Processing] ith =  909
# [Processing] ith =  910
# [Processing] ith =  911
# [Processing] ith =  912
# [Processing] ith =  913
# [Processing] ith =  914
# [Processing] ith =  915
# [Processing] ith =  916
# [Processing] ith =  917
# [Processing] ith =  918
# [Processing] ith =  919
# [Processing] ith =  920
# [Processing] ith =  921
# [Processing] ith =  922
# [Processing] ith =  923
# [Processing] ith =  924
# [Processing] ith =  925
# [Processing] ith =  926
# [Processing] ith =  927
# [Processing] ith =  928
# [Processing] ith =  929
# [Processing] ith =  930
# [Processing] ith =  931
# [Processing] ith =  932
# [Processing] ith =  933
# [Processing] ith =  934
# [Processing] ith =  935
# [Processing] ith =  936
# [Processing] ith =  937
# [Processing] ith =  938
# [Processing] ith =  939
# [Processing] ith =  940
# [Processing] ith =  941
# [Processing] ith =  942
# [Processing] ith =  943
# [Processing] ith =  944
# [Processing] ith =  945
# [Processing] ith =  946
# [Processing] ith =  947
# [Processing] ith =  948
# [Processing] ith =  949
# [Processing] ith =  950
# [Processing] ith =  951
# [Processing] ith =  952
# [Processing] ith =  953
# [Processing] ith =  954
# [Processing] ith =  955
# [Processing] ith =  956
# [Processing] ith =  957
# [Processing] ith =  958
# [Processing] ith =  959
# [Processing] ith =  960
# [Processing] ith =  961
# [Processing] ith =  962
# [Processing] ith =  963
# [Processing] ith =  964
# [Processing] ith =  965
# [Processing] ith =  966
# [Processing] ith =  967
# [Processing] ith =  968
# [Processing] ith =  969
# [Processing] ith =  970
# [Processing] ith =  971
# [Processing] ith =  972
# [Processing] ith =  973
# [Processing] ith =  974
# [Processing] ith =  975
# [Processing] ith =  976
# [Processing] ith =  977
# [Processing] ith =  978
# [Processing] ith =  979
# [Processing] ith =  980
# [Processing] ith =  981
# [Processing] ith =  982
# [Processing] ith =  983
# [Processing] ith =  984
# [Processing] ith =  985
# [Processing] ith =  986
# [Processing] ith =  987
# [Processing] ith =  988
# [Processing] ith =  989
# [Processing] ith =  990
# [Processing] ith =  991
# [Processing] ith =  992
# [Processing] ith =  993
# [Processing] ith =  994
# [Processing] ith =  995
# [Processing] ith =  996
# [Processing] ith =  997
# [Processing] ith =  998
# [Processing] ith =  999

# %% [markdown]
# ## GP Covariance

# %%
# Convert the covariance to correlation. Normalize the diag elements to unity
def build_correlation_matrix(M):
    """
    Covert covariance matrix to correlation matrix
    Parameters:
    ----
    M (N pixels, k) : K = M M' , K is a covariance matrix, M is its matrix decomposition
    Return:
    ----
    C : correlations matrix with its diag C = I
    """
    # build covariance matrix
    K = np.matmul(M, M.T)

    # query diag elements
    d = np.sqrt(np.diag(K))[:, np.newaxis]

    M_div_d = M / d

    C = np.matmul(M_div_d, M_div_d.T)

    return C


C = build_correlation_matrix(gp.this_M)


# scaling factor between rest_wavelengths to pixels
lyman_limit = 911
lyb_wavelength = 1025
lya_wavelength = 1216
nv_wavelength = 1240.81
oi_wavelength = 1305.53
cii_wavelength = 1335.31
siv_wavelength = 1399.8

# plotting covariance matrix
min_lambda = gp.params.min_lambda
max_lambda = gp.params.max_lambda
scale = np.shape(C)[0] / (max_lambda - min_lambda)

lyg_wavelength = 972

fig, ax = plt.subplots(figsize=(5.5, 5.5))
im = ax.imshow(C, origin="lower", cmap="plasma")
ax.set_xticks(
    [
        (lyman_limit - min_lambda) * scale,
        (lyg_wavelength - min_lambda) * scale,
        (lyb_wavelength - min_lambda) * scale,
        (lya_wavelength - min_lambda) * scale,
        (nv_wavelength - min_lambda) * scale,
        (oi_wavelength - min_lambda) * scale,
        (cii_wavelength - min_lambda) * scale,
        (siv_wavelength - min_lambda) * scale,
    ],
)
ax.set_xticklabels(
    [
        r"Ly $\infty$",
        r"Ly $\gamma$",
        r"Ly $\beta$",
        r"Ly $\alpha$",
        r"NV",
        r"OI",
        r"CII",
        r"SIV",
    ],
    rotation=45,
)
ax.set_yticks(
    [
        (lyman_limit - min_lambda) * scale,
        (lyg_wavelength - min_lambda) * scale,
        (lyb_wavelength - min_lambda) * scale,
        (lya_wavelength - min_lambda) * scale,
        (nv_wavelength - min_lambda) * scale,
        (oi_wavelength - min_lambda) * scale,
        (cii_wavelength - min_lambda) * scale,
        (siv_wavelength - min_lambda) * scale,
    ]
)
ax.set_yticklabels(
    [
        r"Ly $\infty$",
        r"Ly $\gamma$",
        r"Ly $\beta$",
        r"Ly $\alpha$",
        r"NV",
        r"OI",
        r"CII",
        r"SIV",
    ]
)

fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.savefig("covariance_matrix", format="png", dpi=300, transparent=True)

# %% [markdown]
# ## GP parameter variation animation

# %%
gp.prev_tau_0, gp.prev_beta
# Out:
# (0.00554, 3.182)

# %%
def make_gp_plot(
    z_dlas=[2.7356542745587893], log_nhis=[20.98739284253573], data=False, color="C1"
):
    # Now you can get the model with Lya absorbers
    spacing = (real_index_zqso_sorted.shape[0]) // 12
    ind = np.arange(0, real_index_zqso_sorted.shape[0], spacing)

    ind = ind[5]

    ith = real_index_zqso_sorted[ind]

    spec_dict = dr12q_catalog[real_index[ith]]

    # extract info
    plate = spec_dict["plate"]
    mjd = spec_dict["mjd"]
    fiber_id = spec_dict["fiber_id"]

    # read spec
    wavelengths, flux, noise_variance, pixel_mask = download_and_read(
        plate, mjd, fiber_id
    )

    z_qso = spec_dict["z_qso"]
    rest_wavelengths = wavelengths / (1 + z_qso)

    # # dla detection
    # dlas_dict = spec_dict["dlas"]
    # num_dlas = len(dlas_dict)
    # z_dlas = []
    # log_nhis = []
    # for j in range(num_dlas):
    #     z_dlas.append(dlas_dict[j]["z_dla"])
    #     log_nhis.append(dlas_dict[j]["log_nhi"])

    # Print out the basic info
    # print(spec_dict)

    ################### Plotting the model ###################
    fig, ax = plt.subplots(1, 1, figsize=(3, 3))
    # from blue to red
    redshift_color = "C0"
    model_color = color

    # plotting normalization
    normalization = 0

    # Make the GP model interpolated onto the observed quasar spectum
    gp.prev_tau_0, gp.prev_beta = 0, 0
    lya_gp.prev_tau_0, lya_gp.prev_beta = 0, 0

    gp.set_data(
        rest_wavelengths, flux, noise_variance, pixel_mask, z_qso, build_model=True
    )
    # p( D | z_abs =  z_lya, NHI = nhi, absorber model)
    lya_gp.set_data(
        rest_wavelengths,
        flux,
        noise_variance,
        pixel_mask,
        z_qso,
        build_model=True,
    )
    lya_mu, lya_M, lya_omega2 = lya_gp.this_dla_gp(
        z_dlas, [10**log_nhi for log_nhi in log_nhis]
    )

    ################# Whole spectrum without cropping ###############
    # normalize spectrum
    ind_norm = (
        (rest_wavelengths >= gp.params.normalization_min_lambda)
        & (rest_wavelengths <= gp.params.normalization_max_lambda)
        & (~pixel_mask)
    )
    this_median = np.nanmedian(flux[ind_norm])
    flux = flux / this_median
    # masking pixels
    wavelengths = wavelengths[~pixel_mask]
    rest_wavelengths = rest_wavelengths[~pixel_mask]
    flux = flux[~pixel_mask]

    # Mean function
    if data == True:
        ax.plot(
            wavelengths,  # quasar spectrum's rest-frame wavelengths
            flux + normalization,  # quasar spectrum's flux
            label="Data",
            # color="black",
            lw=0.6,
            alpha=0.9,
        )
        ax.fill_between(
            wavelengths,
            -0.5,
            flux + normalization,
            label="SDSS Instrumental Uncertainty (95%)",
            color=redshift_color,
            # alpha=0.6,
        )

    ax.plot(
        gp.rest_wavelengths * (1 + z_qso),
        gp.mu + normalization,
        label="GP null model (mu = continuum)",
        color=model_color,
        # ls="--",
        linewidth=2.2,
        alpha=0.9,
    )

    # This line plots model
    ax.plot(
        gp.X * (1 + z_qso),
        lya_mu + normalization,
        color=model_color,
        label="GP Lya model (mu = meanflux)",
    )  # GP model's mean function
    ax.fill_between(
        gp.X * (1 + z_qso),
        lya_mu + normalization,
        gp.mu_interpolator(gp.X),
        color=model_color,
        alpha=0.7,
        label="Absorption",
        ls="--",
    )
    # plt.text(gp.X[200] * (1 + z_qso), lya_mu[200] * normalization, "$z_{QSO} = $" + "{:.3g}".format(z_qso))

    ax.set_xlabel("Observed-frame Wavelengths [$\AA$]", fontdict={"fontsize": 8})
    # ax.set_ylabel("Normalized Flux")
    # ax.set_xlim(3600, 4800)

    ax.set_xlim(1216 * (1 + z_dlas[0] - 0.05), 1216 * (1 + z_dlas[0] + 0.05))
    ax.set_ylim(-0.5, 2)

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)

    ax.text(
        1216 * (1 + z_dlas[0]),
        1.5,
        "$\log N_\mathrm{HI}$ = " + "{:.4g};\n".format(log_nhis[0]),
        fontdict={"fontsize": 12},
    )

    ax.axis("off")
    ax.set(yticklabels=[])
    # fig.tight_layout()

    # fig.savefig(
    #     "cover_photos/demo_spec_{}_snr_35.png".format(k), dpi=150, transparent=True
    # )
    return fig

# %%
# DLAs
freq = 20

plot_log_nhis = np.sin(np.linspace(-freq * np.pi, freq * np.pi, num_bins)) + 21.3


for i, log_nhi in enumerate(plot_log_nhis):
    print("[Processing] ith = ", i)
    fig = make_gp_plot(
        z_dlas=[2.7356542745587893], log_nhis=[log_nhi], data=False, color="#89CE94"
    )

    fig.savefig(
        "gp_animation/dla_model/ver2/dla_{}.png".format(str(i).zfill(4)),
        dpi=100,
        # transparent=True,
    )
    plt.close()
    plt.clf()
# Out:
# [Processing] ith =  0
# [Processing] ith =  1
# [Processing] ith =  2
# [Processing] ith =  3
# [Processing] ith =  4
# [Processing] ith =  5
# [Processing] ith =  6
# [Processing] ith =  7
# [Processing] ith =  8
# [Processing] ith =  9
# [Processing] ith =  10
# [Processing] ith =  11
# [Processing] ith =  12
# [Processing] ith =  13
# [Processing] ith =  14
# [Processing] ith =  15
# [Processing] ith =  16
# [Processing] ith =  17
# [Processing] ith =  18
# [Processing] ith =  19
# [Processing] ith =  20
# [Processing] ith =  21
# [Processing] ith =  22
# [Processing] ith =  23
# [Processing] ith =  24
# [Processing] ith =  25
# [Processing] ith =  26
# [Processing] ith =  27
# [Processing] ith =  28
# [Processing] ith =  29
# [Processing] ith =  30
# [Processing] ith =  31
# [Processing] ith =  32
# [Processing] ith =  33
# [Processing] ith =  34
# [Processing] ith =  35
# [Processing] ith =  36
# [Processing] ith =  37
# [Processing] ith =  38
# [Processing] ith =  39
# [Processing] ith =  40
# [Processing] ith =  41
# [Processing] ith =  42
# [Processing] ith =  43
# [Processing] ith =  44
# [Processing] ith =  45
# [Processing] ith =  46
# [Processing] ith =  47
# [Processing] ith =  48
# [Processing] ith =  49
# [Processing] ith =  50
# [Processing] ith =  51
# [Processing] ith =  52
# [Processing] ith =  53
# [Processing] ith =  54
# [Processing] ith =  55
# [Processing] ith =  56
# [Processing] ith =  57
# [Processing] ith =  58
# [Processing] ith =  59
# [Processing] ith =  60
# [Processing] ith =  61
# [Processing] ith =  62
# [Processing] ith =  63
# [Processing] ith =  64
# [Processing] ith =  65
# [Processing] ith =  66
# [Processing] ith =  67
# [Processing] ith =  68
# [Processing] ith =  69
# [Processing] ith =  70
# [Processing] ith =  71
# [Processing] ith =  72
# [Processing] ith =  73
# [Processing] ith =  74
# [Processing] ith =  75
# [Processing] ith =  76
# [Processing] ith =  77
# [Processing] ith =  78
# [Processing] ith =  79
# [Processing] ith =  80
# [Processing] ith =  81
# [Processing] ith =  82
# [Processing] ith =  83
# [Processing] ith =  84
# [Processing] ith =  85
# [Processing] ith =  86
# [Processing] ith =  87
# [Processing] ith =  88
# [Processing] ith =  89
# [Processing] ith =  90
# [Processing] ith =  91
# [Processing] ith =  92
# [Processing] ith =  93
# [Processing] ith =  94
# [Processing] ith =  95
# [Processing] ith =  96
# [Processing] ith =  97
# [Processing] ith =  98
# [Processing] ith =  99
# [Processing] ith =  100
# [Processing] ith =  101
# [Processing] ith =  102
# [Processing] ith =  103
# [Processing] ith =  104
# [Processing] ith =  105
# [Processing] ith =  106
# [Processing] ith =  107
# [Processing] ith =  108
# [Processing] ith =  109
# [Processing] ith =  110
# [Processing] ith =  111
# [Processing] ith =  112
# [Processing] ith =  113
# [Processing] ith =  114
# [Processing] ith =  115
# [Processing] ith =  116
# [Processing] ith =  117
# [Processing] ith =  118
# [Processing] ith =  119
# [Processing] ith =  120
# [Processing] ith =  121
# [Processing] ith =  122
# [Processing] ith =  123
# [Processing] ith =  124
# [Processing] ith =  125
# [Processing] ith =  126
# [Processing] ith =  127
# [Processing] ith =  128
# [Processing] ith =  129
# [Processing] ith =  130
# [Processing] ith =  131
# [Processing] ith =  132
# [Processing] ith =  133
# [Processing] ith =  134
# [Processing] ith =  135
# [Processing] ith =  136
# [Processing] ith =  137
# [Processing] ith =  138
# [Processing] ith =  139
# [Processing] ith =  140
# [Processing] ith =  141
# [Processing] ith =  142
# [Processing] ith =  143
# [Processing] ith =  144
# [Processing] ith =  145
# [Processing] ith =  146
# [Processing] ith =  147
# [Processing] ith =  148
# [Processing] ith =  149
# [Processing] ith =  150
# [Processing] ith =  151
# [Processing] ith =  152
# [Processing] ith =  153
# [Processing] ith =  154
# [Processing] ith =  155
# [Processing] ith =  156
# [Processing] ith =  157
# [Processing] ith =  158
# [Processing] ith =  159
# [Processing] ith =  160
# [Processing] ith =  161
# [Processing] ith =  162
# [Processing] ith =  163
# [Processing] ith =  164
# [Processing] ith =  165
# [Processing] ith =  166
# [Processing] ith =  167
# [Processing] ith =  168
# [Processing] ith =  169
# [Processing] ith =  170
# [Processing] ith =  171
# [Processing] ith =  172
# [Processing] ith =  173
# [Processing] ith =  174
# [Processing] ith =  175
# [Processing] ith =  176
# [Processing] ith =  177
# [Processing] ith =  178
# [Processing] ith =  179
# [Processing] ith =  180
# [Processing] ith =  181
# [Processing] ith =  182
# [Processing] ith =  183
# [Processing] ith =  184
# [Processing] ith =  185
# [Processing] ith =  186
# [Processing] ith =  187
# [Processing] ith =  188
# [Processing] ith =  189
# [Processing] ith =  190
# [Processing] ith =  191
# [Processing] ith =  192
# [Processing] ith =  193
# [Processing] ith =  194
# [Processing] ith =  195
# [Processing] ith =  196
# [Processing] ith =  197
# [Processing] ith =  198
# [Processing] ith =  199
# [Processing] ith =  200
# [Processing] ith =  201
# [Processing] ith =  202
# [Processing] ith =  203
# [Processing] ith =  204
# [Processing] ith =  205
# [Processing] ith =  206
# [Processing] ith =  207
# [Processing] ith =  208
# [Processing] ith =  209
# [Processing] ith =  210
# [Processing] ith =  211
# [Processing] ith =  212
# [Processing] ith =  213
# [Processing] ith =  214
# [Processing] ith =  215
# [Processing] ith =  216
# [Processing] ith =  217
# [Processing] ith =  218
# [Processing] ith =  219
# [Processing] ith =  220
# [Processing] ith =  221
# [Processing] ith =  222
# [Processing] ith =  223
# [Processing] ith =  224
# [Processing] ith =  225
# [Processing] ith =  226
# [Processing] ith =  227
# [Processing] ith =  228
# [Processing] ith =  229
# [Processing] ith =  230
# [Processing] ith =  231
# [Processing] ith =  232
# [Processing] ith =  233
# [Processing] ith =  234
# [Processing] ith =  235
# [Processing] ith =  236
# [Processing] ith =  237
# [Processing] ith =  238
# [Processing] ith =  239
# [Processing] ith =  240
# [Processing] ith =  241
# [Processing] ith =  242
# [Processing] ith =  243
# [Processing] ith =  244
# [Processing] ith =  245
# [Processing] ith =  246
# [Processing] ith =  247
# [Processing] ith =  248
# [Processing] ith =  249
# [Processing] ith =  250
# [Processing] ith =  251
# [Processing] ith =  252
# [Processing] ith =  253
# [Processing] ith =  254
# [Processing] ith =  255
# [Processing] ith =  256
# [Processing] ith =  257
# [Processing] ith =  258
# [Processing] ith =  259
# [Processing] ith =  260
# [Processing] ith =  261
# [Processing] ith =  262
# [Processing] ith =  263
# [Processing] ith =  264
# [Processing] ith =  265
# [Processing] ith =  266
# [Processing] ith =  267
# [Processing] ith =  268
# [Processing] ith =  269
# [Processing] ith =  270
# [Processing] ith =  271
# [Processing] ith =  272
# [Processing] ith =  273
# [Processing] ith =  274
# [Processing] ith =  275
# [Processing] ith =  276
# [Processing] ith =  277
# [Processing] ith =  278
# [Processing] ith =  279
# [Processing] ith =  280
# [Processing] ith =  281
# [Processing] ith =  282
# [Processing] ith =  283
# [Processing] ith =  284
# [Processing] ith =  285
# [Processing] ith =  286
# [Processing] ith =  287
# [Processing] ith =  288
# [Processing] ith =  289
# [Processing] ith =  290
# [Processing] ith =  291
# [Processing] ith =  292
# [Processing] ith =  293
# [Processing] ith =  294
# [Processing] ith =  295
# [Processing] ith =  296
# [Processing] ith =  297
# [Processing] ith =  298
# [Processing] ith =  299
# [Processing] ith =  300
# [Processing] ith =  301
# [Processing] ith =  302
# [Processing] ith =  303
# [Processing] ith =  304
# [Processing] ith =  305
# [Processing] ith =  306
# [Processing] ith =  307
# [Processing] ith =  308
# [Processing] ith =  309
# [Processing] ith =  310
# [Processing] ith =  311
# [Processing] ith =  312
# [Processing] ith =  313
# [Processing] ith =  314
# [Processing] ith =  315
# [Processing] ith =  316
# [Processing] ith =  317
# [Processing] ith =  318
# [Processing] ith =  319
# [Processing] ith =  320
# [Processing] ith =  321
# [Processing] ith =  322
# [Processing] ith =  323
# [Processing] ith =  324
# [Processing] ith =  325
# [Processing] ith =  326
# [Processing] ith =  327
# [Processing] ith =  328
# [Processing] ith =  329
# [Processing] ith =  330
# [Processing] ith =  331
# [Processing] ith =  332
# [Processing] ith =  333
# [Processing] ith =  334
# [Processing] ith =  335
# [Processing] ith =  336
# [Processing] ith =  337
# [Processing] ith =  338
# [Processing] ith =  339
# [Processing] ith =  340
# [Processing] ith =  341
# [Processing] ith =  342
# [Processing] ith =  343
# [Processing] ith =  344
# [Processing] ith =  345
# [Processing] ith =  346
# [Processing] ith =  347
# [Processing] ith =  348
# [Processing] ith =  349
# [Processing] ith =  350
# [Processing] ith =  351
# [Processing] ith =  352
# [Processing] ith =  353
# [Processing] ith =  354
# [Processing] ith =  355
# [Processing] ith =  356
# [Processing] ith =  357
# [Processing] ith =  358
# [Processing] ith =  359
# [Processing] ith =  360
# [Processing] ith =  361
# [Processing] ith =  362
# [Processing] ith =  363
# [Processing] ith =  364
# [Processing] ith =  365
# [Processing] ith =  366
# [Processing] ith =  367
# [Processing] ith =  368
# [Processing] ith =  369
# [Processing] ith =  370
# [Processing] ith =  371
# [Processing] ith =  372
# [Processing] ith =  373
# [Processing] ith =  374
# [Processing] ith =  375
# [Processing] ith =  376
# [Processing] ith =  377
# [Processing] ith =  378
# [Processing] ith =  379
# [Processing] ith =  380
# [Processing] ith =  381
# [Processing] ith =  382
# [Processing] ith =  383
# [Processing] ith =  384
# [Processing] ith =  385
# [Processing] ith =  386
# [Processing] ith =  387
# [Processing] ith =  388
# [Processing] ith =  389
# [Processing] ith =  390
# [Processing] ith =  391
# [Processing] ith =  392
# [Processing] ith =  393
# [Processing] ith =  394
# [Processing] ith =  395
# [Processing] ith =  396
# [Processing] ith =  397
# [Processing] ith =  398
# [Processing] ith =  399
# [Processing] ith =  400
# [Processing] ith =  401
# [Processing] ith =  402
# [Processing] ith =  403
# [Processing] ith =  404
# [Processing] ith =  405
# [Processing] ith =  406
# [Processing] ith =  407
# [Processing] ith =  408
# [Processing] ith =  409
# [Processing] ith =  410
# [Processing] ith =  411
# [Processing] ith =  412
# [Processing] ith =  413
# [Processing] ith =  414
# [Processing] ith =  415
# [Processing] ith =  416
# [Processing] ith =  417
# [Processing] ith =  418
# [Processing] ith =  419
# [Processing] ith =  420
# [Processing] ith =  421
# [Processing] ith =  422
# [Processing] ith =  423
# [Processing] ith =  424
# [Processing] ith =  425
# [Processing] ith =  426
# [Processing] ith =  427
# [Processing] ith =  428
# [Processing] ith =  429
# [Processing] ith =  430
# [Processing] ith =  431
# [Processing] ith =  432
# [Processing] ith =  433
# [Processing] ith =  434
# [Processing] ith =  435
# [Processing] ith =  436
# [Processing] ith =  437
# [Processing] ith =  438
# [Processing] ith =  439
# [Processing] ith =  440
# [Processing] ith =  441
# [Processing] ith =  442
# [Processing] ith =  443
# [Processing] ith =  444
# [Processing] ith =  445
# [Processing] ith =  446
# [Processing] ith =  447
# [Processing] ith =  448
# [Processing] ith =  449
# [Processing] ith =  450
# [Processing] ith =  451
# [Processing] ith =  452
# [Processing] ith =  453
# [Processing] ith =  454
# [Processing] ith =  455
# [Processing] ith =  456
# [Processing] ith =  457
# [Processing] ith =  458
# [Processing] ith =  459
# [Processing] ith =  460
# [Processing] ith =  461
# [Processing] ith =  462
# [Processing] ith =  463
# [Processing] ith =  464
# [Processing] ith =  465
# [Processing] ith =  466
# [Processing] ith =  467
# [Processing] ith =  468
# [Processing] ith =  469
# [Processing] ith =  470
# [Processing] ith =  471
# [Processing] ith =  472
# [Processing] ith =  473
# [Processing] ith =  474
# [Processing] ith =  475
# [Processing] ith =  476
# [Processing] ith =  477
# [Processing] ith =  478
# [Processing] ith =  479
# [Processing] ith =  480
# [Processing] ith =  481
# [Processing] ith =  482
# [Processing] ith =  483
# [Processing] ith =  484
# [Processing] ith =  485
# [Processing] ith =  486
# [Processing] ith =  487
# [Processing] ith =  488
# [Processing] ith =  489
# [Processing] ith =  490
# [Processing] ith =  491
# [Processing] ith =  492
# [Processing] ith =  493
# [Processing] ith =  494
# [Processing] ith =  495
# [Processing] ith =  496
# [Processing] ith =  497
# [Processing] ith =  498
# [Processing] ith =  499
# [Processing] ith =  500
# [Processing] ith =  501
# [Processing] ith =  502
# [Processing] ith =  503
# [Processing] ith =  504
# [Processing] ith =  505
# [Processing] ith =  506
# [Processing] ith =  507
# [Processing] ith =  508
# [Processing] ith =  509
# [Processing] ith =  510
# [Processing] ith =  511
# [Processing] ith =  512
# [Processing] ith =  513
# [Processing] ith =  514
# [Processing] ith =  515
# [Processing] ith =  516
# [Processing] ith =  517
# [Processing] ith =  518
# [Processing] ith =  519
# [Processing] ith =  520
# [Processing] ith =  521
# [Processing] ith =  522
# [Processing] ith =  523
# [Processing] ith =  524
# [Processing] ith =  525
# [Processing] ith =  526
# [Processing] ith =  527
# [Processing] ith =  528
# [Processing] ith =  529
# [Processing] ith =  530
# [Processing] ith =  531
# [Processing] ith =  532
# [Processing] ith =  533
# [Processing] ith =  534
# [Processing] ith =  535
# [Processing] ith =  536
# [Processing] ith =  537
# [Processing] ith =  538
# [Processing] ith =  539
# [Processing] ith =  540
# [Processing] ith =  541
# [Processing] ith =  542
# [Processing] ith =  543
# [Processing] ith =  544
# [Processing] ith =  545
# [Processing] ith =  546
# [Processing] ith =  547
# [Processing] ith =  548
# [Processing] ith =  549
# [Processing] ith =  550
# [Processing] ith =  551
# [Processing] ith =  552
# [Processing] ith =  553
# [Processing] ith =  554
# [Processing] ith =  555
# [Processing] ith =  556
# [Processing] ith =  557
# [Processing] ith =  558
# [Processing] ith =  559
# [Processing] ith =  560
# [Processing] ith =  561
# [Processing] ith =  562
# [Processing] ith =  563
# [Processing] ith =  564
# [Processing] ith =  565
# [Processing] ith =  566
# [Processing] ith =  567
# [Processing] ith =  568
# [Processing] ith =  569
# [Processing] ith =  570
# [Processing] ith =  571
# [Processing] ith =  572
# [Processing] ith =  573
# [Processing] ith =  574
# [Processing] ith =  575
# [Processing] ith =  576
# [Processing] ith =  577
# [Processing] ith =  578
# [Processing] ith =  579
# [Processing] ith =  580
# [Processing] ith =  581
# [Processing] ith =  582
# [Processing] ith =  583
# [Processing] ith =  584
# [Processing] ith =  585
# [Processing] ith =  586
# [Processing] ith =  587
# [Processing] ith =  588
# [Processing] ith =  589
# [Processing] ith =  590
# [Processing] ith =  591
# [Processing] ith =  592
# [Processing] ith =  593
# [Processing] ith =  594
# [Processing] ith =  595
# [Processing] ith =  596
# [Processing] ith =  597
# [Processing] ith =  598
# [Processing] ith =  599
# [Processing] ith =  600
# [Processing] ith =  601
# [Processing] ith =  602
# [Processing] ith =  603
# [Processing] ith =  604
# [Processing] ith =  605
# [Processing] ith =  606
# [Processing] ith =  607
# [Processing] ith =  608
# [Processing] ith =  609
# [Processing] ith =  610
# [Processing] ith =  611
# [Processing] ith =  612
# [Processing] ith =  613
# [Processing] ith =  614
# [Processing] ith =  615
# [Processing] ith =  616
# [Processing] ith =  617
# [Processing] ith =  618
# [Processing] ith =  619
# [Processing] ith =  620
# [Processing] ith =  621
# [Processing] ith =  622
# [Processing] ith =  623
# [Processing] ith =  624
# [Processing] ith =  625
# [Processing] ith =  626
# [Processing] ith =  627
# [Processing] ith =  628
# [Processing] ith =  629
# [Processing] ith =  630
# [Processing] ith =  631
# [Processing] ith =  632
# [Processing] ith =  633
# [Processing] ith =  634
# [Processing] ith =  635
# [Processing] ith =  636
# [Processing] ith =  637
# [Processing] ith =  638
# [Processing] ith =  639
# [Processing] ith =  640
# [Processing] ith =  641
# [Processing] ith =  642
# [Processing] ith =  643
# [Processing] ith =  644
# [Processing] ith =  645
# [Processing] ith =  646
# [Processing] ith =  647
# [Processing] ith =  648
# [Processing] ith =  649
# [Processing] ith =  650
# [Processing] ith =  651
# [Processing] ith =  652
# [Processing] ith =  653
# [Processing] ith =  654
# [Processing] ith =  655
# [Processing] ith =  656
# [Processing] ith =  657
# [Processing] ith =  658
# [Processing] ith =  659
# [Processing] ith =  660
# [Processing] ith =  661
# [Processing] ith =  662
# [Processing] ith =  663
# [Processing] ith =  664
# [Processing] ith =  665
# [Processing] ith =  666
# [Processing] ith =  667
# [Processing] ith =  668
# [Processing] ith =  669
# [Processing] ith =  670
# [Processing] ith =  671
# [Processing] ith =  672
# [Processing] ith =  673
# [Processing] ith =  674
# [Processing] ith =  675
# [Processing] ith =  676
# [Processing] ith =  677
# [Processing] ith =  678
# [Processing] ith =  679
# [Processing] ith =  680
# [Processing] ith =  681
# [Processing] ith =  682
# [Processing] ith =  683
# [Processing] ith =  684
# [Processing] ith =  685
# [Processing] ith =  686
# [Processing] ith =  687
# [Processing] ith =  688
# [Processing] ith =  689
# [Processing] ith =  690
# [Processing] ith =  691
# [Processing] ith =  692
# [Processing] ith =  693
# [Processing] ith =  694
# [Processing] ith =  695
# [Processing] ith =  696
# [Processing] ith =  697
# [Processing] ith =  698
# [Processing] ith =  699
# [Processing] ith =  700
# [Processing] ith =  701
# [Processing] ith =  702
# [Processing] ith =  703
# [Processing] ith =  704
# [Processing] ith =  705
# [Processing] ith =  706
# [Processing] ith =  707
# [Processing] ith =  708
# [Processing] ith =  709
# [Processing] ith =  710
# [Processing] ith =  711
# [Processing] ith =  712
# [Processing] ith =  713
# [Processing] ith =  714
# [Processing] ith =  715
# [Processing] ith =  716
# [Processing] ith =  717
# [Processing] ith =  718
# [Processing] ith =  719
# [Processing] ith =  720
# [Processing] ith =  721
# [Processing] ith =  722
# [Processing] ith =  723
# [Processing] ith =  724
# [Processing] ith =  725
# [Processing] ith =  726
# [Processing] ith =  727
# [Processing] ith =  728
# [Processing] ith =  729
# [Processing] ith =  730
# [Processing] ith =  731
# [Processing] ith =  732
# [Processing] ith =  733
# [Processing] ith =  734
# [Processing] ith =  735
# [Processing] ith =  736
# [Processing] ith =  737
# [Processing] ith =  738
# [Processing] ith =  739
# [Processing] ith =  740
# [Processing] ith =  741
# [Processing] ith =  742
# [Processing] ith =  743
# [Processing] ith =  744
# [Processing] ith =  745
# [Processing] ith =  746
# [Processing] ith =  747
# [Processing] ith =  748
# [Processing] ith =  749
# [Processing] ith =  750
# [Processing] ith =  751
# [Processing] ith =  752
# [Processing] ith =  753
# [Processing] ith =  754
# [Processing] ith =  755
# [Processing] ith =  756
# [Processing] ith =  757
# [Processing] ith =  758
# [Processing] ith =  759
# [Processing] ith =  760
# [Processing] ith =  761
# [Processing] ith =  762
# [Processing] ith =  763
# [Processing] ith =  764
# [Processing] ith =  765
# [Processing] ith =  766
# [Processing] ith =  767
# [Processing] ith =  768
# [Processing] ith =  769
# [Processing] ith =  770
# [Processing] ith =  771
# [Processing] ith =  772
# [Processing] ith =  773
# [Processing] ith =  774
# [Processing] ith =  775
# [Processing] ith =  776
# [Processing] ith =  777
# [Processing] ith =  778
# [Processing] ith =  779
# [Processing] ith =  780
# [Processing] ith =  781
# [Processing] ith =  782
# [Processing] ith =  783
# [Processing] ith =  784
# [Processing] ith =  785
# [Processing] ith =  786
# [Processing] ith =  787
# [Processing] ith =  788
# [Processing] ith =  789
# [Processing] ith =  790
# [Processing] ith =  791
# [Processing] ith =  792
# [Processing] ith =  793
# [Processing] ith =  794
# [Processing] ith =  795
# [Processing] ith =  796
# [Processing] ith =  797
# [Processing] ith =  798
# [Processing] ith =  799
# [Processing] ith =  800
# [Processing] ith =  801
# [Processing] ith =  802
# [Processing] ith =  803
# [Processing] ith =  804
# [Processing] ith =  805
# [Processing] ith =  806
# [Processing] ith =  807
# [Processing] ith =  808
# [Processing] ith =  809
# [Processing] ith =  810
# [Processing] ith =  811
# [Processing] ith =  812
# [Processing] ith =  813
# [Processing] ith =  814
# [Processing] ith =  815
# [Processing] ith =  816
# [Processing] ith =  817
# [Processing] ith =  818
# [Processing] ith =  819
# [Processing] ith =  820
# [Processing] ith =  821
# [Processing] ith =  822
# [Processing] ith =  823
# [Processing] ith =  824
# [Processing] ith =  825
# [Processing] ith =  826
# [Processing] ith =  827
# [Processing] ith =  828
# [Processing] ith =  829
# [Processing] ith =  830
# [Processing] ith =  831
# [Processing] ith =  832
# [Processing] ith =  833
# [Processing] ith =  834
# [Processing] ith =  835
# [Processing] ith =  836
# [Processing] ith =  837
# [Processing] ith =  838
# [Processing] ith =  839
# [Processing] ith =  840
# [Processing] ith =  841
# [Processing] ith =  842
# [Processing] ith =  843
# [Processing] ith =  844
# [Processing] ith =  845
# [Processing] ith =  846
# [Processing] ith =  847
# [Processing] ith =  848
# [Processing] ith =  849
# [Processing] ith =  850
# [Processing] ith =  851
# [Processing] ith =  852
# [Processing] ith =  853
# [Processing] ith =  854
# [Processing] ith =  855
# [Processing] ith =  856
# [Processing] ith =  857
# [Processing] ith =  858
# [Processing] ith =  859
# [Processing] ith =  860
# [Processing] ith =  861
# [Processing] ith =  862
# [Processing] ith =  863
# [Processing] ith =  864
# [Processing] ith =  865
# [Processing] ith =  866
# [Processing] ith =  867
# [Processing] ith =  868
# [Processing] ith =  869
# [Processing] ith =  870
# [Processing] ith =  871
# [Processing] ith =  872
# [Processing] ith =  873
# [Processing] ith =  874
# [Processing] ith =  875
# [Processing] ith =  876
# [Processing] ith =  877
# [Processing] ith =  878
# [Processing] ith =  879
# [Processing] ith =  880
# [Processing] ith =  881
# [Processing] ith =  882
# [Processing] ith =  883
# [Processing] ith =  884
# [Processing] ith =  885
# [Processing] ith =  886
# [Processing] ith =  887
# [Processing] ith =  888
# [Processing] ith =  889
# [Processing] ith =  890
# [Processing] ith =  891
# [Processing] ith =  892
# [Processing] ith =  893
# [Processing] ith =  894
# [Processing] ith =  895
# [Processing] ith =  896
# [Processing] ith =  897
# [Processing] ith =  898
# [Processing] ith =  899
# [Processing] ith =  900
# [Processing] ith =  901
# [Processing] ith =  902
# [Processing] ith =  903
# [Processing] ith =  904
# [Processing] ith =  905
# [Processing] ith =  906
# [Processing] ith =  907
# [Processing] ith =  908
# [Processing] ith =  909
# [Processing] ith =  910
# [Processing] ith =  911
# [Processing] ith =  912
# [Processing] ith =  913
# [Processing] ith =  914
# [Processing] ith =  915
# [Processing] ith =  916
# [Processing] ith =  917
# [Processing] ith =  918
# [Processing] ith =  919
# [Processing] ith =  920
# [Processing] ith =  921
# [Processing] ith =  922
# [Processing] ith =  923
# [Processing] ith =  924
# [Processing] ith =  925
# [Processing] ith =  926
# [Processing] ith =  927
# [Processing] ith =  928
# [Processing] ith =  929
# [Processing] ith =  930
# [Processing] ith =  931
# [Processing] ith =  932
# [Processing] ith =  933
# [Processing] ith =  934
# [Processing] ith =  935
# [Processing] ith =  936
# [Processing] ith =  937
# [Processing] ith =  938
# [Processing] ith =  939
# [Processing] ith =  940
# [Processing] ith =  941
# [Processing] ith =  942
# [Processing] ith =  943
# [Processing] ith =  944
# [Processing] ith =  945
# [Processing] ith =  946
# [Processing] ith =  947
# [Processing] ith =  948
# [Processing] ith =  949
# [Processing] ith =  950
# [Processing] ith =  951
# [Processing] ith =  952
# [Processing] ith =  953
# [Processing] ith =  954
# [Processing] ith =  955
# [Processing] ith =  956
# [Processing] ith =  957
# [Processing] ith =  958
# [Processing] ith =  959
# [Processing] ith =  960
# [Processing] ith =  961
# [Processing] ith =  962
# [Processing] ith =  963
# [Processing] ith =  964
# [Processing] ith =  965
# [Processing] ith =  966
# [Processing] ith =  967
# [Processing] ith =  968
# [Processing] ith =  969
# [Processing] ith =  970
# [Processing] ith =  971
# [Processing] ith =  972
# [Processing] ith =  973
# [Processing] ith =  974
# [Processing] ith =  975
# [Processing] ith =  976
# [Processing] ith =  977
# [Processing] ith =  978
# [Processing] ith =  979
# [Processing] ith =  980
# [Processing] ith =  981
# [Processing] ith =  982
# [Processing] ith =  983
# [Processing] ith =  984
# [Processing] ith =  985
# [Processing] ith =  986
# [Processing] ith =  987
# [Processing] ith =  988
# [Processing] ith =  989
# [Processing] ith =  990
# [Processing] ith =  991
# [Processing] ith =  992
# [Processing] ith =  993
# [Processing] ith =  994
# [Processing] ith =  995
# [Processing] ith =  996
# [Processing] ith =  997
# [Processing] ith =  998
# [Processing] ith =  999

# %%
# sub-DLA
freq = 20

plot_log_nhis = np.sin(np.linspace(-freq * np.pi, freq * np.pi, num_bins)) * 0.5 + 19.8


for i, log_nhi in enumerate(plot_log_nhis):
    print("[Processing] ith = ", i)
    fig = make_gp_plot(
        z_dlas=[2.7356542745587893], log_nhis=[log_nhi], data=False, color="#B58DB6"
    )

    fig.savefig(
        "gp_animation/subdla_model/ver2/dla_{}.png".format(str(i).zfill(4)),
        dpi=100,
        # transparent=True,
    )
    plt.close()
    plt.clf()
# Out:
# [Processing] ith =  0
# [Processing] ith =  1
# [Processing] ith =  2
# [Processing] ith =  3
# [Processing] ith =  4
# [Processing] ith =  5
# [Processing] ith =  6
# [Processing] ith =  7
# [Processing] ith =  8
# [Processing] ith =  9
# [Processing] ith =  10
# [Processing] ith =  11
# [Processing] ith =  12
# [Processing] ith =  13
# [Processing] ith =  14
# [Processing] ith =  15
# [Processing] ith =  16
# [Processing] ith =  17
# [Processing] ith =  18
# [Processing] ith =  19
# [Processing] ith =  20
# [Processing] ith =  21
# [Processing] ith =  22
# [Processing] ith =  23
# [Processing] ith =  24
# [Processing] ith =  25
# [Processing] ith =  26
# [Processing] ith =  27
# [Processing] ith =  28
# [Processing] ith =  29
# [Processing] ith =  30
# [Processing] ith =  31
# [Processing] ith =  32
# [Processing] ith =  33
# [Processing] ith =  34
# [Processing] ith =  35
# [Processing] ith =  36
# [Processing] ith =  37
# [Processing] ith =  38
# [Processing] ith =  39
# [Processing] ith =  40
# [Processing] ith =  41
# [Processing] ith =  42
# [Processing] ith =  43
# [Processing] ith =  44
# [Processing] ith =  45
# [Processing] ith =  46
# [Processing] ith =  47
# [Processing] ith =  48
# [Processing] ith =  49
# [Processing] ith =  50
# [Processing] ith =  51
# [Processing] ith =  52
# [Processing] ith =  53
# [Processing] ith =  54
# [Processing] ith =  55
# [Processing] ith =  56
# [Processing] ith =  57
# [Processing] ith =  58
# [Processing] ith =  59
# [Processing] ith =  60
# [Processing] ith =  61
# [Processing] ith =  62
# [Processing] ith =  63
# [Processing] ith =  64
# [Processing] ith =  65
# [Processing] ith =  66
# [Processing] ith =  67
# [Processing] ith =  68
# [Processing] ith =  69
# [Processing] ith =  70
# [Processing] ith =  71
# [Processing] ith =  72
# [Processing] ith =  73
# [Processing] ith =  74
# [Processing] ith =  75
# [Processing] ith =  76
# [Processing] ith =  77
# [Processing] ith =  78
# [Processing] ith =  79
# [Processing] ith =  80
# [Processing] ith =  81
# [Processing] ith =  82
# [Processing] ith =  83
# [Processing] ith =  84
# [Processing] ith =  85
# [Processing] ith =  86
# [Processing] ith =  87
# [Processing] ith =  88
# [Processing] ith =  89
# [Processing] ith =  90
# [Processing] ith =  91
# [Processing] ith =  92
# [Processing] ith =  93
# [Processing] ith =  94
# [Processing] ith =  95
# [Processing] ith =  96
# [Processing] ith =  97
# [Processing] ith =  98
# [Processing] ith =  99
# [Processing] ith =  100
# [Processing] ith =  101
# [Processing] ith =  102
# [Processing] ith =  103
# [Processing] ith =  104
# [Processing] ith =  105
# [Processing] ith =  106
# [Processing] ith =  107
# [Processing] ith =  108
# [Processing] ith =  109
# [Processing] ith =  110
# [Processing] ith =  111
# [Processing] ith =  112
# [Processing] ith =  113
# [Processing] ith =  114
# [Processing] ith =  115
# [Processing] ith =  116
# [Processing] ith =  117
# [Processing] ith =  118
# [Processing] ith =  119
# [Processing] ith =  120
# [Processing] ith =  121
# [Processing] ith =  122
# [Processing] ith =  123
# [Processing] ith =  124
# [Processing] ith =  125
# [Processing] ith =  126
# [Processing] ith =  127
# [Processing] ith =  128
# [Processing] ith =  129
# [Processing] ith =  130
# [Processing] ith =  131
# [Processing] ith =  132
# [Processing] ith =  133
# [Processing] ith =  134
# [Processing] ith =  135
# [Processing] ith =  136
# [Processing] ith =  137
# [Processing] ith =  138
# [Processing] ith =  139
# [Processing] ith =  140
# [Processing] ith =  141
# [Processing] ith =  142
# [Processing] ith =  143
# [Processing] ith =  144
# [Processing] ith =  145
# [Processing] ith =  146
# [Processing] ith =  147
# [Processing] ith =  148
# [Processing] ith =  149
# [Processing] ith =  150
# [Processing] ith =  151
# [Processing] ith =  152
# [Processing] ith =  153
# [Processing] ith =  154
# [Processing] ith =  155
# [Processing] ith =  156
# [Processing] ith =  157
# [Processing] ith =  158
# [Processing] ith =  159
# [Processing] ith =  160
# [Processing] ith =  161
# [Processing] ith =  162
# [Processing] ith =  163
# [Processing] ith =  164
# [Processing] ith =  165
# [Processing] ith =  166
# [Processing] ith =  167
# [Processing] ith =  168
# [Processing] ith =  169
# [Processing] ith =  170
# [Processing] ith =  171
# [Processing] ith =  172
# [Processing] ith =  173
# [Processing] ith =  174
# [Processing] ith =  175
# [Processing] ith =  176
# [Processing] ith =  177
# [Processing] ith =  178
# [Processing] ith =  179
# [Processing] ith =  180
# [Processing] ith =  181
# [Processing] ith =  182
# [Processing] ith =  183
# [Processing] ith =  184
# [Processing] ith =  185
# [Processing] ith =  186
# [Processing] ith =  187
# [Processing] ith =  188
# [Processing] ith =  189
# [Processing] ith =  190
# [Processing] ith =  191
# [Processing] ith =  192
# [Processing] ith =  193
# [Processing] ith =  194
# [Processing] ith =  195
# [Processing] ith =  196
# [Processing] ith =  197
# [Processing] ith =  198
# [Processing] ith =  199
# [Processing] ith =  200
# [Processing] ith =  201
# [Processing] ith =  202
# [Processing] ith =  203
# [Processing] ith =  204
# [Processing] ith =  205
# [Processing] ith =  206
# [Processing] ith =  207
# [Processing] ith =  208
# [Processing] ith =  209
# [Processing] ith =  210
# [Processing] ith =  211
# [Processing] ith =  212
# [Processing] ith =  213
# [Processing] ith =  214
# [Processing] ith =  215
# [Processing] ith =  216
# [Processing] ith =  217
# [Processing] ith =  218
# [Processing] ith =  219
# [Processing] ith =  220
# [Processing] ith =  221
# [Processing] ith =  222
# [Processing] ith =  223
# [Processing] ith =  224
# [Processing] ith =  225
# [Processing] ith =  226
# [Processing] ith =  227
# [Processing] ith =  228
# [Processing] ith =  229
# [Processing] ith =  230
# [Processing] ith =  231
# [Processing] ith =  232
# [Processing] ith =  233
# [Processing] ith =  234
# [Processing] ith =  235
# [Processing] ith =  236
# [Processing] ith =  237
# [Processing] ith =  238
# [Processing] ith =  239
# [Processing] ith =  240
# [Processing] ith =  241
# [Processing] ith =  242
# [Processing] ith =  243
# [Processing] ith =  244
# [Processing] ith =  245
# [Processing] ith =  246
# [Processing] ith =  247
# [Processing] ith =  248
# [Processing] ith =  249
# [Processing] ith =  250
# [Processing] ith =  251
# [Processing] ith =  252
# [Processing] ith =  253
# [Processing] ith =  254
# [Processing] ith =  255
# [Processing] ith =  256
# [Processing] ith =  257
# [Processing] ith =  258
# [Processing] ith =  259
# [Processing] ith =  260
# [Processing] ith =  261
# [Processing] ith =  262
# [Processing] ith =  263
# [Processing] ith =  264
# [Processing] ith =  265
# [Processing] ith =  266
# [Processing] ith =  267
# [Processing] ith =  268
# [Processing] ith =  269
# [Processing] ith =  270
# [Processing] ith =  271
# [Processing] ith =  272
# [Processing] ith =  273
# [Processing] ith =  274
# [Processing] ith =  275
# [Processing] ith =  276
# [Processing] ith =  277
# [Processing] ith =  278
# [Processing] ith =  279
# [Processing] ith =  280
# [Processing] ith =  281
# [Processing] ith =  282
# [Processing] ith =  283
# [Processing] ith =  284
# [Processing] ith =  285
# [Processing] ith =  286
# [Processing] ith =  287
# [Processing] ith =  288
# [Processing] ith =  289
# [Processing] ith =  290
# [Processing] ith =  291
# [Processing] ith =  292
# [Processing] ith =  293
# [Processing] ith =  294
# [Processing] ith =  295
# [Processing] ith =  296
# [Processing] ith =  297
# [Processing] ith =  298
# [Processing] ith =  299
# [Processing] ith =  300
# [Processing] ith =  301
# [Processing] ith =  302
# [Processing] ith =  303
# [Processing] ith =  304
# [Processing] ith =  305
# [Processing] ith =  306
# [Processing] ith =  307
# [Processing] ith =  308
# [Processing] ith =  309
# [Processing] ith =  310
# [Processing] ith =  311
# [Processing] ith =  312
# [Processing] ith =  313
# [Processing] ith =  314
# [Processing] ith =  315
# [Processing] ith =  316
# [Processing] ith =  317
# [Processing] ith =  318
# [Processing] ith =  319
# [Processing] ith =  320
# [Processing] ith =  321
# [Processing] ith =  322
# [Processing] ith =  323
# [Processing] ith =  324
# [Processing] ith =  325
# [Processing] ith =  326
# [Processing] ith =  327
# [Processing] ith =  328
# [Processing] ith =  329
# [Processing] ith =  330
# [Processing] ith =  331
# [Processing] ith =  332
# [Processing] ith =  333
# [Processing] ith =  334
# [Processing] ith =  335
# [Processing] ith =  336
# [Processing] ith =  337
# [Processing] ith =  338
# [Processing] ith =  339
# [Processing] ith =  340
# [Processing] ith =  341
# [Processing] ith =  342
# [Processing] ith =  343
# [Processing] ith =  344
# [Processing] ith =  345
# [Processing] ith =  346
# [Processing] ith =  347
# [Processing] ith =  348
# [Processing] ith =  349
# [Processing] ith =  350
# [Processing] ith =  351
# [Processing] ith =  352
# [Processing] ith =  353
# [Processing] ith =  354
# [Processing] ith =  355
# [Processing] ith =  356
# [Processing] ith =  357
# [Processing] ith =  358
# [Processing] ith =  359
# [Processing] ith =  360
# [Processing] ith =  361
# [Processing] ith =  362
# [Processing] ith =  363
# [Processing] ith =  364
# [Processing] ith =  365
# [Processing] ith =  366
# [Processing] ith =  367
# [Processing] ith =  368
# [Processing] ith =  369
# [Processing] ith =  370
# [Processing] ith =  371
# [Processing] ith =  372
# [Processing] ith =  373
# [Processing] ith =  374
# [Processing] ith =  375
# [Processing] ith =  376
# [Processing] ith =  377
# [Processing] ith =  378
# [Processing] ith =  379
# [Processing] ith =  380
# [Processing] ith =  381
# [Processing] ith =  382
# [Processing] ith =  383
# [Processing] ith =  384
# [Processing] ith =  385
# [Processing] ith =  386
# [Processing] ith =  387
# [Processing] ith =  388
# [Processing] ith =  389
# [Processing] ith =  390
# [Processing] ith =  391
# [Processing] ith =  392
# [Processing] ith =  393
# [Processing] ith =  394
# [Processing] ith =  395
# [Processing] ith =  396
# [Processing] ith =  397
# [Processing] ith =  398
# [Processing] ith =  399
# [Processing] ith =  400
# [Processing] ith =  401
# [Processing] ith =  402
# [Processing] ith =  403
# [Processing] ith =  404
# [Processing] ith =  405
# [Processing] ith =  406
# [Processing] ith =  407
# [Processing] ith =  408
# [Processing] ith =  409
# [Processing] ith =  410
# [Processing] ith =  411
# [Processing] ith =  412
# [Processing] ith =  413
# [Processing] ith =  414
# [Processing] ith =  415
# [Processing] ith =  416
# [Processing] ith =  417
# [Processing] ith =  418
# [Processing] ith =  419
# [Processing] ith =  420
# [Processing] ith =  421
# [Processing] ith =  422
# [Processing] ith =  423
# [Processing] ith =  424
# [Processing] ith =  425
# [Processing] ith =  426
# [Processing] ith =  427
# [Processing] ith =  428
# [Processing] ith =  429
# [Processing] ith =  430
# [Processing] ith =  431
# [Processing] ith =  432
# [Processing] ith =  433
# [Processing] ith =  434
# [Processing] ith =  435
# [Processing] ith =  436
# [Processing] ith =  437
# [Processing] ith =  438
# [Processing] ith =  439
# [Processing] ith =  440
# [Processing] ith =  441
# [Processing] ith =  442
# [Processing] ith =  443
# [Processing] ith =  444
# [Processing] ith =  445
# [Processing] ith =  446
# [Processing] ith =  447
# [Processing] ith =  448
# [Processing] ith =  449
# [Processing] ith =  450
# [Processing] ith =  451
# [Processing] ith =  452
# [Processing] ith =  453
# [Processing] ith =  454
# [Processing] ith =  455
# [Processing] ith =  456
# [Processing] ith =  457
# [Processing] ith =  458
# [Processing] ith =  459
# [Processing] ith =  460
# [Processing] ith =  461
# [Processing] ith =  462
# [Processing] ith =  463
# [Processing] ith =  464
# [Processing] ith =  465
# [Processing] ith =  466
# [Processing] ith =  467
# [Processing] ith =  468
# [Processing] ith =  469
# [Processing] ith =  470
# [Processing] ith =  471
# [Processing] ith =  472
# [Processing] ith =  473
# [Processing] ith =  474
# [Processing] ith =  475
# [Processing] ith =  476
# [Processing] ith =  477
# [Processing] ith =  478
# [Processing] ith =  479
# [Processing] ith =  480
# [Processing] ith =  481
# [Processing] ith =  482
# [Processing] ith =  483
# [Processing] ith =  484
# [Processing] ith =  485
# [Processing] ith =  486
# [Processing] ith =  487
# [Processing] ith =  488
# [Processing] ith =  489
# [Processing] ith =  490
# [Processing] ith =  491
# [Processing] ith =  492
# [Processing] ith =  493
# [Processing] ith =  494
# [Processing] ith =  495
# [Processing] ith =  496
# [Processing] ith =  497
# [Processing] ith =  498
# [Processing] ith =  499
# [Processing] ith =  500
# [Processing] ith =  501
# [Processing] ith =  502
# [Processing] ith =  503
# [Processing] ith =  504
# [Processing] ith =  505
# [Processing] ith =  506
# [Processing] ith =  507
# [Processing] ith =  508
# [Processing] ith =  509
# [Processing] ith =  510
# [Processing] ith =  511
# [Processing] ith =  512
# [Processing] ith =  513
# [Processing] ith =  514
# [Processing] ith =  515
# [Processing] ith =  516
# [Processing] ith =  517
# [Processing] ith =  518
# [Processing] ith =  519
# [Processing] ith =  520
# [Processing] ith =  521
# [Processing] ith =  522
# [Processing] ith =  523
# [Processing] ith =  524
# [Processing] ith =  525
# [Processing] ith =  526
# [Processing] ith =  527
# [Processing] ith =  528
# [Processing] ith =  529
# [Processing] ith =  530
# [Processing] ith =  531
# [Processing] ith =  532
# [Processing] ith =  533
# [Processing] ith =  534
# [Processing] ith =  535
# [Processing] ith =  536
# [Processing] ith =  537
# [Processing] ith =  538
# [Processing] ith =  539
# [Processing] ith =  540
# [Processing] ith =  541
# [Processing] ith =  542
# [Processing] ith =  543
# [Processing] ith =  544
# [Processing] ith =  545
# [Processing] ith =  546
# [Processing] ith =  547
# [Processing] ith =  548
# [Processing] ith =  549
# [Processing] ith =  550
# [Processing] ith =  551
# [Processing] ith =  552
# [Processing] ith =  553
# [Processing] ith =  554
# [Processing] ith =  555
# [Processing] ith =  556
# [Processing] ith =  557
# [Processing] ith =  558
# [Processing] ith =  559
# [Processing] ith =  560
# [Processing] ith =  561
# [Processing] ith =  562
# [Processing] ith =  563
# [Processing] ith =  564
# [Processing] ith =  565
# [Processing] ith =  566
# [Processing] ith =  567
# [Processing] ith =  568
# [Processing] ith =  569
# [Processing] ith =  570
# [Processing] ith =  571
# [Processing] ith =  572
# [Processing] ith =  573
# [Processing] ith =  574
# [Processing] ith =  575
# [Processing] ith =  576
# [Processing] ith =  577
# [Processing] ith =  578
# [Processing] ith =  579
# [Processing] ith =  580
# [Processing] ith =  581
# [Processing] ith =  582
# [Processing] ith =  583
# [Processing] ith =  584
# [Processing] ith =  585
# [Processing] ith =  586
# [Processing] ith =  587
# [Processing] ith =  588
# [Processing] ith =  589
# [Processing] ith =  590
# [Processing] ith =  591
# [Processing] ith =  592
# [Processing] ith =  593
# [Processing] ith =  594
# [Processing] ith =  595
# [Processing] ith =  596
# [Processing] ith =  597
# [Processing] ith =  598
# [Processing] ith =  599
# [Processing] ith =  600
# [Processing] ith =  601
# [Processing] ith =  602
# [Processing] ith =  603
# [Processing] ith =  604
# [Processing] ith =  605
# [Processing] ith =  606
# [Processing] ith =  607
# [Processing] ith =  608
# [Processing] ith =  609
# [Processing] ith =  610
# [Processing] ith =  611
# [Processing] ith =  612
# [Processing] ith =  613
# [Processing] ith =  614
# [Processing] ith =  615
# [Processing] ith =  616
# [Processing] ith =  617
# [Processing] ith =  618
# [Processing] ith =  619
# [Processing] ith =  620
# [Processing] ith =  621
# [Processing] ith =  622
# [Processing] ith =  623
# [Processing] ith =  624
# [Processing] ith =  625
# [Processing] ith =  626
# [Processing] ith =  627
# [Processing] ith =  628
# [Processing] ith =  629
# [Processing] ith =  630
# [Processing] ith =  631
# [Processing] ith =  632
# [Processing] ith =  633
# [Processing] ith =  634
# [Processing] ith =  635
# [Processing] ith =  636
# [Processing] ith =  637
# [Processing] ith =  638
# [Processing] ith =  639
# [Processing] ith =  640
# [Processing] ith =  641
# [Processing] ith =  642
# [Processing] ith =  643
# [Processing] ith =  644
# [Processing] ith =  645
# [Processing] ith =  646
# [Processing] ith =  647
# [Processing] ith =  648
# [Processing] ith =  649
# [Processing] ith =  650
# [Processing] ith =  651
# [Processing] ith =  652
# [Processing] ith =  653
# [Processing] ith =  654
# [Processing] ith =  655
# [Processing] ith =  656
# [Processing] ith =  657
# [Processing] ith =  658
# [Processing] ith =  659
# [Processing] ith =  660
# [Processing] ith =  661
# [Processing] ith =  662
# [Processing] ith =  663
# [Processing] ith =  664
# [Processing] ith =  665
# [Processing] ith =  666
# [Processing] ith =  667
# [Processing] ith =  668
# [Processing] ith =  669
# [Processing] ith =  670
# [Processing] ith =  671
# [Processing] ith =  672
# [Processing] ith =  673
# [Processing] ith =  674
# [Processing] ith =  675
# [Processing] ith =  676
# [Processing] ith =  677
# [Processing] ith =  678
# [Processing] ith =  679
# [Processing] ith =  680
# [Processing] ith =  681
# [Processing] ith =  682
# [Processing] ith =  683
# [Processing] ith =  684
# [Processing] ith =  685
# [Processing] ith =  686
# [Processing] ith =  687
# [Processing] ith =  688
# [Processing] ith =  689
# [Processing] ith =  690
# [Processing] ith =  691
# [Processing] ith =  692
# [Processing] ith =  693
# [Processing] ith =  694
# [Processing] ith =  695
# [Processing] ith =  696
# [Processing] ith =  697
# [Processing] ith =  698
# [Processing] ith =  699
# [Processing] ith =  700
# [Processing] ith =  701
# [Processing] ith =  702
# [Processing] ith =  703
# [Processing] ith =  704
# [Processing] ith =  705
# [Processing] ith =  706
# [Processing] ith =  707
# [Processing] ith =  708
# [Processing] ith =  709
# [Processing] ith =  710
# [Processing] ith =  711
# [Processing] ith =  712
# [Processing] ith =  713
# [Processing] ith =  714
# [Processing] ith =  715
# [Processing] ith =  716
# [Processing] ith =  717
# [Processing] ith =  718
# [Processing] ith =  719
# [Processing] ith =  720
# [Processing] ith =  721
# [Processing] ith =  722
# [Processing] ith =  723
# [Processing] ith =  724
# [Processing] ith =  725
# [Processing] ith =  726
# [Processing] ith =  727
# [Processing] ith =  728
# [Processing] ith =  729
# [Processing] ith =  730
# [Processing] ith =  731
# [Processing] ith =  732
# [Processing] ith =  733
# [Processing] ith =  734
# [Processing] ith =  735
# [Processing] ith =  736
# [Processing] ith =  737
# [Processing] ith =  738
# [Processing] ith =  739
# [Processing] ith =  740
# [Processing] ith =  741
# [Processing] ith =  742
# [Processing] ith =  743
# [Processing] ith =  744
# [Processing] ith =  745
# [Processing] ith =  746
# [Processing] ith =  747
# [Processing] ith =  748
# [Processing] ith =  749
# [Processing] ith =  750
# [Processing] ith =  751
# [Processing] ith =  752
# [Processing] ith =  753
# [Processing] ith =  754
# [Processing] ith =  755
# [Processing] ith =  756
# [Processing] ith =  757
# [Processing] ith =  758
# [Processing] ith =  759
# [Processing] ith =  760
# [Processing] ith =  761
# [Processing] ith =  762
# [Processing] ith =  763
# [Processing] ith =  764
# [Processing] ith =  765
# [Processing] ith =  766
# [Processing] ith =  767
# [Processing] ith =  768
# [Processing] ith =  769
# [Processing] ith =  770
# [Processing] ith =  771
# [Processing] ith =  772
# [Processing] ith =  773
# [Processing] ith =  774
# [Processing] ith =  775
# [Processing] ith =  776
# [Processing] ith =  777
# [Processing] ith =  778
# [Processing] ith =  779
# [Processing] ith =  780
# [Processing] ith =  781
# [Processing] ith =  782
# [Processing] ith =  783
# [Processing] ith =  784
# [Processing] ith =  785
# [Processing] ith =  786
# [Processing] ith =  787
# [Processing] ith =  788
# [Processing] ith =  789
# [Processing] ith =  790
# [Processing] ith =  791
# [Processing] ith =  792
# [Processing] ith =  793
# [Processing] ith =  794
# [Processing] ith =  795
# [Processing] ith =  796
# [Processing] ith =  797
# [Processing] ith =  798
# [Processing] ith =  799
# [Processing] ith =  800
# [Processing] ith =  801
# [Processing] ith =  802
# [Processing] ith =  803
# [Processing] ith =  804
# [Processing] ith =  805
# [Processing] ith =  806
# [Processing] ith =  807
# [Processing] ith =  808
# [Processing] ith =  809
# [Processing] ith =  810
# [Processing] ith =  811
# [Processing] ith =  812
# [Processing] ith =  813
# [Processing] ith =  814
# [Processing] ith =  815
# [Processing] ith =  816
# [Processing] ith =  817
# [Processing] ith =  818
# [Processing] ith =  819
# [Processing] ith =  820
# [Processing] ith =  821
# [Processing] ith =  822
# [Processing] ith =  823
# [Processing] ith =  824
# [Processing] ith =  825
# [Processing] ith =  826
# [Processing] ith =  827
# [Processing] ith =  828
# [Processing] ith =  829
# [Processing] ith =  830
# [Processing] ith =  831
# [Processing] ith =  832
# [Processing] ith =  833
# [Processing] ith =  834
# [Processing] ith =  835
# [Processing] ith =  836
# [Processing] ith =  837
# [Processing] ith =  838
# [Processing] ith =  839
# [Processing] ith =  840
# [Processing] ith =  841
# [Processing] ith =  842
# [Processing] ith =  843
# [Processing] ith =  844
# [Processing] ith =  845
# [Processing] ith =  846
# [Processing] ith =  847
# [Processing] ith =  848
# [Processing] ith =  849
# [Processing] ith =  850
# [Processing] ith =  851
# [Processing] ith =  852
# [Processing] ith =  853
# [Processing] ith =  854
# [Processing] ith =  855
# [Processing] ith =  856
# [Processing] ith =  857
# [Processing] ith =  858
# [Processing] ith =  859
# [Processing] ith =  860
# [Processing] ith =  861
# [Processing] ith =  862
# [Processing] ith =  863
# [Processing] ith =  864
# [Processing] ith =  865
# [Processing] ith =  866
# [Processing] ith =  867
# [Processing] ith =  868
# [Processing] ith =  869
# [Processing] ith =  870
# [Processing] ith =  871
# [Processing] ith =  872
# [Processing] ith =  873
# [Processing] ith =  874
# [Processing] ith =  875
# [Processing] ith =  876
# [Processing] ith =  877
# [Processing] ith =  878
# [Processing] ith =  879
# [Processing] ith =  880
# [Processing] ith =  881
# [Processing] ith =  882
# [Processing] ith =  883
# [Processing] ith =  884
# [Processing] ith =  885
# [Processing] ith =  886
# [Processing] ith =  887
# [Processing] ith =  888
# [Processing] ith =  889
# [Processing] ith =  890
# [Processing] ith =  891
# [Processing] ith =  892
# [Processing] ith =  893
# [Processing] ith =  894
# [Processing] ith =  895
# [Processing] ith =  896
# [Processing] ith =  897
# [Processing] ith =  898
# [Processing] ith =  899
# [Processing] ith =  900
# [Processing] ith =  901
# [Processing] ith =  902
# [Processing] ith =  903
# [Processing] ith =  904
# [Processing] ith =  905
# [Processing] ith =  906
# [Processing] ith =  907
# [Processing] ith =  908
# [Processing] ith =  909
# [Processing] ith =  910
# [Processing] ith =  911
# [Processing] ith =  912
# [Processing] ith =  913
# [Processing] ith =  914
# [Processing] ith =  915
# [Processing] ith =  916
# [Processing] ith =  917
# [Processing] ith =  918
# [Processing] ith =  919
# [Processing] ith =  920
# [Processing] ith =  921
# [Processing] ith =  922
# [Processing] ith =  923
# [Processing] ith =  924
# [Processing] ith =  925
# [Processing] ith =  926
# [Processing] ith =  927
# [Processing] ith =  928
# [Processing] ith =  929
# [Processing] ith =  930
# [Processing] ith =  931
# [Processing] ith =  932
# [Processing] ith =  933
# [Processing] ith =  934
# [Processing] ith =  935
# [Processing] ith =  936
# [Processing] ith =  937
# [Processing] ith =  938
# [Processing] ith =  939
# [Processing] ith =  940
# [Processing] ith =  941
# [Processing] ith =  942
# [Processing] ith =  943
# [Processing] ith =  944
# [Processing] ith =  945
# [Processing] ith =  946
# [Processing] ith =  947
# [Processing] ith =  948
# [Processing] ith =  949
# [Processing] ith =  950
# [Processing] ith =  951
# [Processing] ith =  952
# [Processing] ith =  953
# [Processing] ith =  954
# [Processing] ith =  955
# [Processing] ith =  956
# [Processing] ith =  957
# [Processing] ith =  958
# [Processing] ith =  959
# [Processing] ith =  960
# [Processing] ith =  961
# [Processing] ith =  962
# [Processing] ith =  963
# [Processing] ith =  964
# [Processing] ith =  965
# [Processing] ith =  966
# [Processing] ith =  967
# [Processing] ith =  968
# [Processing] ith =  969
# [Processing] ith =  970
# [Processing] ith =  971
# [Processing] ith =  972
# [Processing] ith =  973
# [Processing] ith =  974
# [Processing] ith =  975
# [Processing] ith =  976
# [Processing] ith =  977
# [Processing] ith =  978
# [Processing] ith =  979
# [Processing] ith =  980
# [Processing] ith =  981
# [Processing] ith =  982
# [Processing] ith =  983
# [Processing] ith =  984
# [Processing] ith =  985
# [Processing] ith =  986
# [Processing] ith =  987
# [Processing] ith =  988
# [Processing] ith =  989
# [Processing] ith =  990
# [Processing] ith =  991
# [Processing] ith =  992
# [Processing] ith =  993
# [Processing] ith =  994
# [Processing] ith =  995
# [Processing] ith =  996
# [Processing] ith =  997
# [Processing] ith =  998
# [Processing] ith =  999

# %%
# LLS
freq = 20

plot_log_nhis = np.sin(np.linspace(-freq * np.pi, freq * np.pi, num_bins)) * 0.9 + 18.1


for i, log_nhi in enumerate(plot_log_nhis):
    print("[Processing] ith = ", i)
    fig = make_gp_plot(
        z_dlas=[2.7356542745587893], log_nhis=[log_nhi], data=False, color="#5FA8D3"
    )

    fig.savefig(
        "gp_animation/lls_model/lls_{}.png".format(str(i).zfill(4)),
        dpi=100,
        # transparent=True,
    )
    plt.close()
    plt.clf()
# Out:
# [Processing] ith =  0
# [Processing] ith =  1
# [Processing] ith =  2
# [Processing] ith =  3
# [Processing] ith =  4
# [Processing] ith =  5
# [Processing] ith =  6
# [Processing] ith =  7
# [Processing] ith =  8
# [Processing] ith =  9
# [Processing] ith =  10
# [Processing] ith =  11
# [Processing] ith =  12
# [Processing] ith =  13
# [Processing] ith =  14
# [Processing] ith =  15
# [Processing] ith =  16
# [Processing] ith =  17
# [Processing] ith =  18
# [Processing] ith =  19
# [Processing] ith =  20
# [Processing] ith =  21
# [Processing] ith =  22
# [Processing] ith =  23
# [Processing] ith =  24
# [Processing] ith =  25
# [Processing] ith =  26
# [Processing] ith =  27
# [Processing] ith =  28
# [Processing] ith =  29
# [Processing] ith =  30
# [Processing] ith =  31
# [Processing] ith =  32
# [Processing] ith =  33
# [Processing] ith =  34
# [Processing] ith =  35
# [Processing] ith =  36
# [Processing] ith =  37
# [Processing] ith =  38
# [Processing] ith =  39
# [Processing] ith =  40
# [Processing] ith =  41
# [Processing] ith =  42
# [Processing] ith =  43
# [Processing] ith =  44
# [Processing] ith =  45
# [Processing] ith =  46
# [Processing] ith =  47
# [Processing] ith =  48
# [Processing] ith =  49
# [Processing] ith =  50
# [Processing] ith =  51
# [Processing] ith =  52
# [Processing] ith =  53
# [Processing] ith =  54
# [Processing] ith =  55
# [Processing] ith =  56
# [Processing] ith =  57
# [Processing] ith =  58
# [Processing] ith =  59
# [Processing] ith =  60
# [Processing] ith =  61
# [Processing] ith =  62
# [Processing] ith =  63
# [Processing] ith =  64
# [Processing] ith =  65
# [Processing] ith =  66
# [Processing] ith =  67
# [Processing] ith =  68
# [Processing] ith =  69
# [Processing] ith =  70
# [Processing] ith =  71
# [Processing] ith =  72
# [Processing] ith =  73
# [Processing] ith =  74
# [Processing] ith =  75
# [Processing] ith =  76
# [Processing] ith =  77
# [Processing] ith =  78
# [Processing] ith =  79
# [Processing] ith =  80
# [Processing] ith =  81
# [Processing] ith =  82
# [Processing] ith =  83
# [Processing] ith =  84
# [Processing] ith =  85
# [Processing] ith =  86
# [Processing] ith =  87
# [Processing] ith =  88
# [Processing] ith =  89
# [Processing] ith =  90
# [Processing] ith =  91
# [Processing] ith =  92
# [Processing] ith =  93
# [Processing] ith =  94
# [Processing] ith =  95
# [Processing] ith =  96
# [Processing] ith =  97
# [Processing] ith =  98
# [Processing] ith =  99
# [Processing] ith =  100
# [Processing] ith =  101
# [Processing] ith =  102
# [Processing] ith =  103
# [Processing] ith =  104
# [Processing] ith =  105
# [Processing] ith =  106
# [Processing] ith =  107
# [Processing] ith =  108
# [Processing] ith =  109
# [Processing] ith =  110
# [Processing] ith =  111
# [Processing] ith =  112
# [Processing] ith =  113
# [Processing] ith =  114
# [Processing] ith =  115
# [Processing] ith =  116
# [Processing] ith =  117
# [Processing] ith =  118
# [Processing] ith =  119
# [Processing] ith =  120
# [Processing] ith =  121
# [Processing] ith =  122
# [Processing] ith =  123
# [Processing] ith =  124
# [Processing] ith =  125
# [Processing] ith =  126
# [Processing] ith =  127
# [Processing] ith =  128
# [Processing] ith =  129
# [Processing] ith =  130
# [Processing] ith =  131
# [Processing] ith =  132
# [Processing] ith =  133
# [Processing] ith =  134
# [Processing] ith =  135
# [Processing] ith =  136
# [Processing] ith =  137
# [Processing] ith =  138
# [Processing] ith =  139
# [Processing] ith =  140
# [Processing] ith =  141
# [Processing] ith =  142
# [Processing] ith =  143
# [Processing] ith =  144
# [Processing] ith =  145
# [Processing] ith =  146
# [Processing] ith =  147
# [Processing] ith =  148
# [Processing] ith =  149
# [Processing] ith =  150
# [Processing] ith =  151
# [Processing] ith =  152
# [Processing] ith =  153
# [Processing] ith =  154
# [Processing] ith =  155
# [Processing] ith =  156
# [Processing] ith =  157
# [Processing] ith =  158
# [Processing] ith =  159
# [Processing] ith =  160
# [Processing] ith =  161
# [Processing] ith =  162
# [Processing] ith =  163
# [Processing] ith =  164
# [Processing] ith =  165
# [Processing] ith =  166
# [Processing] ith =  167
# [Processing] ith =  168
# [Processing] ith =  169
# [Processing] ith =  170
# [Processing] ith =  171
# [Processing] ith =  172
# [Processing] ith =  173
# [Processing] ith =  174
# [Processing] ith =  175
# [Processing] ith =  176
# [Processing] ith =  177
# [Processing] ith =  178
# [Processing] ith =  179
# [Processing] ith =  180
# [Processing] ith =  181
# [Processing] ith =  182
# [Processing] ith =  183
# [Processing] ith =  184
# [Processing] ith =  185
# [Processing] ith =  186
# [Processing] ith =  187
# [Processing] ith =  188
# [Processing] ith =  189
# [Processing] ith =  190
# [Processing] ith =  191
# [Processing] ith =  192
# [Processing] ith =  193
# [Processing] ith =  194
# [Processing] ith =  195
# [Processing] ith =  196
# [Processing] ith =  197
# [Processing] ith =  198
# [Processing] ith =  199
# [Processing] ith =  200
# [Processing] ith =  201
# [Processing] ith =  202
# [Processing] ith =  203
# [Processing] ith =  204
# [Processing] ith =  205
# [Processing] ith =  206
# [Processing] ith =  207
# [Processing] ith =  208
# [Processing] ith =  209
# [Processing] ith =  210
# [Processing] ith =  211
# [Processing] ith =  212
# [Processing] ith =  213
# [Processing] ith =  214
# [Processing] ith =  215
# [Processing] ith =  216
# [Processing] ith =  217
# [Processing] ith =  218
# [Processing] ith =  219
# [Processing] ith =  220
# [Processing] ith =  221
# [Processing] ith =  222
# [Processing] ith =  223
# [Processing] ith =  224
# [Processing] ith =  225
# [Processing] ith =  226
# [Processing] ith =  227
# [Processing] ith =  228
# [Processing] ith =  229
# [Processing] ith =  230
# [Processing] ith =  231
# [Processing] ith =  232
# [Processing] ith =  233
# [Processing] ith =  234
# [Processing] ith =  235
# [Processing] ith =  236
# [Processing] ith =  237
# [Processing] ith =  238
# [Processing] ith =  239
# [Processing] ith =  240
# [Processing] ith =  241
# [Processing] ith =  242
# [Processing] ith =  243
# [Processing] ith =  244
# [Processing] ith =  245
# [Processing] ith =  246
# [Processing] ith =  247
# [Processing] ith =  248
# [Processing] ith =  249
# [Processing] ith =  250
# [Processing] ith =  251
# [Processing] ith =  252
# [Processing] ith =  253
# [Processing] ith =  254
# [Processing] ith =  255
# [Processing] ith =  256
# [Processing] ith =  257
# [Processing] ith =  258
# [Processing] ith =  259
# [Processing] ith =  260
# [Processing] ith =  261
# [Processing] ith =  262
# [Processing] ith =  263
# [Processing] ith =  264
# [Processing] ith =  265
# [Processing] ith =  266
# [Processing] ith =  267
# [Processing] ith =  268
# [Processing] ith =  269
# [Processing] ith =  270
# [Processing] ith =  271
# [Processing] ith =  272
# [Processing] ith =  273
# [Processing] ith =  274
# [Processing] ith =  275
# [Processing] ith =  276
# [Processing] ith =  277
# [Processing] ith =  278
# [Processing] ith =  279
# [Processing] ith =  280
# [Processing] ith =  281
# [Processing] ith =  282
# [Processing] ith =  283
# [Processing] ith =  284
# [Processing] ith =  285
# [Processing] ith =  286
# [Processing] ith =  287
# [Processing] ith =  288
# [Processing] ith =  289
# [Processing] ith =  290
# [Processing] ith =  291
# [Processing] ith =  292
# [Processing] ith =  293
# [Processing] ith =  294
# [Processing] ith =  295
# [Processing] ith =  296
# [Processing] ith =  297
# [Processing] ith =  298
# [Processing] ith =  299
# [Processing] ith =  300
# [Processing] ith =  301
# [Processing] ith =  302
# [Processing] ith =  303
# [Processing] ith =  304
# [Processing] ith =  305
# [Processing] ith =  306
# [Processing] ith =  307
# [Processing] ith =  308
# [Processing] ith =  309
# [Processing] ith =  310
# [Processing] ith =  311
# [Processing] ith =  312
# [Processing] ith =  313
# [Processing] ith =  314
# [Processing] ith =  315
# [Processing] ith =  316
# [Processing] ith =  317
# [Processing] ith =  318
# [Processing] ith =  319
# [Processing] ith =  320
# [Processing] ith =  321
# [Processing] ith =  322
# [Processing] ith =  323
# [Processing] ith =  324
# [Processing] ith =  325
# [Processing] ith =  326
# [Processing] ith =  327
# [Processing] ith =  328
# [Processing] ith =  329
# [Processing] ith =  330
# [Processing] ith =  331
# [Processing] ith =  332
# [Processing] ith =  333
# [Processing] ith =  334
# [Processing] ith =  335
# [Processing] ith =  336
# [Processing] ith =  337
# [Processing] ith =  338
# [Processing] ith =  339
# [Processing] ith =  340
# [Processing] ith =  341
# [Processing] ith =  342
# [Processing] ith =  343
# [Processing] ith =  344
# [Processing] ith =  345
# [Processing] ith =  346
# [Processing] ith =  347
# [Processing] ith =  348
# [Processing] ith =  349
# [Processing] ith =  350
# [Processing] ith =  351
# [Processing] ith =  352
# [Processing] ith =  353
# [Processing] ith =  354
# [Processing] ith =  355
# [Processing] ith =  356
# [Processing] ith =  357
# [Processing] ith =  358
# [Processing] ith =  359
# [Processing] ith =  360
# [Processing] ith =  361
# [Processing] ith =  362
# [Processing] ith =  363
# [Processing] ith =  364
# [Processing] ith =  365
# [Processing] ith =  366
# [Processing] ith =  367
# [Processing] ith =  368
# [Processing] ith =  369
# [Processing] ith =  370
# [Processing] ith =  371
# [Processing] ith =  372
# [Processing] ith =  373
# [Processing] ith =  374
# [Processing] ith =  375
# [Processing] ith =  376
# [Processing] ith =  377
# [Processing] ith =  378
# [Processing] ith =  379
# [Processing] ith =  380
# [Processing] ith =  381
# [Processing] ith =  382
# [Processing] ith =  383
# [Processing] ith =  384
# [Processing] ith =  385
# [Processing] ith =  386
# [Processing] ith =  387
# [Processing] ith =  388
# [Processing] ith =  389
# [Processing] ith =  390
# [Processing] ith =  391
# [Processing] ith =  392
# [Processing] ith =  393
# [Processing] ith =  394
# [Processing] ith =  395
# [Processing] ith =  396
# [Processing] ith =  397
# [Processing] ith =  398
# [Processing] ith =  399
# [Processing] ith =  400
# [Processing] ith =  401
# [Processing] ith =  402
# [Processing] ith =  403
# [Processing] ith =  404
# [Processing] ith =  405
# [Processing] ith =  406
# [Processing] ith =  407
# [Processing] ith =  408
# [Processing] ith =  409
# [Processing] ith =  410
# [Processing] ith =  411
# [Processing] ith =  412
# [Processing] ith =  413
# [Processing] ith =  414
# [Processing] ith =  415
# [Processing] ith =  416
# [Processing] ith =  417
# [Processing] ith =  418
# [Processing] ith =  419
# [Processing] ith =  420
# [Processing] ith =  421
# [Processing] ith =  422
# [Processing] ith =  423
# [Processing] ith =  424
# [Processing] ith =  425
# [Processing] ith =  426
# [Processing] ith =  427
# [Processing] ith =  428
# [Processing] ith =  429
# [Processing] ith =  430
# [Processing] ith =  431
# [Processing] ith =  432
# [Processing] ith =  433
# [Processing] ith =  434
# [Processing] ith =  435
# [Processing] ith =  436
# [Processing] ith =  437
# [Processing] ith =  438
# [Processing] ith =  439
# [Processing] ith =  440
# [Processing] ith =  441
# [Processing] ith =  442
# [Processing] ith =  443
# [Processing] ith =  444
# [Processing] ith =  445
# [Processing] ith =  446
# [Processing] ith =  447
# [Processing] ith =  448
# [Processing] ith =  449
# [Processing] ith =  450
# [Processing] ith =  451
# [Processing] ith =  452
# [Processing] ith =  453
# [Processing] ith =  454
# [Processing] ith =  455
# [Processing] ith =  456
# [Processing] ith =  457
# [Processing] ith =  458
# [Processing] ith =  459
# [Processing] ith =  460
# [Processing] ith =  461
# [Processing] ith =  462
# [Processing] ith =  463
# [Processing] ith =  464
# [Processing] ith =  465
# [Processing] ith =  466
# [Processing] ith =  467
# [Processing] ith =  468
# [Processing] ith =  469
# [Processing] ith =  470
# [Processing] ith =  471
# [Processing] ith =  472
# [Processing] ith =  473
# [Processing] ith =  474
# [Processing] ith =  475
# [Processing] ith =  476
# [Processing] ith =  477
# [Processing] ith =  478
# [Processing] ith =  479
# [Processing] ith =  480
# [Processing] ith =  481
# [Processing] ith =  482
# [Processing] ith =  483
# [Processing] ith =  484
# [Processing] ith =  485
# [Processing] ith =  486
# [Processing] ith =  487
# [Processing] ith =  488
# [Processing] ith =  489
# [Processing] ith =  490
# [Processing] ith =  491
# [Processing] ith =  492
# [Processing] ith =  493
# [Processing] ith =  494
# [Processing] ith =  495
# [Processing] ith =  496
# [Processing] ith =  497
# [Processing] ith =  498
# [Processing] ith =  499
# [Processing] ith =  500
# [Processing] ith =  501
# [Processing] ith =  502
# [Processing] ith =  503
# [Processing] ith =  504
# [Processing] ith =  505
# [Processing] ith =  506
# [Processing] ith =  507
# [Processing] ith =  508
# [Processing] ith =  509
# [Processing] ith =  510
# [Processing] ith =  511
# [Processing] ith =  512
# [Processing] ith =  513
# [Processing] ith =  514
# [Processing] ith =  515
# [Processing] ith =  516
# [Processing] ith =  517
# [Processing] ith =  518
# [Processing] ith =  519
# [Processing] ith =  520
# [Processing] ith =  521
# [Processing] ith =  522
# [Processing] ith =  523
# [Processing] ith =  524
# [Processing] ith =  525
# [Processing] ith =  526
# [Processing] ith =  527
# [Processing] ith =  528
# [Processing] ith =  529
# [Processing] ith =  530
# [Processing] ith =  531
# [Processing] ith =  532
# [Processing] ith =  533
# [Processing] ith =  534
# [Processing] ith =  535
# [Processing] ith =  536
# [Processing] ith =  537
# [Processing] ith =  538
# [Processing] ith =  539
# [Processing] ith =  540
# [Processing] ith =  541
# [Processing] ith =  542
# [Processing] ith =  543
# [Processing] ith =  544
# [Processing] ith =  545
# [Processing] ith =  546
# [Processing] ith =  547
# [Processing] ith =  548
# [Processing] ith =  549
# [Processing] ith =  550
# [Processing] ith =  551
# [Processing] ith =  552
# [Processing] ith =  553
# [Processing] ith =  554
# [Processing] ith =  555
# [Processing] ith =  556
# [Processing] ith =  557
# [Processing] ith =  558
# [Processing] ith =  559
# [Processing] ith =  560
# [Processing] ith =  561
# [Processing] ith =  562
# [Processing] ith =  563
# [Processing] ith =  564
# [Processing] ith =  565
# [Processing] ith =  566
# [Processing] ith =  567
# [Processing] ith =  568
# [Processing] ith =  569
# [Processing] ith =  570
# [Processing] ith =  571
# [Processing] ith =  572
# [Processing] ith =  573
# [Processing] ith =  574
# [Processing] ith =  575
# [Processing] ith =  576
# [Processing] ith =  577
# [Processing] ith =  578
# [Processing] ith =  579
# [Processing] ith =  580
# [Processing] ith =  581
# [Processing] ith =  582
# [Processing] ith =  583
# [Processing] ith =  584
# [Processing] ith =  585
# [Processing] ith =  586
# [Processing] ith =  587
# [Processing] ith =  588
# [Processing] ith =  589
# [Processing] ith =  590
# [Processing] ith =  591
# [Processing] ith =  592
# [Processing] ith =  593
# [Processing] ith =  594
# [Processing] ith =  595
# [Processing] ith =  596
# [Processing] ith =  597
# [Processing] ith =  598
# [Processing] ith =  599
# [Processing] ith =  600
# [Processing] ith =  601
# [Processing] ith =  602
# [Processing] ith =  603
# [Processing] ith =  604
# [Processing] ith =  605
# [Processing] ith =  606
# [Processing] ith =  607
# [Processing] ith =  608
# [Processing] ith =  609
# [Processing] ith =  610
# [Processing] ith =  611
# [Processing] ith =  612
# [Processing] ith =  613
# [Processing] ith =  614
# [Processing] ith =  615
# [Processing] ith =  616
# [Processing] ith =  617
# [Processing] ith =  618
# [Processing] ith =  619
# [Processing] ith =  620
# [Processing] ith =  621
# [Processing] ith =  622
# [Processing] ith =  623
# [Processing] ith =  624
# [Processing] ith =  625
# [Processing] ith =  626
# [Processing] ith =  627
# [Processing] ith =  628
# [Processing] ith =  629
# [Processing] ith =  630
# [Processing] ith =  631
# [Processing] ith =  632
# [Processing] ith =  633
# [Processing] ith =  634
# [Processing] ith =  635
# [Processing] ith =  636
# [Processing] ith =  637
# [Processing] ith =  638
# [Processing] ith =  639
# [Processing] ith =  640
# [Processing] ith =  641
# [Processing] ith =  642
# [Processing] ith =  643
# [Processing] ith =  644
# [Processing] ith =  645
# [Processing] ith =  646
# [Processing] ith =  647
# [Processing] ith =  648
# [Processing] ith =  649
# [Processing] ith =  650
# [Processing] ith =  651
# [Processing] ith =  652
# [Processing] ith =  653
# [Processing] ith =  654
# [Processing] ith =  655
# [Processing] ith =  656
# [Processing] ith =  657
# [Processing] ith =  658
# [Processing] ith =  659
# [Processing] ith =  660
# [Processing] ith =  661
# [Processing] ith =  662
# [Processing] ith =  663
# [Processing] ith =  664
# [Processing] ith =  665
# [Processing] ith =  666
# [Processing] ith =  667
# [Processing] ith =  668
# [Processing] ith =  669
# [Processing] ith =  670
# [Processing] ith =  671
# [Processing] ith =  672
# [Processing] ith =  673
# [Processing] ith =  674
# [Processing] ith =  675
# [Processing] ith =  676
# [Processing] ith =  677
# [Processing] ith =  678
# [Processing] ith =  679
# [Processing] ith =  680
# [Processing] ith =  681
# [Processing] ith =  682
# [Processing] ith =  683
# [Processing] ith =  684
# [Processing] ith =  685
# [Processing] ith =  686
# [Processing] ith =  687
# [Processing] ith =  688
# [Processing] ith =  689
# [Processing] ith =  690
# [Processing] ith =  691
# [Processing] ith =  692
# [Processing] ith =  693
# [Processing] ith =  694
# [Processing] ith =  695
# [Processing] ith =  696
# [Processing] ith =  697
# [Processing] ith =  698
# [Processing] ith =  699
# [Processing] ith =  700
# [Processing] ith =  701
# [Processing] ith =  702
# [Processing] ith =  703
# [Processing] ith =  704
# [Processing] ith =  705
# [Processing] ith =  706
# [Processing] ith =  707
# [Processing] ith =  708
# [Processing] ith =  709
# [Processing] ith =  710
# [Processing] ith =  711
# [Processing] ith =  712
# [Processing] ith =  713
# [Processing] ith =  714
# [Processing] ith =  715
# [Processing] ith =  716
# [Processing] ith =  717
# [Processing] ith =  718
# [Processing] ith =  719
# [Processing] ith =  720
# [Processing] ith =  721
# [Processing] ith =  722
# [Processing] ith =  723
# [Processing] ith =  724
# [Processing] ith =  725
# [Processing] ith =  726
# [Processing] ith =  727
# [Processing] ith =  728
# [Processing] ith =  729
# [Processing] ith =  730
# [Processing] ith =  731
# [Processing] ith =  732
# [Processing] ith =  733
# [Processing] ith =  734
# [Processing] ith =  735
# [Processing] ith =  736
# [Processing] ith =  737
# [Processing] ith =  738
# [Processing] ith =  739
# [Processing] ith =  740
# [Processing] ith =  741
# [Processing] ith =  742
# [Processing] ith =  743
# [Processing] ith =  744
# [Processing] ith =  745
# [Processing] ith =  746
# [Processing] ith =  747
# [Processing] ith =  748
# [Processing] ith =  749
# [Processing] ith =  750
# [Processing] ith =  751
# [Processing] ith =  752
# [Processing] ith =  753
# [Processing] ith =  754
# [Processing] ith =  755
# [Processing] ith =  756
# [Processing] ith =  757
# [Processing] ith =  758
# [Processing] ith =  759
# [Processing] ith =  760
# [Processing] ith =  761
# [Processing] ith =  762
# [Processing] ith =  763
# [Processing] ith =  764
# [Processing] ith =  765
# [Processing] ith =  766
# [Processing] ith =  767
# [Processing] ith =  768
# [Processing] ith =  769
# [Processing] ith =  770
# [Processing] ith =  771
# [Processing] ith =  772
# [Processing] ith =  773
# [Processing] ith =  774
# [Processing] ith =  775
# [Processing] ith =  776
# [Processing] ith =  777
# [Processing] ith =  778
# [Processing] ith =  779
# [Processing] ith =  780
# [Processing] ith =  781
# [Processing] ith =  782
# [Processing] ith =  783
# [Processing] ith =  784
# [Processing] ith =  785
# [Processing] ith =  786
# [Processing] ith =  787
# [Processing] ith =  788
# [Processing] ith =  789
# [Processing] ith =  790
# [Processing] ith =  791
# [Processing] ith =  792
# [Processing] ith =  793
# [Processing] ith =  794
# [Processing] ith =  795
# [Processing] ith =  796
# [Processing] ith =  797
# [Processing] ith =  798
# [Processing] ith =  799
# [Processing] ith =  800
# [Processing] ith =  801
# [Processing] ith =  802
# [Processing] ith =  803
# [Processing] ith =  804
# [Processing] ith =  805
# [Processing] ith =  806
# [Processing] ith =  807
# [Processing] ith =  808
# [Processing] ith =  809
# [Processing] ith =  810
# [Processing] ith =  811
# [Processing] ith =  812
# [Processing] ith =  813
# [Processing] ith =  814
# [Processing] ith =  815
# [Processing] ith =  816
# [Processing] ith =  817
# [Processing] ith =  818
# [Processing] ith =  819
# [Processing] ith =  820
# [Processing] ith =  821
# [Processing] ith =  822
# [Processing] ith =  823
# [Processing] ith =  824
# [Processing] ith =  825
# [Processing] ith =  826
# [Processing] ith =  827
# [Processing] ith =  828
# [Processing] ith =  829
# [Processing] ith =  830
# [Processing] ith =  831
# [Processing] ith =  832
# [Processing] ith =  833
# [Processing] ith =  834
# [Processing] ith =  835
# [Processing] ith =  836
# [Processing] ith =  837
# [Processing] ith =  838
# [Processing] ith =  839
# [Processing] ith =  840
# [Processing] ith =  841
# [Processing] ith =  842
# [Processing] ith =  843
# [Processing] ith =  844
# [Processing] ith =  845
# [Processing] ith =  846
# [Processing] ith =  847
# [Processing] ith =  848
# [Processing] ith =  849
# [Processing] ith =  850
# [Processing] ith =  851
# [Processing] ith =  852
# [Processing] ith =  853
# [Processing] ith =  854
# [Processing] ith =  855
# [Processing] ith =  856
# [Processing] ith =  857
# [Processing] ith =  858
# [Processing] ith =  859
# [Processing] ith =  860
# [Processing] ith =  861
# [Processing] ith =  862
# [Processing] ith =  863
# [Processing] ith =  864
# [Processing] ith =  865
# [Processing] ith =  866
# [Processing] ith =  867
# [Processing] ith =  868
# [Processing] ith =  869
# [Processing] ith =  870
# [Processing] ith =  871
# [Processing] ith =  872
# [Processing] ith =  873
# [Processing] ith =  874
# [Processing] ith =  875
# [Processing] ith =  876
# [Processing] ith =  877
# [Processing] ith =  878
# [Processing] ith =  879
# [Processing] ith =  880
# [Processing] ith =  881
# [Processing] ith =  882
# [Processing] ith =  883
# [Processing] ith =  884
# [Processing] ith =  885
# [Processing] ith =  886
# [Processing] ith =  887
# [Processing] ith =  888
# [Processing] ith =  889
# [Processing] ith =  890
# [Processing] ith =  891
# [Processing] ith =  892
# [Processing] ith =  893
# [Processing] ith =  894
# [Processing] ith =  895
# [Processing] ith =  896
# [Processing] ith =  897
# [Processing] ith =  898
# [Processing] ith =  899
# [Processing] ith =  900
# [Processing] ith =  901
# [Processing] ith =  902
# [Processing] ith =  903
# [Processing] ith =  904
# [Processing] ith =  905
# [Processing] ith =  906
# [Processing] ith =  907
# [Processing] ith =  908
# [Processing] ith =  909
# [Processing] ith =  910
# [Processing] ith =  911
# [Processing] ith =  912
# [Processing] ith =  913
# [Processing] ith =  914
# [Processing] ith =  915
# [Processing] ith =  916
# [Processing] ith =  917
# [Processing] ith =  918
# [Processing] ith =  919
# [Processing] ith =  920
# [Processing] ith =  921
# [Processing] ith =  922
# [Processing] ith =  923
# [Processing] ith =  924
# [Processing] ith =  925
# [Processing] ith =  926
# [Processing] ith =  927
# [Processing] ith =  928
# [Processing] ith =  929
# [Processing] ith =  930
# [Processing] ith =  931
# [Processing] ith =  932
# [Processing] ith =  933
# [Processing] ith =  934
# [Processing] ith =  935
# [Processing] ith =  936
# [Processing] ith =  937
# [Processing] ith =  938
# [Processing] ith =  939
# [Processing] ith =  940
# [Processing] ith =  941
# [Processing] ith =  942
# [Processing] ith =  943
# [Processing] ith =  944
# [Processing] ith =  945
# [Processing] ith =  946
# [Processing] ith =  947
# [Processing] ith =  948
# [Processing] ith =  949
# [Processing] ith =  950
# [Processing] ith =  951
# [Processing] ith =  952
# [Processing] ith =  953
# [Processing] ith =  954
# [Processing] ith =  955
# [Processing] ith =  956
# [Processing] ith =  957
# [Processing] ith =  958
# [Processing] ith =  959
# [Processing] ith =  960
# [Processing] ith =  961
# [Processing] ith =  962
# [Processing] ith =  963
# [Processing] ith =  964
# [Processing] ith =  965
# [Processing] ith =  966
# [Processing] ith =  967
# [Processing] ith =  968
# [Processing] ith =  969
# [Processing] ith =  970
# [Processing] ith =  971
# [Processing] ith =  972
# [Processing] ith =  973
# [Processing] ith =  974
# [Processing] ith =  975
# [Processing] ith =  976
# [Processing] ith =  977
# [Processing] ith =  978
# [Processing] ith =  979
# [Processing] ith =  980
# [Processing] ith =  981
# [Processing] ith =  982
# [Processing] ith =  983
# [Processing] ith =  984
# [Processing] ith =  985
# [Processing] ith =  986
# [Processing] ith =  987
# [Processing] ith =  988
# [Processing] ith =  989
# [Processing] ith =  990
# [Processing] ith =  991
# [Processing] ith =  992
# [Processing] ith =  993
# [Processing] ith =  994
# [Processing] ith =  995
# [Processing] ith =  996
# [Processing] ith =  997
# [Processing] ith =  998
# [Processing] ith =  999

# %%
# Forest
freq = 20

plot_log_nhis = np.sin(np.linspace(-freq * np.pi, freq * np.pi, num_bins)) * 1 + 16

for i, log_nhi in enumerate(plot_log_nhis):
    print("[Processing] ith = ", i)
    fig = make_gp_plot(
        z_dlas=[2.7356542745587893], log_nhis=[log_nhi], data=False, color="#5FA8D3"
    )

    fig.savefig(
        "gp_animation/forest/forest_{}.png".format(str(i).zfill(4)),
        dpi=100,
        # transparent=True,
    )
    plt.close()
    plt.clf()
# Out:
# [Processing] ith =  0
# [Processing] ith =  1
# [Processing] ith =  2
# [Processing] ith =  3
# [Processing] ith =  4
# [Processing] ith =  5
# [Processing] ith =  6
# [Processing] ith =  7
# [Processing] ith =  8
# [Processing] ith =  9
# [Processing] ith =  10
# [Processing] ith =  11
# [Processing] ith =  12
# [Processing] ith =  13
# [Processing] ith =  14
# [Processing] ith =  15
# [Processing] ith =  16
# [Processing] ith =  17
# [Processing] ith =  18
# [Processing] ith =  19
# [Processing] ith =  20
# [Processing] ith =  21
# [Processing] ith =  22
# [Processing] ith =  23
# [Processing] ith =  24
# [Processing] ith =  25
# [Processing] ith =  26
# [Processing] ith =  27
# [Processing] ith =  28
# [Processing] ith =  29
# [Processing] ith =  30
# [Processing] ith =  31
# [Processing] ith =  32
# [Processing] ith =  33
# [Processing] ith =  34
# [Processing] ith =  35
# [Processing] ith =  36
# [Processing] ith =  37
# [Processing] ith =  38
# [Processing] ith =  39
# [Processing] ith =  40
# [Processing] ith =  41
# [Processing] ith =  42
# [Processing] ith =  43
# [Processing] ith =  44
# [Processing] ith =  45
# [Processing] ith =  46
# [Processing] ith =  47
# [Processing] ith =  48
# [Processing] ith =  49
# [Processing] ith =  50
# [Processing] ith =  51
# [Processing] ith =  52
# [Processing] ith =  53
# [Processing] ith =  54
# [Processing] ith =  55
# [Processing] ith =  56
# [Processing] ith =  57
# [Processing] ith =  58
# [Processing] ith =  59
# [Processing] ith =  60
# [Processing] ith =  61
# [Processing] ith =  62
# [Processing] ith =  63
# [Processing] ith =  64
# [Processing] ith =  65
# [Processing] ith =  66
# [Processing] ith =  67
# [Processing] ith =  68
# [Processing] ith =  69
# [Processing] ith =  70
# [Processing] ith =  71
# [Processing] ith =  72
# [Processing] ith =  73
# [Processing] ith =  74
# [Processing] ith =  75
# [Processing] ith =  76
# [Processing] ith =  77
# [Processing] ith =  78
# [Processing] ith =  79
# [Processing] ith =  80
# [Processing] ith =  81
# [Processing] ith =  82
# [Processing] ith =  83
# [Processing] ith =  84
# [Processing] ith =  85
# [Processing] ith =  86
# [Processing] ith =  87
# [Processing] ith =  88
# [Processing] ith =  89
# [Processing] ith =  90
# [Processing] ith =  91
# [Processing] ith =  92
# [Processing] ith =  93
# [Processing] ith =  94
# [Processing] ith =  95
# [Processing] ith =  96
# [Processing] ith =  97
# [Processing] ith =  98
# [Processing] ith =  99
# [Processing] ith =  100
# [Processing] ith =  101
# [Processing] ith =  102
# [Processing] ith =  103
# [Processing] ith =  104
# [Processing] ith =  105
# [Processing] ith =  106
# [Processing] ith =  107
# [Processing] ith =  108
# [Processing] ith =  109
# [Processing] ith =  110
# [Processing] ith =  111
# [Processing] ith =  112
# [Processing] ith =  113
# [Processing] ith =  114
# [Processing] ith =  115
# [Processing] ith =  116
# [Processing] ith =  117
# [Processing] ith =  118
# [Processing] ith =  119
# [Processing] ith =  120
# [Processing] ith =  121
# [Processing] ith =  122
# [Processing] ith =  123
# [Processing] ith =  124
# [Processing] ith =  125
# [Processing] ith =  126
# [Processing] ith =  127
# [Processing] ith =  128
# [Processing] ith =  129
# [Processing] ith =  130
# [Processing] ith =  131
# [Processing] ith =  132
# [Processing] ith =  133
# [Processing] ith =  134
# [Processing] ith =  135
# [Processing] ith =  136
# [Processing] ith =  137
# [Processing] ith =  138
# [Processing] ith =  139
# [Processing] ith =  140
# [Processing] ith =  141
# [Processing] ith =  142
# [Processing] ith =  143
# [Processing] ith =  144
# [Processing] ith =  145
# [Processing] ith =  146
# [Processing] ith =  147
# [Processing] ith =  148
# [Processing] ith =  149
# [Processing] ith =  150
# [Processing] ith =  151
# [Processing] ith =  152
# [Processing] ith =  153
# [Processing] ith =  154
# [Processing] ith =  155
# [Processing] ith =  156
# [Processing] ith =  157
# [Processing] ith =  158
# [Processing] ith =  159
# [Processing] ith =  160
# [Processing] ith =  161
# [Processing] ith =  162
# [Processing] ith =  163
# [Processing] ith =  164
# [Processing] ith =  165
# [Processing] ith =  166
# [Processing] ith =  167
# [Processing] ith =  168
# [Processing] ith =  169
# [Processing] ith =  170
# [Processing] ith =  171
# [Processing] ith =  172
# [Processing] ith =  173
# [Processing] ith =  174
# [Processing] ith =  175
# [Processing] ith =  176
# [Processing] ith =  177
# [Processing] ith =  178
# [Processing] ith =  179
# [Processing] ith =  180
# [Processing] ith =  181
# [Processing] ith =  182
# [Processing] ith =  183
# [Processing] ith =  184
# [Processing] ith =  185
# [Processing] ith =  186
# [Processing] ith =  187
# [Processing] ith =  188
# [Processing] ith =  189
# [Processing] ith =  190
# [Processing] ith =  191
# [Processing] ith =  192
# [Processing] ith =  193
# [Processing] ith =  194
# [Processing] ith =  195
# [Processing] ith =  196
# [Processing] ith =  197
# [Processing] ith =  198
# [Processing] ith =  199
# [Processing] ith =  200
# [Processing] ith =  201
# [Processing] ith =  202
# [Processing] ith =  203
# [Processing] ith =  204
# [Processing] ith =  205
# [Processing] ith =  206
# [Processing] ith =  207
# [Processing] ith =  208
# [Processing] ith =  209
# [Processing] ith =  210
# [Processing] ith =  211
# [Processing] ith =  212
# [Processing] ith =  213
# [Processing] ith =  214
# [Processing] ith =  215
# [Processing] ith =  216
# [Processing] ith =  217
# [Processing] ith =  218
# [Processing] ith =  219
# [Processing] ith =  220
# [Processing] ith =  221
# [Processing] ith =  222
# [Processing] ith =  223
# [Processing] ith =  224
# [Processing] ith =  225
# [Processing] ith =  226
# [Processing] ith =  227
# [Processing] ith =  228
# [Processing] ith =  229
# [Processing] ith =  230
# [Processing] ith =  231
# [Processing] ith =  232
# [Processing] ith =  233
# [Processing] ith =  234
# [Processing] ith =  235
# [Processing] ith =  236
# [Processing] ith =  237
# [Processing] ith =  238
# [Processing] ith =  239
# [Processing] ith =  240
# [Processing] ith =  241
# [Processing] ith =  242
# [Processing] ith =  243
# [Processing] ith =  244
# [Processing] ith =  245
# [Processing] ith =  246
# [Processing] ith =  247
# [Processing] ith =  248
# [Processing] ith =  249
# [Processing] ith =  250
# [Processing] ith =  251
# [Processing] ith =  252
# [Processing] ith =  253
# [Processing] ith =  254
# [Processing] ith =  255
# [Processing] ith =  256
# [Processing] ith =  257
# [Processing] ith =  258
# [Processing] ith =  259
# [Processing] ith =  260
# [Processing] ith =  261
# [Processing] ith =  262
# [Processing] ith =  263
# [Processing] ith =  264
# [Processing] ith =  265
# [Processing] ith =  266
# [Processing] ith =  267
# [Processing] ith =  268
# [Processing] ith =  269
# [Processing] ith =  270
# [Processing] ith =  271
# [Processing] ith =  272
# [Processing] ith =  273
# [Processing] ith =  274
# [Processing] ith =  275
# [Processing] ith =  276
# [Processing] ith =  277
# [Processing] ith =  278
# [Processing] ith =  279
# [Processing] ith =  280
# [Processing] ith =  281
# [Processing] ith =  282
# [Processing] ith =  283
# [Processing] ith =  284
# [Processing] ith =  285
# [Processing] ith =  286
# [Processing] ith =  287
# [Processing] ith =  288
# [Processing] ith =  289
# [Processing] ith =  290
# [Processing] ith =  291
# [Processing] ith =  292
# [Processing] ith =  293
# [Processing] ith =  294
# [Processing] ith =  295
# [Processing] ith =  296
# [Processing] ith =  297
# [Processing] ith =  298
# [Processing] ith =  299
# [Processing] ith =  300
# [Processing] ith =  301
# [Processing] ith =  302
# [Processing] ith =  303
# [Processing] ith =  304
# [Processing] ith =  305
# [Processing] ith =  306
# [Processing] ith =  307
# [Processing] ith =  308
# [Processing] ith =  309
# [Processing] ith =  310
# [Processing] ith =  311
# [Processing] ith =  312
# [Processing] ith =  313
# [Processing] ith =  314
# [Processing] ith =  315
# [Processing] ith =  316
# [Processing] ith =  317
# [Processing] ith =  318
# [Processing] ith =  319
# [Processing] ith =  320
# [Processing] ith =  321
# [Processing] ith =  322
# [Processing] ith =  323
# [Processing] ith =  324
# [Processing] ith =  325
# [Processing] ith =  326
# [Processing] ith =  327
# [Processing] ith =  328
# [Processing] ith =  329
# [Processing] ith =  330
# [Processing] ith =  331
# [Processing] ith =  332
# [Processing] ith =  333
# [Processing] ith =  334
# [Processing] ith =  335
# [Processing] ith =  336
# [Processing] ith =  337
# [Processing] ith =  338
# [Processing] ith =  339
# [Processing] ith =  340
# [Processing] ith =  341
# [Processing] ith =  342
# [Processing] ith =  343
# [Processing] ith =  344
# [Processing] ith =  345
# [Processing] ith =  346
# [Processing] ith =  347
# [Processing] ith =  348
# [Processing] ith =  349
# [Processing] ith =  350
# [Processing] ith =  351
# [Processing] ith =  352
# [Processing] ith =  353
# [Processing] ith =  354
# [Processing] ith =  355
# [Processing] ith =  356
# [Processing] ith =  357
# [Processing] ith =  358
# [Processing] ith =  359
# [Processing] ith =  360
# [Processing] ith =  361
# [Processing] ith =  362
# [Processing] ith =  363
# [Processing] ith =  364
# [Processing] ith =  365
# [Processing] ith =  366
# [Processing] ith =  367
# [Processing] ith =  368
# [Processing] ith =  369
# [Processing] ith =  370
# [Processing] ith =  371
# [Processing] ith =  372
# [Processing] ith =  373
# [Processing] ith =  374
# [Processing] ith =  375
# [Processing] ith =  376
# [Processing] ith =  377
# [Processing] ith =  378
# [Processing] ith =  379
# [Processing] ith =  380
# [Processing] ith =  381
# [Processing] ith =  382
# [Processing] ith =  383
# [Processing] ith =  384
# [Processing] ith =  385
# [Processing] ith =  386
# [Processing] ith =  387
# [Processing] ith =  388
# [Processing] ith =  389
# [Processing] ith =  390
# [Processing] ith =  391
# [Processing] ith =  392
# [Processing] ith =  393
# [Processing] ith =  394
# [Processing] ith =  395
# [Processing] ith =  396
# [Processing] ith =  397
# [Processing] ith =  398
# [Processing] ith =  399
# [Processing] ith =  400
# [Processing] ith =  401
# [Processing] ith =  402
# [Processing] ith =  403
# [Processing] ith =  404
# [Processing] ith =  405
# [Processing] ith =  406
# [Processing] ith =  407
# [Processing] ith =  408
# [Processing] ith =  409
# [Processing] ith =  410
# [Processing] ith =  411
# [Processing] ith =  412
# [Processing] ith =  413
# [Processing] ith =  414
# [Processing] ith =  415
# [Processing] ith =  416
# [Processing] ith =  417
# [Processing] ith =  418
# [Processing] ith =  419
# [Processing] ith =  420
# [Processing] ith =  421
# [Processing] ith =  422
# [Processing] ith =  423
# [Processing] ith =  424
# [Processing] ith =  425
# [Processing] ith =  426
# [Processing] ith =  427
# [Processing] ith =  428
# [Processing] ith =  429
# [Processing] ith =  430
# [Processing] ith =  431
# [Processing] ith =  432
# [Processing] ith =  433
# [Processing] ith =  434
# [Processing] ith =  435
# [Processing] ith =  436
# [Processing] ith =  437
# [Processing] ith =  438
# [Processing] ith =  439
# [Processing] ith =  440
# [Processing] ith =  441
# [Processing] ith =  442
# [Processing] ith =  443
# [Processing] ith =  444
# [Processing] ith =  445
# [Processing] ith =  446
# [Processing] ith =  447
# [Processing] ith =  448
# [Processing] ith =  449
# [Processing] ith =  450
# [Processing] ith =  451
# [Processing] ith =  452
# [Processing] ith =  453
# [Processing] ith =  454
# [Processing] ith =  455
# [Processing] ith =  456
# [Processing] ith =  457
# [Processing] ith =  458
# [Processing] ith =  459
# [Processing] ith =  460
# [Processing] ith =  461
# [Processing] ith =  462
# [Processing] ith =  463
# [Processing] ith =  464
# [Processing] ith =  465
# [Processing] ith =  466
# [Processing] ith =  467
# [Processing] ith =  468
# [Processing] ith =  469
# [Processing] ith =  470
# [Processing] ith =  471
# [Processing] ith =  472
# [Processing] ith =  473
# [Processing] ith =  474
# [Processing] ith =  475
# [Processing] ith =  476
# [Processing] ith =  477
# [Processing] ith =  478
# [Processing] ith =  479
# [Processing] ith =  480
# [Processing] ith =  481
# [Processing] ith =  482
# [Processing] ith =  483
# [Processing] ith =  484
# [Processing] ith =  485
# [Processing] ith =  486
# [Processing] ith =  487
# [Processing] ith =  488
# [Processing] ith =  489
# [Processing] ith =  490
# [Processing] ith =  491
# [Processing] ith =  492
# [Processing] ith =  493
# [Processing] ith =  494
# [Processing] ith =  495
# [Processing] ith =  496
# [Processing] ith =  497
# [Processing] ith =  498
# [Processing] ith =  499
# [Processing] ith =  500
# [Processing] ith =  501
# [Processing] ith =  502
# [Processing] ith =  503
# [Processing] ith =  504
# [Processing] ith =  505
# [Processing] ith =  506
# [Processing] ith =  507
# [Processing] ith =  508
# [Processing] ith =  509
# [Processing] ith =  510
# [Processing] ith =  511
# [Processing] ith =  512
# [Processing] ith =  513
# [Processing] ith =  514
# [Processing] ith =  515
# [Processing] ith =  516
# [Processing] ith =  517
# [Processing] ith =  518
# [Processing] ith =  519
# [Processing] ith =  520
# [Processing] ith =  521
# [Processing] ith =  522
# [Processing] ith =  523
# [Processing] ith =  524
# [Processing] ith =  525
# [Processing] ith =  526
# [Processing] ith =  527
# [Processing] ith =  528
# [Processing] ith =  529
# [Processing] ith =  530
# [Processing] ith =  531
# [Processing] ith =  532
# [Processing] ith =  533
# [Processing] ith =  534
# [Processing] ith =  535
# [Processing] ith =  536
# [Processing] ith =  537
# [Processing] ith =  538
# [Processing] ith =  539
# [Processing] ith =  540
# [Processing] ith =  541
# [Processing] ith =  542
# [Processing] ith =  543
# [Processing] ith =  544
# [Processing] ith =  545
# [Processing] ith =  546
# [Processing] ith =  547
# [Processing] ith =  548
# [Processing] ith =  549
# [Processing] ith =  550
# [Processing] ith =  551
# [Processing] ith =  552
# [Processing] ith =  553
# [Processing] ith =  554
# [Processing] ith =  555
# [Processing] ith =  556
# [Processing] ith =  557
# [Processing] ith =  558
# [Processing] ith =  559
# [Processing] ith =  560
# [Processing] ith =  561
# [Processing] ith =  562
# [Processing] ith =  563
# [Processing] ith =  564
# [Processing] ith =  565
# [Processing] ith =  566
# [Processing] ith =  567
# [Processing] ith =  568
# [Processing] ith =  569
# [Processing] ith =  570
# [Processing] ith =  571
# [Processing] ith =  572
# [Processing] ith =  573
# [Processing] ith =  574
# [Processing] ith =  575
# [Processing] ith =  576
# [Processing] ith =  577
# [Processing] ith =  578
# [Processing] ith =  579
# [Processing] ith =  580
# [Processing] ith =  581
# [Processing] ith =  582
# [Processing] ith =  583
# [Processing] ith =  584
# [Processing] ith =  585
# [Processing] ith =  586
# [Processing] ith =  587
# [Processing] ith =  588
# [Processing] ith =  589
# [Processing] ith =  590
# [Processing] ith =  591
# [Processing] ith =  592
# [Processing] ith =  593
# [Processing] ith =  594
# [Processing] ith =  595
# [Processing] ith =  596
# [Processing] ith =  597
# [Processing] ith =  598
# [Processing] ith =  599
# [Processing] ith =  600
# [Processing] ith =  601
# [Processing] ith =  602
# [Processing] ith =  603
# [Processing] ith =  604
# [Processing] ith =  605
# [Processing] ith =  606
# [Processing] ith =  607
# [Processing] ith =  608
# [Processing] ith =  609
# [Processing] ith =  610
# [Processing] ith =  611
# [Processing] ith =  612
# [Processing] ith =  613
# [Processing] ith =  614
# [Processing] ith =  615
# [Processing] ith =  616
# [Processing] ith =  617
# [Processing] ith =  618
# [Processing] ith =  619
# [Processing] ith =  620
# [Processing] ith =  621
# [Processing] ith =  622
# [Processing] ith =  623
# [Processing] ith =  624
# [Processing] ith =  625
# [Processing] ith =  626
# [Processing] ith =  627
# [Processing] ith =  628
# [Processing] ith =  629
# [Processing] ith =  630
# [Processing] ith =  631
# [Processing] ith =  632
# [Processing] ith =  633
# [Processing] ith =  634
# [Processing] ith =  635
# [Processing] ith =  636
# [Processing] ith =  637
# [Processing] ith =  638
# [Processing] ith =  639
# [Processing] ith =  640
# [Processing] ith =  641
# [Processing] ith =  642
# [Processing] ith =  643
# [Processing] ith =  644
# [Processing] ith =  645
# [Processing] ith =  646
# [Processing] ith =  647
# [Processing] ith =  648
# [Processing] ith =  649
# [Processing] ith =  650
# [Processing] ith =  651
# [Processing] ith =  652
# [Processing] ith =  653
# [Processing] ith =  654
# [Processing] ith =  655
# [Processing] ith =  656
# [Processing] ith =  657
# [Processing] ith =  658
# [Processing] ith =  659
# [Processing] ith =  660
# [Processing] ith =  661
# [Processing] ith =  662
# [Processing] ith =  663
# [Processing] ith =  664
# [Processing] ith =  665
# [Processing] ith =  666
# [Processing] ith =  667
# [Processing] ith =  668
# [Processing] ith =  669
# [Processing] ith =  670
# [Processing] ith =  671
# [Processing] ith =  672
# [Processing] ith =  673
# [Processing] ith =  674
# [Processing] ith =  675
# [Processing] ith =  676
# [Processing] ith =  677
# [Processing] ith =  678
# [Processing] ith =  679
# [Processing] ith =  680
# [Processing] ith =  681
# [Processing] ith =  682
# [Processing] ith =  683
# [Processing] ith =  684
# [Processing] ith =  685
# [Processing] ith =  686
# [Processing] ith =  687
# [Processing] ith =  688
# [Processing] ith =  689
# [Processing] ith =  690
# [Processing] ith =  691
# [Processing] ith =  692
# [Processing] ith =  693
# [Processing] ith =  694
# [Processing] ith =  695
# [Processing] ith =  696
# [Processing] ith =  697
# [Processing] ith =  698
# [Processing] ith =  699
# [Processing] ith =  700
# [Processing] ith =  701
# [Processing] ith =  702
# [Processing] ith =  703
# [Processing] ith =  704
# [Processing] ith =  705
# [Processing] ith =  706
# [Processing] ith =  707
# [Processing] ith =  708
# [Processing] ith =  709
# [Processing] ith =  710
# [Processing] ith =  711
# [Processing] ith =  712
# [Processing] ith =  713
# [Processing] ith =  714
# [Processing] ith =  715
# [Processing] ith =  716
# [Processing] ith =  717
# [Processing] ith =  718
# [Processing] ith =  719
# [Processing] ith =  720
# [Processing] ith =  721
# [Processing] ith =  722
# [Processing] ith =  723
# [Processing] ith =  724
# [Processing] ith =  725
# [Processing] ith =  726
# [Processing] ith =  727
# [Processing] ith =  728
# [Processing] ith =  729
# [Processing] ith =  730
# [Processing] ith =  731
# [Processing] ith =  732
# [Processing] ith =  733
# [Processing] ith =  734
# [Processing] ith =  735
# [Processing] ith =  736
# [Processing] ith =  737
# [Processing] ith =  738
# [Processing] ith =  739
# [Processing] ith =  740
# [Processing] ith =  741
# [Processing] ith =  742
# [Processing] ith =  743
# [Processing] ith =  744
# [Processing] ith =  745
# [Processing] ith =  746
# [Processing] ith =  747
# [Processing] ith =  748
# [Processing] ith =  749
# [Processing] ith =  750
# [Processing] ith =  751
# [Processing] ith =  752
# [Processing] ith =  753
# [Processing] ith =  754
# [Processing] ith =  755
# [Processing] ith =  756
# [Processing] ith =  757
# [Processing] ith =  758
# [Processing] ith =  759
# [Processing] ith =  760
# [Processing] ith =  761
# [Processing] ith =  762
# [Processing] ith =  763
# [Processing] ith =  764
# [Processing] ith =  765
# [Processing] ith =  766
# [Processing] ith =  767
# [Processing] ith =  768
# [Processing] ith =  769
# [Processing] ith =  770
# [Processing] ith =  771
# [Processing] ith =  772
# [Processing] ith =  773
# [Processing] ith =  774
# [Processing] ith =  775
# [Processing] ith =  776
# [Processing] ith =  777
# [Processing] ith =  778
# [Processing] ith =  779
# [Processing] ith =  780
# [Processing] ith =  781
# [Processing] ith =  782
# [Processing] ith =  783
# [Processing] ith =  784
# [Processing] ith =  785
# [Processing] ith =  786
# [Processing] ith =  787
# [Processing] ith =  788
# [Processing] ith =  789
# [Processing] ith =  790
# [Processing] ith =  791
# [Processing] ith =  792
# [Processing] ith =  793
# [Processing] ith =  794
# [Processing] ith =  795
# [Processing] ith =  796
# [Processing] ith =  797
# [Processing] ith =  798
# [Processing] ith =  799
# [Processing] ith =  800
# [Processing] ith =  801
# [Processing] ith =  802
# [Processing] ith =  803
# [Processing] ith =  804
# [Processing] ith =  805
# [Processing] ith =  806
# [Processing] ith =  807
# [Processing] ith =  808
# [Processing] ith =  809
# [Processing] ith =  810
# [Processing] ith =  811
# [Processing] ith =  812
# [Processing] ith =  813
# [Processing] ith =  814
# [Processing] ith =  815
# [Processing] ith =  816
# [Processing] ith =  817
# [Processing] ith =  818
# [Processing] ith =  819
# [Processing] ith =  820
# [Processing] ith =  821
# [Processing] ith =  822
# [Processing] ith =  823
# [Processing] ith =  824
# [Processing] ith =  825
# [Processing] ith =  826
# [Processing] ith =  827
# [Processing] ith =  828
# [Processing] ith =  829
# [Processing] ith =  830
# [Processing] ith =  831
# [Processing] ith =  832
# [Processing] ith =  833
# [Processing] ith =  834
# [Processing] ith =  835
# [Processing] ith =  836
# [Processing] ith =  837
# [Processing] ith =  838
# [Processing] ith =  839
# [Processing] ith =  840
# [Processing] ith =  841
# [Processing] ith =  842
# [Processing] ith =  843
# [Processing] ith =  844
# [Processing] ith =  845
# [Processing] ith =  846
# [Processing] ith =  847
# [Processing] ith =  848
# [Processing] ith =  849
# [Processing] ith =  850
# [Processing] ith =  851
# [Processing] ith =  852
# [Processing] ith =  853
# [Processing] ith =  854
# [Processing] ith =  855
# [Processing] ith =  856
# [Processing] ith =  857
# [Processing] ith =  858
# [Processing] ith =  859
# [Processing] ith =  860
# [Processing] ith =  861
# [Processing] ith =  862
# [Processing] ith =  863
# [Processing] ith =  864
# [Processing] ith =  865
# [Processing] ith =  866
# [Processing] ith =  867
# [Processing] ith =  868
# [Processing] ith =  869
# [Processing] ith =  870
# [Processing] ith =  871
# [Processing] ith =  872
# [Processing] ith =  873
# [Processing] ith =  874
# [Processing] ith =  875
# [Processing] ith =  876
# [Processing] ith =  877
# [Processing] ith =  878
# [Processing] ith =  879
# [Processing] ith =  880
# [Processing] ith =  881
# [Processing] ith =  882
# [Processing] ith =  883
# [Processing] ith =  884
# [Processing] ith =  885
# [Processing] ith =  886
# [Processing] ith =  887
# [Processing] ith =  888
# [Processing] ith =  889
# [Processing] ith =  890
# [Processing] ith =  891
# [Processing] ith =  892
# [Processing] ith =  893
# [Processing] ith =  894
# [Processing] ith =  895
# [Processing] ith =  896
# [Processing] ith =  897
# [Processing] ith =  898
# [Processing] ith =  899
# [Processing] ith =  900
# [Processing] ith =  901
# [Processing] ith =  902
# [Processing] ith =  903
# [Processing] ith =  904
# [Processing] ith =  905
# [Processing] ith =  906
# [Processing] ith =  907
# [Processing] ith =  908
# [Processing] ith =  909
# [Processing] ith =  910
# [Processing] ith =  911
# [Processing] ith =  912
# [Processing] ith =  913
# [Processing] ith =  914
# [Processing] ith =  915
# [Processing] ith =  916
# [Processing] ith =  917
# [Processing] ith =  918
# [Processing] ith =  919
# [Processing] ith =  920
# [Processing] ith =  921
# [Processing] ith =  922
# [Processing] ith =  923
# [Processing] ith =  924
# [Processing] ith =  925
# [Processing] ith =  926
# [Processing] ith =  927
# [Processing] ith =  928
# [Processing] ith =  929
# [Processing] ith =  930
# [Processing] ith =  931
# [Processing] ith =  932
# [Processing] ith =  933
# [Processing] ith =  934
# [Processing] ith =  935
# [Processing] ith =  936
# [Processing] ith =  937
# [Processing] ith =  938
# [Processing] ith =  939
# [Processing] ith =  940
# [Processing] ith =  941
# [Processing] ith =  942
# [Processing] ith =  943
# [Processing] ith =  944
# [Processing] ith =  945
# [Processing] ith =  946
# [Processing] ith =  947
# [Processing] ith =  948
# [Processing] ith =  949
# [Processing] ith =  950
# [Processing] ith =  951
# [Processing] ith =  952
# [Processing] ith =  953
# [Processing] ith =  954
# [Processing] ith =  955
# [Processing] ith =  956
# [Processing] ith =  957
# [Processing] ith =  958
# [Processing] ith =  959
# [Processing] ith =  960
# [Processing] ith =  961
# [Processing] ith =  962
# [Processing] ith =  963
# [Processing] ith =  964
# [Processing] ith =  965
# [Processing] ith =  966
# [Processing] ith =  967
# [Processing] ith =  968
# [Processing] ith =  969
# [Processing] ith =  970
# [Processing] ith =  971
# [Processing] ith =  972
# [Processing] ith =  973
# [Processing] ith =  974
# [Processing] ith =  975
# [Processing] ith =  976
# [Processing] ith =  977
# [Processing] ith =  978
# [Processing] ith =  979
# [Processing] ith =  980
# [Processing] ith =  981
# [Processing] ith =  982
# [Processing] ith =  983
# [Processing] ith =  984
# [Processing] ith =  985
# [Processing] ith =  986
# [Processing] ith =  987
# [Processing] ith =  988
# [Processing] ith =  989
# [Processing] ith =  990
# [Processing] ith =  991
# [Processing] ith =  992
# [Processing] ith =  993
# [Processing] ith =  994
# [Processing] ith =  995
# [Processing] ith =  996
# [Processing] ith =  997
# [Processing] ith =  998
# [Processing] ith =  999

# %%
fig = make_gp_plot(
    z_dlas=[2.7356542745587893], log_nhis=[log_nhi], data=False, color="C0"
)

# %% [markdown]
# ## Bayesian model selection example

# %%
from gpy_dla_detection.read_spec import read_spec_dr14q

# %%
with open("data/dla_catalogs/dr16q_gp/predictions_DLAs_dr16q_lyinf.json", "r") as f:
    dr16q_catalog = json.load(f)

# %%
real_index = np.where([(spec["thing_id"] == 488562798) for spec in dr16q_catalog])[0]

# %%
def download_and_read_dr16q(
    plate: int,
    mjd: int,
    fiber_id: int,
):
    filename = "spec-{:d}-{:d}-{:04d}.fits".format(plate, mjd, fiber_id)

    # If we haven't downloaded the file, this cell will help you download the file from SDSS database
    if not os.path.exists(filename):
        # This line gets the plate, mjd, and fiber_id from the given filename
        # Note: re is the regex.
        plate, mjd, fiber_id = re.findall(
            r"spec-([0-9]+)-([0-9]+)-([0-9]+).fits",
            filename,
        )[0]
        # Download the file using the given plate, mjd, and fiber_id
        retrieve_raw_spec(int(plate), int(mjd), int(fiber_id), release="dr14q")

    # make sure the file exists
    assert os.path.exists(filename) == True

    # Read the raw spectrum: This line reads the spectrum file into four numpy arrays
    wavelengths, flux, noise_variance, pixel_mask = read_spec_dr14q(filename)
    # simulated data
    # you have : wavelengths (velocities), flux
    # noise_variance : you need to inject your own noise
    # pixel_mask : you don't have. pixel_mask is the invalid pixel in spectrum
    return wavelengths, flux, noise_variance, pixel_mask

# %%
ith = 0

spec_dict = dr16q_catalog[real_index[ith]]

# extract info
plate = spec_dict["plate"]
mjd = spec_dict["mjd"]
fiber_id = spec_dict["fiber_id"]

z_qso = spec_dict["z_qso"]

# dla detection
dlas_dict = spec_dict["dlas"]
num_dlas = len(dlas_dict)
z_dlas = []
log_nhis = []
for j in range(num_dlas):
    z_dlas.append(dlas_dict[j]["z_dla"])
    log_nhis.append(dlas_dict[j]["log_nhi"])

spec_dict
# Out:
# {'p_dla': 1.0,
#  'p_no_dla': 7.682805201047715e-69,
#  'max_model_posterior': 1.0,
#  'num_dlas': 3,
#  'min_z_dla': 2.0749966949453986,
#  'max_z_dla': 3.076598035618435,
#  'snr': 7.521835563560534,
#  'ra': 144.70586409750788,
#  'dec': 50.58689152368285,
#  'plate': 7448,
#  'mjd': 56739,
#  'fiber_id': 136,
#  'thing_id': 488562798,
#  'z_qso': 3.0866049584743798,
#  'dlas': [{'log_nhi': 20.051429484721176, 'z_dla': 2.667099342961066},
#   {'log_nhi': 21.141880107346395, 'z_dla': 3.017513093250241},
#   {'log_nhi': 20.32869876798681, 'z_dla': 2.8976009210255}],
#  'tail_dlas': []}

# %%
wavelengths, flux, noise_variance, pixel_mask = download_and_read_dr16q(
    plate, mjd, fiber_id
)
# Out:
# [Info] retrieving https://data.sdss.org/sas/dr16/eboss/spectro/redux/v5_13_0/spectra/lite/7448/spec-7448-56739-0136.fits ... Done.

# %%
def make_plot_bayes_model(z_dlas=[2.7356542745587893], log_nhis=[20.98739284253573]):
    # Now you can get the model with Lya absorbers
    spec_dict = dr16q_catalog[real_index[0]]

    # extract info
    plate = spec_dict["plate"]
    mjd = spec_dict["mjd"]
    fiber_id = spec_dict["fiber_id"]

    # read spec
    wavelengths, flux, noise_variance, pixel_mask = download_and_read_dr16q(
        plate, mjd, fiber_id
    )

    z_qso = spec_dict["z_qso"]
    rest_wavelengths = wavelengths / (1 + z_qso)

    # dla detection
    dlas_dict = spec_dict["dlas"]
    num_dlas = len(dlas_dict)
    true_z_dlas = []
    true_log_nhis = []
    for j in range(num_dlas):
        true_z_dlas.append(dlas_dict[j]["z_dla"])
        true_log_nhis.append(dlas_dict[j]["log_nhi"])
    true_z_dlas = np.array(true_z_dlas)
    true_log_nhis = np.array(true_log_nhis)

    ################### Plotting the model ###################
    fig, ax = plt.subplots(1, 1, figsize=(16, 5))
    # from blue to red
    redshift_color = "C4"
    model_color = "C8"

    # Change DLA color if there's detection
    is_change_color = []
    for z_dla, log_nhi in zip(z_dlas, log_nhis):
        change_or_not = np.any(np.abs(z_dla - true_z_dlas) < 0.02) & np.any(
            np.abs(log_nhi - true_log_nhis) < 0.05
        )
        is_change_color.append(change_or_not)
    is_change_color = np.all(is_change_color)
    if is_change_color:
        model_color = "C5"

    # plotting normalization
    normalization = 0

    # Make the GP model interpolated onto the observed quasar spectum
    gp.set_data(
        rest_wavelengths, flux, noise_variance, pixel_mask, z_qso, build_model=True
    )
    # p( D | z_abs =  z_lya, NHI = nhi, absorber model)
    lya_gp.set_data(
        rest_wavelengths,
        flux,
        noise_variance,
        pixel_mask,
        z_qso,
        build_model=True,
    )
    lya_mu, lya_M, lya_omega2 = lya_gp.this_dla_gp(
        z_dlas, [10**log_nhi for log_nhi in log_nhis]
    )

    ################# Whole spectrum without cropping ###############
    # normalize spectrum
    ind_norm = (
        (rest_wavelengths >= gp.params.normalization_min_lambda)
        & (rest_wavelengths <= gp.params.normalization_max_lambda)
        & (~pixel_mask)
    )
    this_median = np.nanmedian(flux[ind_norm])
    flux = flux / this_median
    # masking pixels
    wavelengths = wavelengths[~pixel_mask]
    rest_wavelengths = rest_wavelengths[~pixel_mask]
    flux = flux[~pixel_mask]

    # Mean function
    ax.plot(
        wavelengths,  # quasar spectrum's rest-frame wavelengths
        flux + normalization,  # quasar spectrum's flux
        label="Data",
        color=redshift_color,
        lw=0.9,
        alpha=0.9,
    )
    ax.fill_between(
        wavelengths,
        -0.5,
        flux + normalization,
        label="SDSS Instrumental Uncertainty (95%)",
        color=redshift_color,
        # alpha=0.6,
    )

    ax.plot(
        gp.rest_wavelengths * (1 + z_qso),
        gp.mu + normalization,
        label="GP null model (mu = continuum)",
        color=model_color,
        # ls="--",
        linewidth=2.2,
        alpha=0.9,
    )

    # This line plots model
    ax.plot(
        gp.X * (1 + z_qso),
        lya_mu + normalization,
        color=model_color,
        label="GP Lya model (mu = meanflux)",
    )  # GP model's mean function
    ax.fill_between(
        gp.X * (1 + z_qso),
        lya_mu + normalization,
        gp.mu_interpolator(gp.X),
        color=model_color,
        alpha=0.7,
        label="Absorption",
        ls="--",
    )
    # plt.text(gp.X[200] * (1 + z_qso), lya_mu[200] * normalization, "$z_{QSO} = $" + "{:.3g}".format(z_qso))

    ax.set_xlabel("Observed-frame Wavelengths [$\AA$]", fontdict={"fontsize": 16})
    # ax.set_ylabel("Normalized Flux")
    ax.set_xlim(3600, 1215 * (1 + z_qso))
    ax.set_ylim(-0.5, 5)

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["bottom"].set_visible(False)
    ax.spines["left"].set_visible(False)

    ax.text(
        4400,
        4,
        "$z_{DLA}$ = "
        + ",".join(["{:.4g}".format(z_dla) for z_dla in z_dlas])
        + ";\n"
        + "$\log N_\mathrm{HI}$ = "
        + ",".join(["{:.4g}".format(log_nhi) for log_nhi in log_nhis]),
        fontdict={"fontsize": 20},
    )

    # ax.axis("off")
    ax.set(yticklabels=[])
    fig.tight_layout()

    # fig.savefig(
    #     "cover_photos/demo_spec_{}_snr_35.png".format(k), dpi=150, transparent=True
    # )
    return fig

# %%
spec_dict["dlas"]
# Out:
# [{'log_nhi': 20.051429484721176, 'z_dla': 2.667099342961066},
#  {'log_nhi': 21.141880107346395, 'z_dla': 3.017513093250241},
#  {'log_nhi': 20.32869876798681, 'z_dla': 2.8976009210255}]

# %%
num_bins = 500
freq = 10

plot_log_nhis = np.sin(np.linspace(-3 * freq * np.pi, 3 * freq * np.pi, num_bins)) + 21

# Generate plotting samples centered around detection
num_dlas = len(spec_dict["dlas"])
num_centered_samples = 100
num_uniform_samples = num_bins - num_dlas * num_centered_samples

plot_z_dlas = []
for dla_sample in spec_dict["dlas"]:
    z_dla_samples = np.random.normal(
        loc=dla_sample["z_dla"], scale=0.02, size=num_centered_samples
    )
    plot_z_dlas.append(z_dla_samples)

min_z_dla = lya_gp.params.min_z_dla(wavelengths, z_qso)
max_z_dla = lya_gp.params.max_z_dla(wavelengths, z_qso)
uniform_samples = np.linspace(min_z_dla, max_z_dla, num_uniform_samples)

plot_z_dlas = np.append(np.concatenate(plot_z_dlas), uniform_samples)
plot_z_dlas = np.sort(plot_z_dlas)

## Want it to go reverse
plot_log_nhis = np.concatenate([plot_log_nhis, plot_log_nhis[::-1]])
plot_z_dlas = np.concatenate([plot_z_dlas, plot_z_dlas[::-1]])

# %%
plt.plot(plot_z_dlas)

# %%
make_plot_bayes_model(z_dlas=[plot_z_dlas[-1]], log_nhis=[plot_log_nhis[-1]])

# %%
for k, (z_dla, log_nhi) in enumerate(zip(plot_z_dlas, plot_log_nhis)):
    print("[Processing] ith = ", k)
    fig = make_plot_bayes_model(z_dlas=[z_dla], log_nhis=[log_nhi])
    fig.savefig(
        "bayes_model_animation/demo_spec_{}.png".format(str(k).zfill(4)),
        dpi=100,
        # transparent=True,
    )
    plt.close()
    plt.clf()
# Out:
# [Processing] ith =  0
# [Processing] ith =  1
# [Processing] ith =  2
# [Processing] ith =  3
# [Processing] ith =  4
# [Processing] ith =  5
# [Processing] ith =  6
# [Processing] ith =  7
# [Processing] ith =  8
# [Processing] ith =  9
# [Processing] ith =  10
# [Processing] ith =  11
# [Processing] ith =  12
# [Processing] ith =  13
# [Processing] ith =  14
# [Processing] ith =  15
# [Processing] ith =  16
# [Processing] ith =  17
# [Processing] ith =  18
# [Processing] ith =  19
# [Processing] ith =  20
# [Processing] ith =  21
# [Processing] ith =  22
# [Processing] ith =  23
# [Processing] ith =  24
# [Processing] ith =  25
# [Processing] ith =  26
# [Processing] ith =  27
# [Processing] ith =  28
# [Processing] ith =  29
# [Processing] ith =  30
# [Processing] ith =  31
# [Processing] ith =  32
# [Processing] ith =  33
# [Processing] ith =  34
# [Processing] ith =  35
# [Processing] ith =  36
# [Processing] ith =  37
# [Processing] ith =  38
# [Processing] ith =  39
# [Processing] ith =  40
# [Processing] ith =  41
# [Processing] ith =  42
# [Processing] ith =  43
# [Processing] ith =  44
# [Processing] ith =  45
# [Processing] ith =  46
# [Processing] ith =  47
# [Processing] ith =  48
# [Processing] ith =  49
# [Processing] ith =  50
# [Processing] ith =  51
# [Processing] ith =  52
# [Processing] ith =  53
# [Processing] ith =  54
# [Processing] ith =  55
# [Processing] ith =  56
# [Processing] ith =  57
# [Processing] ith =  58
# [Processing] ith =  59
# [Processing] ith =  60
# [Processing] ith =  61
# [Processing] ith =  62
# [Processing] ith =  63
# [Processing] ith =  64
# [Processing] ith =  65
# [Processing] ith =  66
# [Processing] ith =  67
# [Processing] ith =  68
# [Processing] ith =  69
# [Processing] ith =  70
# [Processing] ith =  71
# [Processing] ith =  72
# [Processing] ith =  73
# [Processing] ith =  74
# [Processing] ith =  75
# [Processing] ith =  76
# [Processing] ith =  77
# [Processing] ith =  78
# [Processing] ith =  79
# [Processing] ith =  80
# [Processing] ith =  81
# [Processing] ith =  82
# [Processing] ith =  83
# [Processing] ith =  84
# [Processing] ith =  85
# [Processing] ith =  86
# [Processing] ith =  87
# [Processing] ith =  88
# [Processing] ith =  89
# [Processing] ith =  90
# [Processing] ith =  91
# [Processing] ith =  92
# [Processing] ith =  93
# [Processing] ith =  94
# [Processing] ith =  95
# [Processing] ith =  96
# [Processing] ith =  97
# [Processing] ith =  98
# [Processing] ith =  99
# [Processing] ith =  100
# [Processing] ith =  101
# [Processing] ith =  102
# [Processing] ith =  103
# [Processing] ith =  104
# [Processing] ith =  105
# [Processing] ith =  106
# [Processing] ith =  107
# [Processing] ith =  108
# [Processing] ith =  109
# [Processing] ith =  110
# [Processing] ith =  111
# [Processing] ith =  112
# [Processing] ith =  113
# [Processing] ith =  114
# [Processing] ith =  115
# [Processing] ith =  116
# [Processing] ith =  117
# [Processing] ith =  118
# [Processing] ith =  119
# [Processing] ith =  120
# [Processing] ith =  121
# [Processing] ith =  122
# [Processing] ith =  123
# [Processing] ith =  124
# [Processing] ith =  125
# [Processing] ith =  126
# [Processing] ith =  127
# [Processing] ith =  128
# [Processing] ith =  129
# [Processing] ith =  130
# [Processing] ith =  131
# [Processing] ith =  132
# [Processing] ith =  133
# [Processing] ith =  134
# [Processing] ith =  135
# [Processing] ith =  136
# [Processing] ith =  137
# [Processing] ith =  138
# [Processing] ith =  139
# [Processing] ith =  140
# [Processing] ith =  141
# [Processing] ith =  142
# [Processing] ith =  143
# [Processing] ith =  144
# [Processing] ith =  145
# [Processing] ith =  146
# [Processing] ith =  147
# [Processing] ith =  148
# [Processing] ith =  149
# [Processing] ith =  150
# [Processing] ith =  151
# [Processing] ith =  152
# [Processing] ith =  153
# [Processing] ith =  154
# [Processing] ith =  155
# [Processing] ith =  156
# [Processing] ith =  157
# [Processing] ith =  158
# [Processing] ith =  159
# [Processing] ith =  160
# [Processing] ith =  161
# [Processing] ith =  162
# [Processing] ith =  163
# [Processing] ith =  164
# [Processing] ith =  165
# [Processing] ith =  166
# [Processing] ith =  167
# [Processing] ith =  168
# [Processing] ith =  169
# [Processing] ith =  170
# [Processing] ith =  171
# [Processing] ith =  172
# [Processing] ith =  173
# [Processing] ith =  174
# [Processing] ith =  175
# [Processing] ith =  176
# [Processing] ith =  177
# [Processing] ith =  178
# [Processing] ith =  179
# [Processing] ith =  180
# [Processing] ith =  181
# [Processing] ith =  182
# [Processing] ith =  183
# [Processing] ith =  184
# [Processing] ith =  185
# [Processing] ith =  186
# [Processing] ith =  187
# [Processing] ith =  188
# [Processing] ith =  189
# [Processing] ith =  190
# [Processing] ith =  191
# [Processing] ith =  192
# [Processing] ith =  193
# [Processing] ith =  194
# [Processing] ith =  195
# [Processing] ith =  196
# [Processing] ith =  197
# [Processing] ith =  198
# [Processing] ith =  199
# [Processing] ith =  200
# [Processing] ith =  201
# [Processing] ith =  202
# [Processing] ith =  203
# [Processing] ith =  204
# [Processing] ith =  205
# [Processing] ith =  206
# [Processing] ith =  207
# [Processing] ith =  208
# [Processing] ith =  209
# [Processing] ith =  210
# [Processing] ith =  211
# [Processing] ith =  212
# [Processing] ith =  213
# [Processing] ith =  214
# [Processing] ith =  215
# [Processing] ith =  216
# [Processing] ith =  217
# [Processing] ith =  218
# [Processing] ith =  219
# [Processing] ith =  220
# [Processing] ith =  221
# [Processing] ith =  222
# [Processing] ith =  223
# [Processing] ith =  224
# [Processing] ith =  225
# [Processing] ith =  226
# [Processing] ith =  227
# [Processing] ith =  228
# [Processing] ith =  229
# [Processing] ith =  230
# [Processing] ith =  231
# [Processing] ith =  232
# [Processing] ith =  233
# [Processing] ith =  234
# [Processing] ith =  235
# [Processing] ith =  236
# [Processing] ith =  237
# [Processing] ith =  238
# [Processing] ith =  239
# [Processing] ith =  240
# [Processing] ith =  241
# [Processing] ith =  242
# [Processing] ith =  243
# [Processing] ith =  244
# [Processing] ith =  245
# [Processing] ith =  246
# [Processing] ith =  247
# [Processing] ith =  248
# [Processing] ith =  249
# [Processing] ith =  250
# [Processing] ith =  251
# [Processing] ith =  252
# [Processing] ith =  253
# [Processing] ith =  254
# [Processing] ith =  255
# [Processing] ith =  256
# [Processing] ith =  257
# [Processing] ith =  258
# [Processing] ith =  259
# [Processing] ith =  260
# [Processing] ith =  261
# [Processing] ith =  262
# [Processing] ith =  263
# [Processing] ith =  264
# [Processing] ith =  265
# [Processing] ith =  266
# [Processing] ith =  267
# [Processing] ith =  268
# [Processing] ith =  269
# [Processing] ith =  270
# [Processing] ith =  271
# [Processing] ith =  272
# [Processing] ith =  273
# [Processing] ith =  274
# [Processing] ith =  275
# [Processing] ith =  276
# [Processing] ith =  277
# [Processing] ith =  278
# [Processing] ith =  279
# [Processing] ith =  280
# [Processing] ith =  281
# [Processing] ith =  282
# [Processing] ith =  283
# [Processing] ith =  284
# [Processing] ith =  285
# [Processing] ith =  286
# [Processing] ith =  287
# [Processing] ith =  288
# [Processing] ith =  289
# [Processing] ith =  290
# [Processing] ith =  291
# [Processing] ith =  292
# [Processing] ith =  293
# [Processing] ith =  294
# [Processing] ith =  295
# [Processing] ith =  296
# [Processing] ith =  297
# [Processing] ith =  298
# [Processing] ith =  299
# [Processing] ith =  300
# [Processing] ith =  301
# [Processing] ith =  302
# [Processing] ith =  303
# [Processing] ith =  304
# [Processing] ith =  305
# [Processing] ith =  306
# [Processing] ith =  307
# [Processing] ith =  308
# [Processing] ith =  309
# [Processing] ith =  310
# [Processing] ith =  311
# [Processing] ith =  312
# [Processing] ith =  313
# [Processing] ith =  314
# [Processing] ith =  315
# [Processing] ith =  316
# [Processing] ith =  317
# [Processing] ith =  318
# [Processing] ith =  319
# [Processing] ith =  320
# [Processing] ith =  321
# [Processing] ith =  322
# [Processing] ith =  323
# [Processing] ith =  324
# [Processing] ith =  325
# [Processing] ith =  326
# [Processing] ith =  327
# [Processing] ith =  328
# [Processing] ith =  329
# [Processing] ith =  330
# [Processing] ith =  331
# [Processing] ith =  332
# [Processing] ith =  333
# [Processing] ith =  334
# [Processing] ith =  335
# [Processing] ith =  336
# [Processing] ith =  337
# [Processing] ith =  338
# [Processing] ith =  339
# [Processing] ith =  340
# [Processing] ith =  341
# [Processing] ith =  342
# [Processing] ith =  343
# [Processing] ith =  344
# [Processing] ith =  345
# [Processing] ith =  346
# [Processing] ith =  347
# [Processing] ith =  348
# [Processing] ith =  349
# [Processing] ith =  350
# [Processing] ith =  351
# [Processing] ith =  352
# [Processing] ith =  353
# [Processing] ith =  354
# [Processing] ith =  355
# [Processing] ith =  356
# [Processing] ith =  357
# [Processing] ith =  358
# [Processing] ith =  359
# [Processing] ith =  360
# [Processing] ith =  361
# [Processing] ith =  362
# [Processing] ith =  363
# [Processing] ith =  364
# [Processing] ith =  365
# [Processing] ith =  366
# [Processing] ith =  367
# [Processing] ith =  368
# [Processing] ith =  369
# [Processing] ith =  370
# [Processing] ith =  371
# [Processing] ith =  372
# [Processing] ith =  373
# [Processing] ith =  374
# [Processing] ith =  375
# [Processing] ith =  376
# [Processing] ith =  377
# [Processing] ith =  378
# [Processing] ith =  379
# [Processing] ith =  380
# [Processing] ith =  381
# [Processing] ith =  382
# [Processing] ith =  383
# [Processing] ith =  384
# [Processing] ith =  385
# [Processing] ith =  386
# [Processing] ith =  387
# [Processing] ith =  388
# [Processing] ith =  389
# [Processing] ith =  390
# [Processing] ith =  391
# [Processing] ith =  392
# [Processing] ith =  393
# [Processing] ith =  394
# [Processing] ith =  395
# [Processing] ith =  396
# [Processing] ith =  397
# [Processing] ith =  398
# [Processing] ith =  399
# [Processing] ith =  400
# [Processing] ith =  401
# [Processing] ith =  402
# [Processing] ith =  403
# [Processing] ith =  404
# [Processing] ith =  405
# [Processing] ith =  406
# [Processing] ith =  407
# [Processing] ith =  408
# [Processing] ith =  409
# [Processing] ith =  410
# [Processing] ith =  411
# [Processing] ith =  412
# [Processing] ith =  413
# [Processing] ith =  414
# [Processing] ith =  415
# [Processing] ith =  416
# [Processing] ith =  417
# [Processing] ith =  418
# [Processing] ith =  419
# [Processing] ith =  420
# [Processing] ith =  421
# [Processing] ith =  422
# [Processing] ith =  423
# [Processing] ith =  424
# [Processing] ith =  425
# [Processing] ith =  426
# [Processing] ith =  427
# [Processing] ith =  428
# [Processing] ith =  429
# [Processing] ith =  430
# [Processing] ith =  431
# [Processing] ith =  432
# [Processing] ith =  433
# [Processing] ith =  434
# [Processing] ith =  435
# [Processing] ith =  436
# [Processing] ith =  437
# [Processing] ith =  438
# [Processing] ith =  439
# [Processing] ith =  440
# [Processing] ith =  441
# [Processing] ith =  442
# [Processing] ith =  443
# [Processing] ith =  444
# [Processing] ith =  445
# [Processing] ith =  446
# [Processing] ith =  447
# [Processing] ith =  448
# [Processing] ith =  449
# [Processing] ith =  450
# [Processing] ith =  451
# [Processing] ith =  452
# [Processing] ith =  453
# [Processing] ith =  454
# [Processing] ith =  455
# [Processing] ith =  456
# [Processing] ith =  457
# [Processing] ith =  458
# [Processing] ith =  459
# [Processing] ith =  460
# [Processing] ith =  461
# [Processing] ith =  462
# [Processing] ith =  463
# [Processing] ith =  464
# [Processing] ith =  465
# [Processing] ith =  466
# [Processing] ith =  467
# [Processing] ith =  468
# [Processing] ith =  469
# [Processing] ith =  470
# [Processing] ith =  471
# [Processing] ith =  472
# [Processing] ith =  473
# [Processing] ith =  474
# [Processing] ith =  475
# [Processing] ith =  476
# [Processing] ith =  477
# [Processing] ith =  478
# [Processing] ith =  479
# [Processing] ith =  480
# [Processing] ith =  481
# [Processing] ith =  482
# [Processing] ith =  483
# [Processing] ith =  484
# [Processing] ith =  485
# [Processing] ith =  486
# [Processing] ith =  487
# [Processing] ith =  488
# [Processing] ith =  489
# [Processing] ith =  490
# [Processing] ith =  491
# [Processing] ith =  492
# [Processing] ith =  493
# [Processing] ith =  494
# [Processing] ith =  495
# [Processing] ith =  496
# [Processing] ith =  497
# [Processing] ith =  498
# [Processing] ith =  499
# [Processing] ith =  500
# [Processing] ith =  501
# [Processing] ith =  502
# [Processing] ith =  503
# [Processing] ith =  504
# [Processing] ith =  505
# [Processing] ith =  506
# [Processing] ith =  507
# [Processing] ith =  508
# [Processing] ith =  509
# [Processing] ith =  510
# [Processing] ith =  511
# [Processing] ith =  512
# [Processing] ith =  513
# [Processing] ith =  514
# [Processing] ith =  515
# [Processing] ith =  516
# [Processing] ith =  517
# [Processing] ith =  518
# [Processing] ith =  519
# [Processing] ith =  520
# [Processing] ith =  521
# [Processing] ith =  522
# [Processing] ith =  523
# [Processing] ith =  524
# [Processing] ith =  525
# [Processing] ith =  526
# [Processing] ith =  527
# [Processing] ith =  528
# [Processing] ith =  529
# [Processing] ith =  530
# [Processing] ith =  531
# [Processing] ith =  532
# [Processing] ith =  533
# [Processing] ith =  534
# [Processing] ith =  535
# [Processing] ith =  536
# [Processing] ith =  537
# [Processing] ith =  538
# [Processing] ith =  539
# [Processing] ith =  540
# [Processing] ith =  541
# [Processing] ith =  542
# [Processing] ith =  543
# [Processing] ith =  544
# [Processing] ith =  545
# [Processing] ith =  546
# [Processing] ith =  547
# [Processing] ith =  548
# [Processing] ith =  549
# [Processing] ith =  550
# [Processing] ith =  551
# [Processing] ith =  552
# [Processing] ith =  553
# [Processing] ith =  554
# [Processing] ith =  555
# [Processing] ith =  556
# [Processing] ith =  557
# [Processing] ith =  558
# [Processing] ith =  559
# [Processing] ith =  560
# [Processing] ith =  561
# [Processing] ith =  562
# [Processing] ith =  563
# [Processing] ith =  564
# [Processing] ith =  565
# [Processing] ith =  566
# [Processing] ith =  567
# [Processing] ith =  568
# [Processing] ith =  569
# [Processing] ith =  570
# [Processing] ith =  571
# [Processing] ith =  572
# [Processing] ith =  573
# [Processing] ith =  574
# [Processing] ith =  575
# [Processing] ith =  576
# [Processing] ith =  577
# [Processing] ith =  578
# [Processing] ith =  579
# [Processing] ith =  580
# [Processing] ith =  581
# [Processing] ith =  582
# [Processing] ith =  583
# [Processing] ith =  584
# [Processing] ith =  585
# [Processing] ith =  586
# [Processing] ith =  587
# [Processing] ith =  588
# [Processing] ith =  589
# [Processing] ith =  590
# [Processing] ith =  591
# [Processing] ith =  592
# [Processing] ith =  593
# [Processing] ith =  594
# [Processing] ith =  595
# [Processing] ith =  596
# [Processing] ith =  597
# [Processing] ith =  598
# [Processing] ith =  599
# [Processing] ith =  600
# [Processing] ith =  601
# [Processing] ith =  602
# [Processing] ith =  603
# [Processing] ith =  604
# [Processing] ith =  605
# [Processing] ith =  606
# [Processing] ith =  607
# [Processing] ith =  608
# [Processing] ith =  609
# [Processing] ith =  610
# [Processing] ith =  611
# [Processing] ith =  612
# [Processing] ith =  613
# [Processing] ith =  614
# [Processing] ith =  615
# [Processing] ith =  616
# [Processing] ith =  617
# [Processing] ith =  618
# [Processing] ith =  619
# [Processing] ith =  620
# [Processing] ith =  621
# [Processing] ith =  622
# [Processing] ith =  623
# [Processing] ith =  624
# [Processing] ith =  625
# [Processing] ith =  626
# [Processing] ith =  627
# [Processing] ith =  628
# [Processing] ith =  629
# [Processing] ith =  630
# [Processing] ith =  631
# [Processing] ith =  632
# [Processing] ith =  633
# [Processing] ith =  634
# [Processing] ith =  635
# [Processing] ith =  636
# [Processing] ith =  637
# [Processing] ith =  638
# [Processing] ith =  639
# [Processing] ith =  640
# [Processing] ith =  641
# [Processing] ith =  642
# [Processing] ith =  643
# [Processing] ith =  644
# [Processing] ith =  645
# [Processing] ith =  646
# [Processing] ith =  647
# [Processing] ith =  648
# [Processing] ith =  649
# [Processing] ith =  650
# [Processing] ith =  651
# [Processing] ith =  652
# [Processing] ith =  653
# [Processing] ith =  654
# [Processing] ith =  655
# [Processing] ith =  656
# [Processing] ith =  657
# [Processing] ith =  658
# [Processing] ith =  659
# [Processing] ith =  660
# [Processing] ith =  661
# [Processing] ith =  662
# [Processing] ith =  663
# [Processing] ith =  664
# [Processing] ith =  665
# [Processing] ith =  666
# [Processing] ith =  667
# [Processing] ith =  668
# [Processing] ith =  669
# [Processing] ith =  670
# [Processing] ith =  671
# [Processing] ith =  672
# [Processing] ith =  673
# [Processing] ith =  674
# [Processing] ith =  675
# [Processing] ith =  676
# [Processing] ith =  677
# [Processing] ith =  678
# [Processing] ith =  679
# [Processing] ith =  680
# [Processing] ith =  681
# [Processing] ith =  682
# [Processing] ith =  683
# [Processing] ith =  684
# [Processing] ith =  685
# [Processing] ith =  686
# [Processing] ith =  687
# [Processing] ith =  688
# [Processing] ith =  689
# [Processing] ith =  690
# [Processing] ith =  691
# [Processing] ith =  692
# [Processing] ith =  693
# [Processing] ith =  694
# [Processing] ith =  695
# [Processing] ith =  696
# [Processing] ith =  697
# [Processing] ith =  698
# [Processing] ith =  699
# [Processing] ith =  700
# [Processing] ith =  701
# [Processing] ith =  702
# [Processing] ith =  703
# [Processing] ith =  704
# [Processing] ith =  705
# [Processing] ith =  706
# [Processing] ith =  707
# [Processing] ith =  708
# [Processing] ith =  709
# [Processing] ith =  710
# [Processing] ith =  711
# [Processing] ith =  712
# [Processing] ith =  713
# [Processing] ith =  714
# [Processing] ith =  715
# [Processing] ith =  716
# [Processing] ith =  717
# [Processing] ith =  718
# [Processing] ith =  719
# [Processing] ith =  720
# [Processing] ith =  721
# [Processing] ith =  722
# [Processing] ith =  723
# [Processing] ith =  724
# [Processing] ith =  725
# [Processing] ith =  726
# [Processing] ith =  727
# [Processing] ith =  728
# [Processing] ith =  729
# [Processing] ith =  730
# [Processing] ith =  731
# [Processing] ith =  732
# [Processing] ith =  733
# [Processing] ith =  734
# [Processing] ith =  735
# [Processing] ith =  736
# [Processing] ith =  737
# [Processing] ith =  738
# [Processing] ith =  739
# [Processing] ith =  740
# [Processing] ith =  741
# [Processing] ith =  742
# [Processing] ith =  743
# [Processing] ith =  744
# [Processing] ith =  745
# [Processing] ith =  746
# [Processing] ith =  747
# [Processing] ith =  748
# [Processing] ith =  749
# [Processing] ith =  750
# [Processing] ith =  751
# [Processing] ith =  752
# [Processing] ith =  753
# [Processing] ith =  754
# [Processing] ith =  755
# [Processing] ith =  756
# [Processing] ith =  757
# [Processing] ith =  758
# [Processing] ith =  759
# [Processing] ith =  760
# [Processing] ith =  761
# [Processing] ith =  762
# [Processing] ith =  763
# [Processing] ith =  764
# [Processing] ith =  765
# [Processing] ith =  766
# [Processing] ith =  767
# [Processing] ith =  768
# [Processing] ith =  769
# [Processing] ith =  770
# [Processing] ith =  771
# [Processing] ith =  772
# [Processing] ith =  773
# [Processing] ith =  774
# [Processing] ith =  775
# [Processing] ith =  776
# [Processing] ith =  777
# [Processing] ith =  778
# [Processing] ith =  779
# [Processing] ith =  780
# [Processing] ith =  781
# [Processing] ith =  782
# [Processing] ith =  783
# [Processing] ith =  784
# [Processing] ith =  785
# [Processing] ith =  786
# [Processing] ith =  787
# [Processing] ith =  788
# [Processing] ith =  789
# [Processing] ith =  790
# [Processing] ith =  791
# [Processing] ith =  792
# [Processing] ith =  793
# [Processing] ith =  794
# [Processing] ith =  795
# [Processing] ith =  796
# [Processing] ith =  797
# [Processing] ith =  798
# [Processing] ith =  799
# [Processing] ith =  800
# [Processing] ith =  801
# [Processing] ith =  802
# [Processing] ith =  803
# [Processing] ith =  804
# [Processing] ith =  805
# [Processing] ith =  806
# [Processing] ith =  807
# [Processing] ith =  808
# [Processing] ith =  809
# [Processing] ith =  810
# [Processing] ith =  811
# [Processing] ith =  812
# [Processing] ith =  813
# [Processing] ith =  814
# [Processing] ith =  815
# [Processing] ith =  816
# [Processing] ith =  817
# [Processing] ith =  818
# [Processing] ith =  819
# [Processing] ith =  820
# [Processing] ith =  821
# [Processing] ith =  822
# [Processing] ith =  823
# [Processing] ith =  824
# [Processing] ith =  825
# [Processing] ith =  826
# [Processing] ith =  827
# [Processing] ith =  828
# [Processing] ith =  829
# [Processing] ith =  830
# [Processing] ith =  831
# [Processing] ith =  832
# [Processing] ith =  833
# [Processing] ith =  834
# [Processing] ith =  835
# [Processing] ith =  836
# [Processing] ith =  837
# [Processing] ith =  838
# [Processing] ith =  839
# [Processing] ith =  840
# [Processing] ith =  841
# [Processing] ith =  842
# [Processing] ith =  843
# [Processing] ith =  844
# [Processing] ith =  845
# [Processing] ith =  846
# [Processing] ith =  847
# [Processing] ith =  848
# [Processing] ith =  849
# [Processing] ith =  850
# [Processing] ith =  851
# [Processing] ith =  852
# [Processing] ith =  853
# [Processing] ith =  854
# [Processing] ith =  855
# [Processing] ith =  856
# [Processing] ith =  857
# [Processing] ith =  858
# [Processing] ith =  859
# [Processing] ith =  860
# [Processing] ith =  861
# [Processing] ith =  862
# [Processing] ith =  863
# [Processing] ith =  864
# [Processing] ith =  865
# [Processing] ith =  866
# [Processing] ith =  867
# [Processing] ith =  868
# [Processing] ith =  869
# [Processing] ith =  870
# [Processing] ith =  871
# [Processing] ith =  872
# [Processing] ith =  873
# [Processing] ith =  874
# [Processing] ith =  875
# [Processing] ith =  876
# [Processing] ith =  877
# [Processing] ith =  878
# [Processing] ith =  879
# [Processing] ith =  880
# [Processing] ith =  881
# [Processing] ith =  882
# [Processing] ith =  883
# [Processing] ith =  884
# [Processing] ith =  885
# [Processing] ith =  886
# [Processing] ith =  887
# [Processing] ith =  888
# [Processing] ith =  889
# [Processing] ith =  890
# [Processing] ith =  891
# [Processing] ith =  892
# [Processing] ith =  893
# [Processing] ith =  894
# [Processing] ith =  895
# [Processing] ith =  896
# [Processing] ith =  897
# [Processing] ith =  898
# [Processing] ith =  899
# [Processing] ith =  900
# [Processing] ith =  901
# [Processing] ith =  902
# [Processing] ith =  903
# [Processing] ith =  904
# [Processing] ith =  905
# [Processing] ith =  906
# [Processing] ith =  907
# [Processing] ith =  908
# [Processing] ith =  909
# [Processing] ith =  910
# [Processing] ith =  911
# [Processing] ith =  912
# [Processing] ith =  913
# [Processing] ith =  914
# [Processing] ith =  915
# [Processing] ith =  916
# [Processing] ith =  917
# [Processing] ith =  918
# [Processing] ith =  919
# [Processing] ith =  920
# [Processing] ith =  921
# [Processing] ith =  922
# [Processing] ith =  923
# [Processing] ith =  924
# [Processing] ith =  925
# [Processing] ith =  926
# [Processing] ith =  927
# [Processing] ith =  928
# [Processing] ith =  929
# [Processing] ith =  930
# [Processing] ith =  931
# [Processing] ith =  932
# [Processing] ith =  933
# [Processing] ith =  934
# [Processing] ith =  935
# [Processing] ith =  936
# [Processing] ith =  937
# [Processing] ith =  938
# [Processing] ith =  939
# [Processing] ith =  940
# [Processing] ith =  941
# [Processing] ith =  942
# [Processing] ith =  943
# [Processing] ith =  944
# [Processing] ith =  945
# [Processing] ith =  946
# [Processing] ith =  947
# [Processing] ith =  948
# [Processing] ith =  949
# [Processing] ith =  950
# [Processing] ith =  951
# [Processing] ith =  952
# [Processing] ith =  953
# [Processing] ith =  954
# [Processing] ith =  955
# [Processing] ith =  956
# [Processing] ith =  957
# [Processing] ith =  958
# [Processing] ith =  959
# [Processing] ith =  960
# [Processing] ith =  961
# [Processing] ith =  962
# [Processing] ith =  963
# [Processing] ith =  964
# [Processing] ith =  965
# [Processing] ith =  966
# [Processing] ith =  967
# [Processing] ith =  968
# [Processing] ith =  969
# [Processing] ith =  970
# [Processing] ith =  971
# [Processing] ith =  972
# [Processing] ith =  973
# [Processing] ith =  974
# [Processing] ith =  975
# [Processing] ith =  976
# [Processing] ith =  977
# [Processing] ith =  978
# [Processing] ith =  979
# [Processing] ith =  980
# [Processing] ith =  981
# [Processing] ith =  982
# [Processing] ith =  983
# [Processing] ith =  984
# [Processing] ith =  985
# [Processing] ith =  986
# [Processing] ith =  987
# [Processing] ith =  988
# [Processing] ith =  989
# [Processing] ith =  990
# [Processing] ith =  991
# [Processing] ith =  992
# [Processing] ith =  993
# [Processing] ith =  994
# [Processing] ith =  995
# [Processing] ith =  996
# [Processing] ith =  997
# [Processing] ith =  998
# [Processing] ith =  999

# %%
z_dla
# Out:
# 2.9910341019931

# %% [markdown]
# 2D Integration Demo

# %%
def generate_plot_samples(num_bins=500, freq=10, scale=0.02, num_centered_samples=100):
    ########### 1 Dimension ###########
    plot_log_nhis_1 = (
        np.sin(np.linspace(-3 * freq * np.pi, 3 * freq * np.pi, num_bins)) + 21
    )

    # Generate plotting samples centered around detection
    num_dlas = len(spec_dict["dlas"])
    num_uniform_samples = num_bins - num_dlas * num_centered_samples

    plot_z_dlas_1 = []
    for dla_sample in spec_dict["dlas"]:
        z_dla_samples = np.random.normal(
            loc=dla_sample["z_dla"], scale=scale, size=num_centered_samples
        )
        plot_z_dlas_1.append(z_dla_samples)

    min_z_dla = lya_gp.params.min_z_dla(wavelengths, z_qso)
    max_z_dla = lya_gp.params.max_z_dla(wavelengths, z_qso)
    uniform_samples = np.linspace(min_z_dla, max_z_dla, num_uniform_samples)

    plot_z_dlas_1 = np.append(np.concatenate(plot_z_dlas_1), uniform_samples)
    plot_z_dlas_1 = np.sort(plot_z_dlas_1)

    ## Want it to go reverse
    plot_log_nhis_1 = np.concatenate([plot_log_nhis_1, plot_log_nhis_1[::-1]])
    plot_z_dlas_1 = np.concatenate([plot_z_dlas_1, plot_z_dlas_1[::-1]])

    return plot_z_dlas_1, plot_log_nhis_1


plot_z_dlas_1, plot_log_nhis_1 = generate_plot_samples(
    num_bins=500, freq=10, scale=0.02, num_centered_samples=100
)
plot_z_dlas_2, plot_log_nhis_2 = generate_plot_samples(
    num_bins=100, freq=1.5, scale=0.01, num_centered_samples=30
)
plot_z_dlas_2 = np.concatenate([plot_z_dlas_2 for i in range(5)])
plot_log_nhis_2 = np.concatenate([plot_log_nhis_2 for i in range(5)])

# %%
for k, (z_dla_1, log_nhi_1, z_dla_2, log_nhi_2) in enumerate(
    zip(plot_z_dlas_1, plot_log_nhis_1, plot_z_dlas_2, plot_log_nhis_2)
):
    print("[Processing] ith = ", k)
    fig = make_plot_bayes_model(
        z_dlas=[z_dla_1, z_dla_2], log_nhis=[log_nhi_1, log_nhi_2]
    )
    fig.savefig(
        "bayes_model_animation/bayes2d/demo_spec_{}.png".format(str(k).zfill(4)),
        dpi=100,
        # transparent=True,
    )
    plt.close()
    plt.clf()
# Out:
# [Processing] ith =  0
# [Processing] ith =  1
# [Processing] ith =  2
# [Processing] ith =  3
# [Processing] ith =  4
# [Processing] ith =  5
# [Processing] ith =  6
# [Processing] ith =  7
# [Processing] ith =  8
# [Processing] ith =  9
# [Processing] ith =  10
# [Processing] ith =  11
# [Processing] ith =  12
# [Processing] ith =  13
# [Processing] ith =  14
# [Processing] ith =  15
# [Processing] ith =  16
# [Processing] ith =  17
# [Processing] ith =  18
# [Processing] ith =  19
# [Processing] ith =  20
# [Processing] ith =  21
# [Processing] ith =  22
# [Processing] ith =  23
# [Processing] ith =  24
# [Processing] ith =  25
# [Processing] ith =  26
# [Processing] ith =  27
# [Processing] ith =  28
# [Processing] ith =  29
# [Processing] ith =  30
# [Processing] ith =  31
# [Processing] ith =  32
# [Processing] ith =  33
# [Processing] ith =  34
# [Processing] ith =  35
# [Processing] ith =  36
# [Processing] ith =  37
# [Processing] ith =  38
# [Processing] ith =  39
# [Processing] ith =  40
# [Processing] ith =  41
# [Processing] ith =  42
# [Processing] ith =  43
# [Processing] ith =  44
# [Processing] ith =  45
# [Processing] ith =  46
# [Processing] ith =  47
# [Processing] ith =  48
# [Processing] ith =  49
# [Processing] ith =  50
# [Processing] ith =  51
# [Processing] ith =  52
# [Processing] ith =  53
# [Processing] ith =  54
# [Processing] ith =  55
# [Processing] ith =  56
# [Processing] ith =  57
# [Processing] ith =  58
# [Processing] ith =  59
# [Processing] ith =  60
# [Processing] ith =  61
# [Processing] ith =  62
# [Processing] ith =  63
# [Processing] ith =  64
# [Processing] ith =  65
# [Processing] ith =  66
# [Processing] ith =  67
# [Processing] ith =  68
# [Processing] ith =  69
# [Processing] ith =  70
# [Processing] ith =  71
# [Processing] ith =  72
# [Processing] ith =  73
# [Processing] ith =  74
# [Processing] ith =  75
# [Processing] ith =  76
# [Processing] ith =  77
# [Processing] ith =  78
# [Processing] ith =  79
# [Processing] ith =  80
# [Processing] ith =  81
# [Processing] ith =  82
# [Processing] ith =  83
# [Processing] ith =  84
# [Processing] ith =  85
# [Processing] ith =  86
# [Processing] ith =  87
# [Processing] ith =  88
# [Processing] ith =  89
# [Processing] ith =  90
# [Processing] ith =  91
# [Processing] ith =  92
# [Processing] ith =  93
# [Processing] ith =  94
# [Processing] ith =  95
# [Processing] ith =  96
# [Processing] ith =  97
# [Processing] ith =  98
# [Processing] ith =  99
# [Processing] ith =  100
# [Processing] ith =  101
# [Processing] ith =  102
# [Processing] ith =  103
# [Processing] ith =  104
# [Processing] ith =  105
# [Processing] ith =  106
# [Processing] ith =  107
# [Processing] ith =  108
# [Processing] ith =  109
# [Processing] ith =  110
# [Processing] ith =  111
# [Processing] ith =  112
# [Processing] ith =  113
# [Processing] ith =  114
# [Processing] ith =  115
# [Processing] ith =  116
# [Processing] ith =  117
# [Processing] ith =  118
# [Processing] ith =  119
# [Processing] ith =  120
# [Processing] ith =  121
# [Processing] ith =  122
# [Processing] ith =  123
# [Processing] ith =  124
# [Processing] ith =  125
# [Processing] ith =  126
# [Processing] ith =  127
# [Processing] ith =  128
# [Processing] ith =  129
# [Processing] ith =  130
# [Processing] ith =  131
# [Processing] ith =  132
# [Processing] ith =  133
# [Processing] ith =  134
# [Processing] ith =  135
# [Processing] ith =  136
# [Processing] ith =  137
# [Processing] ith =  138
# [Processing] ith =  139
# [Processing] ith =  140
# [Processing] ith =  141
# [Processing] ith =  142
# [Processing] ith =  143
# [Processing] ith =  144
# [Processing] ith =  145
# [Processing] ith =  146
# [Processing] ith =  147
# [Processing] ith =  148
# [Processing] ith =  149
# [Processing] ith =  150
# [Processing] ith =  151
# [Processing] ith =  152
# [Processing] ith =  153
# [Processing] ith =  154
# [Processing] ith =  155
# [Processing] ith =  156
# [Processing] ith =  157
# [Processing] ith =  158
# [Processing] ith =  159
# [Processing] ith =  160
# [Processing] ith =  161
# [Processing] ith =  162
# [Processing] ith =  163
# [Processing] ith =  164
# [Processing] ith =  165
# [Processing] ith =  166
# [Processing] ith =  167
# [Processing] ith =  168
# [Processing] ith =  169
# [Processing] ith =  170
# [Processing] ith =  171
# [Processing] ith =  172
# [Processing] ith =  173
# [Processing] ith =  174
# [Processing] ith =  175
# [Processing] ith =  176
# [Processing] ith =  177
# [Processing] ith =  178
# [Processing] ith =  179
# [Processing] ith =  180
# [Processing] ith =  181
# [Processing] ith =  182
# [Processing] ith =  183
# [Processing] ith =  184
# [Processing] ith =  185
# [Processing] ith =  186
# [Processing] ith =  187
# [Processing] ith =  188
# [Processing] ith =  189
# [Processing] ith =  190
# [Processing] ith =  191
# [Processing] ith =  192
# [Processing] ith =  193
# [Processing] ith =  194
# [Processing] ith =  195
# [Processing] ith =  196
# [Processing] ith =  197
# [Processing] ith =  198
# [Processing] ith =  199
# [Processing] ith =  200
# [Processing] ith =  201
# [Processing] ith =  202
# [Processing] ith =  203
# [Processing] ith =  204
# [Processing] ith =  205
# [Processing] ith =  206
# [Processing] ith =  207
# [Processing] ith =  208
# [Processing] ith =  209
# [Processing] ith =  210
# [Processing] ith =  211
# [Processing] ith =  212
# [Processing] ith =  213
# [Processing] ith =  214
# [Processing] ith =  215
# [Processing] ith =  216
# [Processing] ith =  217
# [Processing] ith =  218
# [Processing] ith =  219
# [Processing] ith =  220
# [Processing] ith =  221
# [Processing] ith =  222
# [Processing] ith =  223
# [Processing] ith =  224
# [Processing] ith =  225
# [Processing] ith =  226
# [Processing] ith =  227
# [Processing] ith =  228
# [Processing] ith =  229
# [Processing] ith =  230
# [Processing] ith =  231
# [Processing] ith =  232
# [Processing] ith =  233
# [Processing] ith =  234
# [Processing] ith =  235
# [Processing] ith =  236
# [Processing] ith =  237
# [Processing] ith =  238
# [Processing] ith =  239
# [Processing] ith =  240
# [Processing] ith =  241
# [Processing] ith =  242
# [Processing] ith =  243
# [Processing] ith =  244
# [Processing] ith =  245
# [Processing] ith =  246
# [Processing] ith =  247
# [Processing] ith =  248
# [Processing] ith =  249
# [Processing] ith =  250
# [Processing] ith =  251
# [Processing] ith =  252
# [Processing] ith =  253
# [Processing] ith =  254
# [Processing] ith =  255
# [Processing] ith =  256
# [Processing] ith =  257
# [Processing] ith =  258
# [Processing] ith =  259
# [Processing] ith =  260
# [Processing] ith =  261
# [Processing] ith =  262
# [Processing] ith =  263
# [Processing] ith =  264
# [Processing] ith =  265
# [Processing] ith =  266
# [Processing] ith =  267
# [Processing] ith =  268
# [Processing] ith =  269
# [Processing] ith =  270
# [Processing] ith =  271
# [Processing] ith =  272
# [Processing] ith =  273
# [Processing] ith =  274
# [Processing] ith =  275
# [Processing] ith =  276
# [Processing] ith =  277
# [Processing] ith =  278
# [Processing] ith =  279
# [Processing] ith =  280
# [Processing] ith =  281
# [Processing] ith =  282
# [Processing] ith =  283
# [Processing] ith =  284
# [Processing] ith =  285
# [Processing] ith =  286
# [Processing] ith =  287
# [Processing] ith =  288
# [Processing] ith =  289
# [Processing] ith =  290
# [Processing] ith =  291
# [Processing] ith =  292
# [Processing] ith =  293
# [Processing] ith =  294
# [Processing] ith =  295
# [Processing] ith =  296
# [Processing] ith =  297
# [Processing] ith =  298
# [Processing] ith =  299
# [Processing] ith =  300
# [Processing] ith =  301
# [Processing] ith =  302
# [Processing] ith =  303
# [Processing] ith =  304
# [Processing] ith =  305
# [Processing] ith =  306
# [Processing] ith =  307
# [Processing] ith =  308
# [Processing] ith =  309
# [Processing] ith =  310
# [Processing] ith =  311
# [Processing] ith =  312
# [Processing] ith =  313
# [Processing] ith =  314
# [Processing] ith =  315
# [Processing] ith =  316
# [Processing] ith =  317
# [Processing] ith =  318
# [Processing] ith =  319
# [Processing] ith =  320
# [Processing] ith =  321
# [Processing] ith =  322
# [Processing] ith =  323
# [Processing] ith =  324
# [Processing] ith =  325
# [Processing] ith =  326
# [Processing] ith =  327
# [Processing] ith =  328
# [Processing] ith =  329
# [Processing] ith =  330
# [Processing] ith =  331
# [Processing] ith =  332
# [Processing] ith =  333
# [Processing] ith =  334
# [Processing] ith =  335
# [Processing] ith =  336
# [Processing] ith =  337
# [Processing] ith =  338
# [Processing] ith =  339
# [Processing] ith =  340
# [Processing] ith =  341
# [Processing] ith =  342
# [Processing] ith =  343
# [Processing] ith =  344
# [Processing] ith =  345
# [Processing] ith =  346
# [Processing] ith =  347
# [Processing] ith =  348
# [Processing] ith =  349
# [Processing] ith =  350
# [Processing] ith =  351
# [Processing] ith =  352
# [Processing] ith =  353
# [Processing] ith =  354
# [Processing] ith =  355
# [Processing] ith =  356
# [Processing] ith =  357
# [Processing] ith =  358
# [Processing] ith =  359
# [Processing] ith =  360
# [Processing] ith =  361
# [Processing] ith =  362
# [Processing] ith =  363
# [Processing] ith =  364
# [Processing] ith =  365
# [Processing] ith =  366
# [Processing] ith =  367
# [Processing] ith =  368
# [Processing] ith =  369
# [Processing] ith =  370
# [Processing] ith =  371
# [Processing] ith =  372
# [Processing] ith =  373
# [Processing] ith =  374
# [Processing] ith =  375
# [Processing] ith =  376
# [Processing] ith =  377
# [Processing] ith =  378
# [Processing] ith =  379
# [Processing] ith =  380
# [Processing] ith =  381
# [Processing] ith =  382
# [Processing] ith =  383
# [Processing] ith =  384
# [Processing] ith =  385
# [Processing] ith =  386
# [Processing] ith =  387
# [Processing] ith =  388
# [Processing] ith =  389
# [Processing] ith =  390
# [Processing] ith =  391
# [Processing] ith =  392
# [Processing] ith =  393
# [Processing] ith =  394
# [Processing] ith =  395
# [Processing] ith =  396
# [Processing] ith =  397
# [Processing] ith =  398
# [Processing] ith =  399
# [Processing] ith =  400
# [Processing] ith =  401
# [Processing] ith =  402
# [Processing] ith =  403
# [Processing] ith =  404
# [Processing] ith =  405
# [Processing] ith =  406
# [Processing] ith =  407
# [Processing] ith =  408
# [Processing] ith =  409
# [Processing] ith =  410
# [Processing] ith =  411
# [Processing] ith =  412
# [Processing] ith =  413
# [Processing] ith =  414
# [Processing] ith =  415
# [Processing] ith =  416
# [Processing] ith =  417
# [Processing] ith =  418
# [Processing] ith =  419
# [Processing] ith =  420
# [Processing] ith =  421
# [Processing] ith =  422
# [Processing] ith =  423
# [Processing] ith =  424
# [Processing] ith =  425
# [Processing] ith =  426
# [Processing] ith =  427
# [Processing] ith =  428
# [Processing] ith =  429
# [Processing] ith =  430
# [Processing] ith =  431
# [Processing] ith =  432
# [Processing] ith =  433
# [Processing] ith =  434
# [Processing] ith =  435
# [Processing] ith =  436
# [Processing] ith =  437
# [Processing] ith =  438
# [Processing] ith =  439
# [Processing] ith =  440
# [Processing] ith =  441
# [Processing] ith =  442
# [Processing] ith =  443
# [Processing] ith =  444
# [Processing] ith =  445
# [Processing] ith =  446
# [Processing] ith =  447
# [Processing] ith =  448
# [Processing] ith =  449
# [Processing] ith =  450
# [Processing] ith =  451
# [Processing] ith =  452
# [Processing] ith =  453
# [Processing] ith =  454
# [Processing] ith =  455
# [Processing] ith =  456
# [Processing] ith =  457
# [Processing] ith =  458
# [Processing] ith =  459
# [Processing] ith =  460
# [Processing] ith =  461
# [Processing] ith =  462
# [Processing] ith =  463
# [Processing] ith =  464
# [Processing] ith =  465
# [Processing] ith =  466
# [Processing] ith =  467
# [Processing] ith =  468
# [Processing] ith =  469
# [Processing] ith =  470
# [Processing] ith =  471
# [Processing] ith =  472
# [Processing] ith =  473
# [Processing] ith =  474
# [Processing] ith =  475
# [Processing] ith =  476
# [Processing] ith =  477
# [Processing] ith =  478
# [Processing] ith =  479
# [Processing] ith =  480
# [Processing] ith =  481
# [Processing] ith =  482
# [Processing] ith =  483
# [Processing] ith =  484
# [Processing] ith =  485
# [Processing] ith =  486
# [Processing] ith =  487
# [Processing] ith =  488
# [Processing] ith =  489
# [Processing] ith =  490
# [Processing] ith =  491
# [Processing] ith =  492
# [Processing] ith =  493
# [Processing] ith =  494
# [Processing] ith =  495
# [Processing] ith =  496
# [Processing] ith =  497
# [Processing] ith =  498
# [Processing] ith =  499
# [Processing] ith =  500
# [Processing] ith =  501
# [Processing] ith =  502
# [Processing] ith =  503
# [Processing] ith =  504
# [Processing] ith =  505
# [Processing] ith =  506
# [Processing] ith =  507
# [Processing] ith =  508
# [Processing] ith =  509
# [Processing] ith =  510
# [Processing] ith =  511
# [Processing] ith =  512
# [Processing] ith =  513
# [Processing] ith =  514
# [Processing] ith =  515
# [Processing] ith =  516
# [Processing] ith =  517
# [Processing] ith =  518
# [Processing] ith =  519
# [Processing] ith =  520
# [Processing] ith =  521
# [Processing] ith =  522
# [Processing] ith =  523
# [Processing] ith =  524
# [Processing] ith =  525
# [Processing] ith =  526
# [Processing] ith =  527
# [Processing] ith =  528
# [Processing] ith =  529
# [Processing] ith =  530
# [Processing] ith =  531
# [Processing] ith =  532
# [Processing] ith =  533
# [Processing] ith =  534
# [Processing] ith =  535
# [Processing] ith =  536
# [Processing] ith =  537
# [Processing] ith =  538
# [Processing] ith =  539
# [Processing] ith =  540
# [Processing] ith =  541
# [Processing] ith =  542
# [Processing] ith =  543
# [Processing] ith =  544
# [Processing] ith =  545
# [Processing] ith =  546
# [Processing] ith =  547
# [Processing] ith =  548
# [Processing] ith =  549
# [Processing] ith =  550
# [Processing] ith =  551
# [Processing] ith =  552
# [Processing] ith =  553
# [Processing] ith =  554
# [Processing] ith =  555
# [Processing] ith =  556
# [Processing] ith =  557
# [Processing] ith =  558
# [Processing] ith =  559
# [Processing] ith =  560
# [Processing] ith =  561
# [Processing] ith =  562
# [Processing] ith =  563
# [Processing] ith =  564
# [Processing] ith =  565
# [Processing] ith =  566
# [Processing] ith =  567
# [Processing] ith =  568
# [Processing] ith =  569
# [Processing] ith =  570
# [Processing] ith =  571
# [Processing] ith =  572
# [Processing] ith =  573
# [Processing] ith =  574
# [Processing] ith =  575
# [Processing] ith =  576
# [Processing] ith =  577
# [Processing] ith =  578
# [Processing] ith =  579
# [Processing] ith =  580
# [Processing] ith =  581
# [Processing] ith =  582
# [Processing] ith =  583
# [Processing] ith =  584
# [Processing] ith =  585
# [Processing] ith =  586
# [Processing] ith =  587
# [Processing] ith =  588
# [Processing] ith =  589
# [Processing] ith =  590
# [Processing] ith =  591
# [Processing] ith =  592
# [Processing] ith =  593
# [Processing] ith =  594
# [Processing] ith =  595
# [Processing] ith =  596
# [Processing] ith =  597
# [Processing] ith =  598
# [Processing] ith =  599
# [Processing] ith =  600
# [Processing] ith =  601
# [Processing] ith =  602
# [Processing] ith =  603
# [Processing] ith =  604
# [Processing] ith =  605
# [Processing] ith =  606
# [Processing] ith =  607
# [Processing] ith =  608
# [Processing] ith =  609
# [Processing] ith =  610
# [Processing] ith =  611
# [Processing] ith =  612
# [Processing] ith =  613
# [Processing] ith =  614
# [Processing] ith =  615
# [Processing] ith =  616
# [Processing] ith =  617
# [Processing] ith =  618
# [Processing] ith =  619
# [Processing] ith =  620
# [Processing] ith =  621
# [Processing] ith =  622
# [Processing] ith =  623
# [Processing] ith =  624
# [Processing] ith =  625
# [Processing] ith =  626
# [Processing] ith =  627
# [Processing] ith =  628
# [Processing] ith =  629
# [Processing] ith =  630
# [Processing] ith =  631
# [Processing] ith =  632
# [Processing] ith =  633
# [Processing] ith =  634
# [Processing] ith =  635
# [Processing] ith =  636
# [Processing] ith =  637
# [Processing] ith =  638
# [Processing] ith =  639
# [Processing] ith =  640
# [Processing] ith =  641
# [Processing] ith =  642
# [Processing] ith =  643
# [Processing] ith =  644
# [Processing] ith =  645
# [Processing] ith =  646
# [Processing] ith =  647
# [Processing] ith =  648
# [Processing] ith =  649
# [Processing] ith =  650
# [Processing] ith =  651
# [Processing] ith =  652
# [Processing] ith =  653
# [Processing] ith =  654
# [Processing] ith =  655
# [Processing] ith =  656
# [Processing] ith =  657
# [Processing] ith =  658
# [Processing] ith =  659
# [Processing] ith =  660
# [Processing] ith =  661
# [Processing] ith =  662
# [Processing] ith =  663
# [Processing] ith =  664
# [Processing] ith =  665
# [Processing] ith =  666
# [Processing] ith =  667
# [Processing] ith =  668
# [Processing] ith =  669
# [Processing] ith =  670
# [Processing] ith =  671
# [Processing] ith =  672
# [Processing] ith =  673
# [Processing] ith =  674
# [Processing] ith =  675
# [Processing] ith =  676
# [Processing] ith =  677
# [Processing] ith =  678
# [Processing] ith =  679
# [Processing] ith =  680
# [Processing] ith =  681
# [Processing] ith =  682
# [Processing] ith =  683
# [Processing] ith =  684
# [Processing] ith =  685
# [Processing] ith =  686
# [Processing] ith =  687
# [Processing] ith =  688
# [Processing] ith =  689
# [Processing] ith =  690
# [Processing] ith =  691
# [Processing] ith =  692
# [Processing] ith =  693
# [Processing] ith =  694
# [Processing] ith =  695
# [Processing] ith =  696
# [Processing] ith =  697
# [Processing] ith =  698
# [Processing] ith =  699
# [Processing] ith =  700
# [Processing] ith =  701
# [Processing] ith =  702
# [Processing] ith =  703
# [Processing] ith =  704
# [Processing] ith =  705
# [Processing] ith =  706
# [Processing] ith =  707
# [Processing] ith =  708
# [Processing] ith =  709
# [Processing] ith =  710
# [Processing] ith =  711
# [Processing] ith =  712
# [Processing] ith =  713
# [Processing] ith =  714
# [Processing] ith =  715
# [Processing] ith =  716
# [Processing] ith =  717
# [Processing] ith =  718
# [Processing] ith =  719
# [Processing] ith =  720
# [Processing] ith =  721
# [Processing] ith =  722
# [Processing] ith =  723
# [Processing] ith =  724
# [Processing] ith =  725
# [Processing] ith =  726
# [Processing] ith =  727
# [Processing] ith =  728
# [Processing] ith =  729
# [Processing] ith =  730
# [Processing] ith =  731
# [Processing] ith =  732
# [Processing] ith =  733
# [Processing] ith =  734
# [Processing] ith =  735
# [Processing] ith =  736
# [Processing] ith =  737
# [Processing] ith =  738
# [Processing] ith =  739
# [Processing] ith =  740
# [Processing] ith =  741
# [Processing] ith =  742
# [Processing] ith =  743
# [Processing] ith =  744
# [Processing] ith =  745
# [Processing] ith =  746
# [Processing] ith =  747
# [Processing] ith =  748
# [Processing] ith =  749
# [Processing] ith =  750
# [Processing] ith =  751
# [Processing] ith =  752
# [Processing] ith =  753
# [Processing] ith =  754
# [Processing] ith =  755
# [Processing] ith =  756
# [Processing] ith =  757
# [Processing] ith =  758
# [Processing] ith =  759
# [Processing] ith =  760
# [Processing] ith =  761
# [Processing] ith =  762
# [Processing] ith =  763
# [Processing] ith =  764
# [Processing] ith =  765
# [Processing] ith =  766
# [Processing] ith =  767
# [Processing] ith =  768
# [Processing] ith =  769
# [Processing] ith =  770
# [Processing] ith =  771
# [Processing] ith =  772
# [Processing] ith =  773
# [Processing] ith =  774
# [Processing] ith =  775
# [Processing] ith =  776
# [Processing] ith =  777
# [Processing] ith =  778
# [Processing] ith =  779
# [Processing] ith =  780
# [Processing] ith =  781
# [Processing] ith =  782
# [Processing] ith =  783
# [Processing] ith =  784
# [Processing] ith =  785
# [Processing] ith =  786
# [Processing] ith =  787
# [Processing] ith =  788
# [Processing] ith =  789
# [Processing] ith =  790
# [Processing] ith =  791
# [Processing] ith =  792
# [Processing] ith =  793
# [Processing] ith =  794
# [Processing] ith =  795
# [Processing] ith =  796
# [Processing] ith =  797
# [Processing] ith =  798
# [Processing] ith =  799
# [Processing] ith =  800
# [Processing] ith =  801
# [Processing] ith =  802
# [Processing] ith =  803
# [Processing] ith =  804
# [Processing] ith =  805
# [Processing] ith =  806
# [Processing] ith =  807
# [Processing] ith =  808
# [Processing] ith =  809
# [Processing] ith =  810
# [Processing] ith =  811
# [Processing] ith =  812
# [Processing] ith =  813
# [Processing] ith =  814
# [Processing] ith =  815
# [Processing] ith =  816
# [Processing] ith =  817
# [Processing] ith =  818
# [Processing] ith =  819
# [Processing] ith =  820
# [Processing] ith =  821
# [Processing] ith =  822
# [Processing] ith =  823
# [Processing] ith =  824
# [Processing] ith =  825
# [Processing] ith =  826
# [Processing] ith =  827
# [Processing] ith =  828
# [Processing] ith =  829
# [Processing] ith =  830
# [Processing] ith =  831
# [Processing] ith =  832
# [Processing] ith =  833
# [Processing] ith =  834
# [Processing] ith =  835
# [Processing] ith =  836
# [Processing] ith =  837
# [Processing] ith =  838
# [Processing] ith =  839
# [Processing] ith =  840
# [Processing] ith =  841
# [Processing] ith =  842
# [Processing] ith =  843
# [Processing] ith =  844
# [Processing] ith =  845
# [Processing] ith =  846
# [Processing] ith =  847
# [Processing] ith =  848
# [Processing] ith =  849
# [Processing] ith =  850
# [Processing] ith =  851
# [Processing] ith =  852
# [Processing] ith =  853
# [Processing] ith =  854
# [Processing] ith =  855
# [Processing] ith =  856
# [Processing] ith =  857
# [Processing] ith =  858
# [Processing] ith =  859
# [Processing] ith =  860
# [Processing] ith =  861
# [Processing] ith =  862
# [Processing] ith =  863
# [Processing] ith =  864
# [Processing] ith =  865
# [Processing] ith =  866
# [Processing] ith =  867
# [Processing] ith =  868
# [Processing] ith =  869
# [Processing] ith =  870
# [Processing] ith =  871
# [Processing] ith =  872
# [Processing] ith =  873
# [Processing] ith =  874
# [Processing] ith =  875
# [Processing] ith =  876
# [Processing] ith =  877
# [Processing] ith =  878
# [Processing] ith =  879
# [Processing] ith =  880
# [Processing] ith =  881
# [Processing] ith =  882
# [Processing] ith =  883
# [Processing] ith =  884
# [Processing] ith =  885
# [Processing] ith =  886
# [Processing] ith =  887
# [Processing] ith =  888
# [Processing] ith =  889
# [Processing] ith =  890
# [Processing] ith =  891
# [Processing] ith =  892
# [Processing] ith =  893
# [Processing] ith =  894
# [Processing] ith =  895
# [Processing] ith =  896
# [Processing] ith =  897
# [Processing] ith =  898
# [Processing] ith =  899
# [Processing] ith =  900
# [Processing] ith =  901
# [Processing] ith =  902
# [Processing] ith =  903
# [Processing] ith =  904
# [Processing] ith =  905
# [Processing] ith =  906
# [Processing] ith =  907
# [Processing] ith =  908
# [Processing] ith =  909
# [Processing] ith =  910
# [Processing] ith =  911
# [Processing] ith =  912
# [Processing] ith =  913
# [Processing] ith =  914
# [Processing] ith =  915
# [Processing] ith =  916
# [Processing] ith =  917
# [Processing] ith =  918
# [Processing] ith =  919
# [Processing] ith =  920
# [Processing] ith =  921
# [Processing] ith =  922
# [Processing] ith =  923
# [Processing] ith =  924
# [Processing] ith =  925
# [Processing] ith =  926
# [Processing] ith =  927
# [Processing] ith =  928
# [Processing] ith =  929
# [Processing] ith =  930
# [Processing] ith =  931
# [Processing] ith =  932
# [Processing] ith =  933
# [Processing] ith =  934
# [Processing] ith =  935
# [Processing] ith =  936
# [Processing] ith =  937
# [Processing] ith =  938
# [Processing] ith =  939
# [Processing] ith =  940
# [Processing] ith =  941
# [Processing] ith =  942
# [Processing] ith =  943
# [Processing] ith =  944
# [Processing] ith =  945
# [Processing] ith =  946
# [Processing] ith =  947
# [Processing] ith =  948
# [Processing] ith =  949
# [Processing] ith =  950
# [Processing] ith =  951
# [Processing] ith =  952
# [Processing] ith =  953
# [Processing] ith =  954
# [Processing] ith =  955
# [Processing] ith =  956
# [Processing] ith =  957
# [Processing] ith =  958
# [Processing] ith =  959
# [Processing] ith =  960
# [Processing] ith =  961
# [Processing] ith =  962
# [Processing] ith =  963
# [Processing] ith =  964
# [Processing] ith =  965
# [Processing] ith =  966
# [Processing] ith =  967
# [Processing] ith =  968
# [Processing] ith =  969
# [Processing] ith =  970
# [Processing] ith =  971
# [Processing] ith =  972
# [Processing] ith =  973
# [Processing] ith =  974
# [Processing] ith =  975
# [Processing] ith =  976
# [Processing] ith =  977
# [Processing] ith =  978
# [Processing] ith =  979
# [Processing] ith =  980
# [Processing] ith =  981
# [Processing] ith =  982
# [Processing] ith =  983
# [Processing] ith =  984
# [Processing] ith =  985
# [Processing] ith =  986
# [Processing] ith =  987
# [Processing] ith =  988
# [Processing] ith =  989
# [Processing] ith =  990
# [Processing] ith =  991
# [Processing] ith =  992
# [Processing] ith =  993
# [Processing] ith =  994
# [Processing] ith =  995
# [Processing] ith =  996
# [Processing] ith =  997
# [Processing] ith =  998
# [Processing] ith =  999

# %% [markdown]
# 3D integration

# %%
plot_z_dlas_1, plot_log_nhis_1 = generate_plot_samples(
    num_bins=500, freq=10, scale=0.02, num_centered_samples=100
)
plot_z_dlas_2, plot_log_nhis_2 = generate_plot_samples(
    num_bins=100, freq=1.5, scale=0.01, num_centered_samples=30
)

plot_z_dlas_2 = np.concatenate([plot_z_dlas_2 for i in range(5)])
plot_log_nhis_2 = np.concatenate([plot_log_nhis_2 for i in range(5)])

plot_z_dlas_3, plot_log_nhis_3 = generate_plot_samples(
    num_bins=250, freq=4, scale=0.005, num_centered_samples=80
)

plot_z_dlas_3 = np.concatenate([plot_z_dlas_3 for i in range(2)])
plot_log_nhis_3 = np.concatenate([plot_log_nhis_3 for i in range(2)])

# %%
for k, (z_dla_1, log_nhi_1, z_dla_2, log_nhi_2, z_dla_3, log_nhi_3) in enumerate(
    zip(
        plot_z_dlas_1,
        plot_log_nhis_1,
        plot_z_dlas_2,
        plot_log_nhis_2,
        plot_z_dlas_3,
        plot_log_nhis_3,
    )
):
    print("[Processing] ith = ", k)
    fig = make_plot_bayes_model(
        z_dlas=[z_dla_1, z_dla_2, z_dla_3], log_nhis=[log_nhi_1, log_nhi_2, log_nhi_3]
    )
    fig.savefig(
        "bayes_model_animation/bayes3d/demo_spec_{}.png".format(str(k).zfill(4)),
        dpi=100,
        # transparent=True,
    )
    plt.close()
    plt.clf()
# Out:
# [Processing] ith =  0
# [Processing] ith =  1
# [Processing] ith =  2
# [Processing] ith =  3
# [Processing] ith =  4
# [Processing] ith =  5
# [Processing] ith =  6
# [Processing] ith =  7
# [Processing] ith =  8
# [Processing] ith =  9
# [Processing] ith =  10
# [Processing] ith =  11
# [Processing] ith =  12
# [Processing] ith =  13
# [Processing] ith =  14
# [Processing] ith =  15
# [Processing] ith =  16
# [Processing] ith =  17
# [Processing] ith =  18
# [Processing] ith =  19
# [Processing] ith =  20
# [Processing] ith =  21
# [Processing] ith =  22
# [Processing] ith =  23
# [Processing] ith =  24
# [Processing] ith =  25
# [Processing] ith =  26
# [Processing] ith =  27
# [Processing] ith =  28
# [Processing] ith =  29
# [Processing] ith =  30
# [Processing] ith =  31
# [Processing] ith =  32
# [Processing] ith =  33
# [Processing] ith =  34
# [Processing] ith =  35
# [Processing] ith =  36
# [Processing] ith =  37
# [Processing] ith =  38
# [Processing] ith =  39
# [Processing] ith =  40
# [Processing] ith =  41
# [Processing] ith =  42
# [Processing] ith =  43
# [Processing] ith =  44
# [Processing] ith =  45
# [Processing] ith =  46
# [Processing] ith =  47
# [Processing] ith =  48
# [Processing] ith =  49
# [Processing] ith =  50
# [Processing] ith =  51
# [Processing] ith =  52
# [Processing] ith =  53
# [Processing] ith =  54
# [Processing] ith =  55
# [Processing] ith =  56
# [Processing] ith =  57
# [Processing] ith =  58
# [Processing] ith =  59
# [Processing] ith =  60
# [Processing] ith =  61
# [Processing] ith =  62
# [Processing] ith =  63
# [Processing] ith =  64
# [Processing] ith =  65
# [Processing] ith =  66
# [Processing] ith =  67
# [Processing] ith =  68
# [Processing] ith =  69
# [Processing] ith =  70
# [Processing] ith =  71
# [Processing] ith =  72
# [Processing] ith =  73
# [Processing] ith =  74
# [Processing] ith =  75
# [Processing] ith =  76
# [Processing] ith =  77
# [Processing] ith =  78
# [Processing] ith =  79
# [Processing] ith =  80
# [Processing] ith =  81
# [Processing] ith =  82
# [Processing] ith =  83
# [Processing] ith =  84
# [Processing] ith =  85
# [Processing] ith =  86
# [Processing] ith =  87
# [Processing] ith =  88
# [Processing] ith =  89
# [Processing] ith =  90
# [Processing] ith =  91
# [Processing] ith =  92
# [Processing] ith =  93
# [Processing] ith =  94
# [Processing] ith =  95
# [Processing] ith =  96
# [Processing] ith =  97
# [Processing] ith =  98
# [Processing] ith =  99
# [Processing] ith =  100
# [Processing] ith =  101
# [Processing] ith =  102
# [Processing] ith =  103
# [Processing] ith =  104
# [Processing] ith =  105
# [Processing] ith =  106
# [Processing] ith =  107
# [Processing] ith =  108
# [Processing] ith =  109
# [Processing] ith =  110
# [Processing] ith =  111
# [Processing] ith =  112
# [Processing] ith =  113
# [Processing] ith =  114
# [Processing] ith =  115
# [Processing] ith =  116
# [Processing] ith =  117
# [Processing] ith =  118
# [Processing] ith =  119
# [Processing] ith =  120
# [Processing] ith =  121
# [Processing] ith =  122
# [Processing] ith =  123
# [Processing] ith =  124
# [Processing] ith =  125
# [Processing] ith =  126
# [Processing] ith =  127
# [Processing] ith =  128
# [Processing] ith =  129
# [Processing] ith =  130
# [Processing] ith =  131
# [Processing] ith =  132
# [Processing] ith =  133
# [Processing] ith =  134
# [Processing] ith =  135
# [Processing] ith =  136
# [Processing] ith =  137
# [Processing] ith =  138
# [Processing] ith =  139
# [Processing] ith =  140
# [Processing] ith =  141
# [Processing] ith =  142
# [Processing] ith =  143
# [Processing] ith =  144
# [Processing] ith =  145
# [Processing] ith =  146
# [Processing] ith =  147
# [Processing] ith =  148
# [Processing] ith =  149
# [Processing] ith =  150
# [Processing] ith =  151
# [Processing] ith =  152
# [Processing] ith =  153
# [Processing] ith =  154
# [Processing] ith =  155
# [Processing] ith =  156
# [Processing] ith =  157
# [Processing] ith =  158
# [Processing] ith =  159
# [Processing] ith =  160
# [Processing] ith =  161
# [Processing] ith =  162
# [Processing] ith =  163
# [Processing] ith =  164
# [Processing] ith =  165
# [Processing] ith =  166
# [Processing] ith =  167
# [Processing] ith =  168
# [Processing] ith =  169
# [Processing] ith =  170
# [Processing] ith =  171
# [Processing] ith =  172
# [Processing] ith =  173
# [Processing] ith =  174
# [Processing] ith =  175
# [Processing] ith =  176
# [Processing] ith =  177
# [Processing] ith =  178
# [Processing] ith =  179
# [Processing] ith =  180
# [Processing] ith =  181
# [Processing] ith =  182
# [Processing] ith =  183
# [Processing] ith =  184
# [Processing] ith =  185
# [Processing] ith =  186
# [Processing] ith =  187
# [Processing] ith =  188
# [Processing] ith =  189
# [Processing] ith =  190
# [Processing] ith =  191
# [Processing] ith =  192
# [Processing] ith =  193
# [Processing] ith =  194
# [Processing] ith =  195
# [Processing] ith =  196
# [Processing] ith =  197
# [Processing] ith =  198
# [Processing] ith =  199
# [Processing] ith =  200
# [Processing] ith =  201
# [Processing] ith =  202
# [Processing] ith =  203
# [Processing] ith =  204
# [Processing] ith =  205
# [Processing] ith =  206
# [Processing] ith =  207
# [Processing] ith =  208
# [Processing] ith =  209
# [Processing] ith =  210
# [Processing] ith =  211
# [Processing] ith =  212
# [Processing] ith =  213
# [Processing] ith =  214
# [Processing] ith =  215
# [Processing] ith =  216
# [Processing] ith =  217
# [Processing] ith =  218
# [Processing] ith =  219
# [Processing] ith =  220
# [Processing] ith =  221
# [Processing] ith =  222
# [Processing] ith =  223
# [Processing] ith =  224
# [Processing] ith =  225
# [Processing] ith =  226
# [Processing] ith =  227
# [Processing] ith =  228
# [Processing] ith =  229
# [Processing] ith =  230
# [Processing] ith =  231
# [Processing] ith =  232
# [Processing] ith =  233
# [Processing] ith =  234
# [Processing] ith =  235
# [Processing] ith =  236
# [Processing] ith =  237
# [Processing] ith =  238
# [Processing] ith =  239
# [Processing] ith =  240
# [Processing] ith =  241
# [Processing] ith =  242
# [Processing] ith =  243
# [Processing] ith =  244
# [Processing] ith =  245
# [Processing] ith =  246
# [Processing] ith =  247
# [Processing] ith =  248
# [Processing] ith =  249
# [Processing] ith =  250
# [Processing] ith =  251
# [Processing] ith =  252
# [Processing] ith =  253
# [Processing] ith =  254
# [Processing] ith =  255
# [Processing] ith =  256
# [Processing] ith =  257
# [Processing] ith =  258
# [Processing] ith =  259
# [Processing] ith =  260
# [Processing] ith =  261
# [Processing] ith =  262
# [Processing] ith =  263
# [Processing] ith =  264
# [Processing] ith =  265
# [Processing] ith =  266
# [Processing] ith =  267
# [Processing] ith =  268
# [Processing] ith =  269
# [Processing] ith =  270
# [Processing] ith =  271
# [Processing] ith =  272
# [Processing] ith =  273
# [Processing] ith =  274
# [Processing] ith =  275
# [Processing] ith =  276
# [Processing] ith =  277
# [Processing] ith =  278
# [Processing] ith =  279
# [Processing] ith =  280
# [Processing] ith =  281
# [Processing] ith =  282
# [Processing] ith =  283
# [Processing] ith =  284
# [Processing] ith =  285
# [Processing] ith =  286
# [Processing] ith =  287
# [Processing] ith =  288
# [Processing] ith =  289
# [Processing] ith =  290
# [Processing] ith =  291
# [Processing] ith =  292
# [Processing] ith =  293
# [Processing] ith =  294
# [Processing] ith =  295
# [Processing] ith =  296
# [Processing] ith =  297
# [Processing] ith =  298
# [Processing] ith =  299
# [Processing] ith =  300
# [Processing] ith =  301
# [Processing] ith =  302
# [Processing] ith =  303
# [Processing] ith =  304
# [Processing] ith =  305
# [Processing] ith =  306
# [Processing] ith =  307
# [Processing] ith =  308
# [Processing] ith =  309
# [Processing] ith =  310
# [Processing] ith =  311
# [Processing] ith =  312
# [Processing] ith =  313
# [Processing] ith =  314
# [Processing] ith =  315
# [Processing] ith =  316
# [Processing] ith =  317
# [Processing] ith =  318
# [Processing] ith =  319
# [Processing] ith =  320
# [Processing] ith =  321
# [Processing] ith =  322
# [Processing] ith =  323
# [Processing] ith =  324
# [Processing] ith =  325
# [Processing] ith =  326
# [Processing] ith =  327
# [Processing] ith =  328
# [Processing] ith =  329
# [Processing] ith =  330
# [Processing] ith =  331
# [Processing] ith =  332
# [Processing] ith =  333
# [Processing] ith =  334
# [Processing] ith =  335
# [Processing] ith =  336
# [Processing] ith =  337
# [Processing] ith =  338
# [Processing] ith =  339
# [Processing] ith =  340
# [Processing] ith =  341
# [Processing] ith =  342
# [Processing] ith =  343
# [Processing] ith =  344
# [Processing] ith =  345
# [Processing] ith =  346
# [Processing] ith =  347
# [Processing] ith =  348
# [Processing] ith =  349
# [Processing] ith =  350
# [Processing] ith =  351
# [Processing] ith =  352
# [Processing] ith =  353
# [Processing] ith =  354
# [Processing] ith =  355
# [Processing] ith =  356
# [Processing] ith =  357
# [Processing] ith =  358
# [Processing] ith =  359
# [Processing] ith =  360
# [Processing] ith =  361
# [Processing] ith =  362
# [Processing] ith =  363
# [Processing] ith =  364
# [Processing] ith =  365
# [Processing] ith =  366
# [Processing] ith =  367
# [Processing] ith =  368
# [Processing] ith =  369
# [Processing] ith =  370
# [Processing] ith =  371
# [Processing] ith =  372
# [Processing] ith =  373
# [Processing] ith =  374
# [Processing] ith =  375
# [Processing] ith =  376
# [Processing] ith =  377
# [Processing] ith =  378
# [Processing] ith =  379
# [Processing] ith =  380
# [Processing] ith =  381
# [Processing] ith =  382
# [Processing] ith =  383
# [Processing] ith =  384
# [Processing] ith =  385
# [Processing] ith =  386
# [Processing] ith =  387
# [Processing] ith =  388
# [Processing] ith =  389
# [Processing] ith =  390
# [Processing] ith =  391
# [Processing] ith =  392
# [Processing] ith =  393
# [Processing] ith =  394
# [Processing] ith =  395
# [Processing] ith =  396
# [Processing] ith =  397
# [Processing] ith =  398
# [Processing] ith =  399
# [Processing] ith =  400
# [Processing] ith =  401
# [Processing] ith =  402
# [Processing] ith =  403
# [Processing] ith =  404
# [Processing] ith =  405
# [Processing] ith =  406
# [Processing] ith =  407
# [Processing] ith =  408
# [Processing] ith =  409
# [Processing] ith =  410
# [Processing] ith =  411
# [Processing] ith =  412
# [Processing] ith =  413
# [Processing] ith =  414
# [Processing] ith =  415
# [Processing] ith =  416
# [Processing] ith =  417
# [Processing] ith =  418
# [Processing] ith =  419
# [Processing] ith =  420
# [Processing] ith =  421
# [Processing] ith =  422
# [Processing] ith =  423
# [Processing] ith =  424
# [Processing] ith =  425
# [Processing] ith =  426
# [Processing] ith =  427
# [Processing] ith =  428
# [Processing] ith =  429
# [Processing] ith =  430
# [Processing] ith =  431
# [Processing] ith =  432
# [Processing] ith =  433
# [Processing] ith =  434
# [Processing] ith =  435
# [Processing] ith =  436
# [Processing] ith =  437
# [Processing] ith =  438
# [Processing] ith =  439
# [Processing] ith =  440
# [Processing] ith =  441
# [Processing] ith =  442
# [Processing] ith =  443
# [Processing] ith =  444
# [Processing] ith =  445
# [Processing] ith =  446
# [Processing] ith =  447
# [Processing] ith =  448
# [Processing] ith =  449
# [Processing] ith =  450
# [Processing] ith =  451
# [Processing] ith =  452
# [Processing] ith =  453
# [Processing] ith =  454
# [Processing] ith =  455
# [Processing] ith =  456
# [Processing] ith =  457
# [Processing] ith =  458
# [Processing] ith =  459
# [Processing] ith =  460
# [Processing] ith =  461
# [Processing] ith =  462
# [Processing] ith =  463
# [Processing] ith =  464
# [Processing] ith =  465
# [Processing] ith =  466
# [Processing] ith =  467
# [Processing] ith =  468
# [Processing] ith =  469
# [Processing] ith =  470
# [Processing] ith =  471
# [Processing] ith =  472
# [Processing] ith =  473
# [Processing] ith =  474
# [Processing] ith =  475
# [Processing] ith =  476
# [Processing] ith =  477
# [Processing] ith =  478
# [Processing] ith =  479
# [Processing] ith =  480
# [Processing] ith =  481
# [Processing] ith =  482
# [Processing] ith =  483
# [Processing] ith =  484
# [Processing] ith =  485
# [Processing] ith =  486
# [Processing] ith =  487
# [Processing] ith =  488
# [Processing] ith =  489
# [Processing] ith =  490
# [Processing] ith =  491
# [Processing] ith =  492
# [Processing] ith =  493
# [Processing] ith =  494
# [Processing] ith =  495
# [Processing] ith =  496
# [Processing] ith =  497
# [Processing] ith =  498
# [Processing] ith =  499
# [Processing] ith =  500
# [Processing] ith =  501
# [Processing] ith =  502
# [Processing] ith =  503
# [Processing] ith =  504
# [Processing] ith =  505
# [Processing] ith =  506
# [Processing] ith =  507
# [Processing] ith =  508
# [Processing] ith =  509
# [Processing] ith =  510
# [Processing] ith =  511
# [Processing] ith =  512
# [Processing] ith =  513
# [Processing] ith =  514
# [Processing] ith =  515
# [Processing] ith =  516
# [Processing] ith =  517
# [Processing] ith =  518
# [Processing] ith =  519
# [Processing] ith =  520
# [Processing] ith =  521
# [Processing] ith =  522
# [Processing] ith =  523
# [Processing] ith =  524
# [Processing] ith =  525
# [Processing] ith =  526
# [Processing] ith =  527
# [Processing] ith =  528
# [Processing] ith =  529
# [Processing] ith =  530
# [Processing] ith =  531
# [Processing] ith =  532
# [Processing] ith =  533
# [Processing] ith =  534
# [Processing] ith =  535
# [Processing] ith =  536
# [Processing] ith =  537
# [Processing] ith =  538
# [Processing] ith =  539
# [Processing] ith =  540
# [Processing] ith =  541
# [Processing] ith =  542
# [Processing] ith =  543
# [Processing] ith =  544
# [Processing] ith =  545
# [Processing] ith =  546
# [Processing] ith =  547
# [Processing] ith =  548
# [Processing] ith =  549
# [Processing] ith =  550
# [Processing] ith =  551
# [Processing] ith =  552
# [Processing] ith =  553
# [Processing] ith =  554
# [Processing] ith =  555
# [Processing] ith =  556
# [Processing] ith =  557
# [Processing] ith =  558
# [Processing] ith =  559
# [Processing] ith =  560
# [Processing] ith =  561
# [Processing] ith =  562
# [Processing] ith =  563
# [Processing] ith =  564
# [Processing] ith =  565
# [Processing] ith =  566
# [Processing] ith =  567
# [Processing] ith =  568
# [Processing] ith =  569
# [Processing] ith =  570
# [Processing] ith =  571
# [Processing] ith =  572
# [Processing] ith =  573
# [Processing] ith =  574
# [Processing] ith =  575
# [Processing] ith =  576
# [Processing] ith =  577
# [Processing] ith =  578
# [Processing] ith =  579
# [Processing] ith =  580
# [Processing] ith =  581
# [Processing] ith =  582
# [Processing] ith =  583
# [Processing] ith =  584
# [Processing] ith =  585
# [Processing] ith =  586
# [Processing] ith =  587
# [Processing] ith =  588
# [Processing] ith =  589
# [Processing] ith =  590
# [Processing] ith =  591
# [Processing] ith =  592
# [Processing] ith =  593
# [Processing] ith =  594
# [Processing] ith =  595
# [Processing] ith =  596
# [Processing] ith =  597
# [Processing] ith =  598
# [Processing] ith =  599
# [Processing] ith =  600
# [Processing] ith =  601
# [Processing] ith =  602
# [Processing] ith =  603
# [Processing] ith =  604
# [Processing] ith =  605
# [Processing] ith =  606
# [Processing] ith =  607
# [Processing] ith =  608
# [Processing] ith =  609
# [Processing] ith =  610
# [Processing] ith =  611
# [Processing] ith =  612
# [Processing] ith =  613
# [Processing] ith =  614
# [Processing] ith =  615
# [Processing] ith =  616
# [Processing] ith =  617
# [Processing] ith =  618
# [Processing] ith =  619
# [Processing] ith =  620
# [Processing] ith =  621
# [Processing] ith =  622
# [Processing] ith =  623
# [Processing] ith =  624
# [Processing] ith =  625
# [Processing] ith =  626
# [Processing] ith =  627
# [Processing] ith =  628
# [Processing] ith =  629
# [Processing] ith =  630
# [Processing] ith =  631
# [Processing] ith =  632
# [Processing] ith =  633
# [Processing] ith =  634
# [Processing] ith =  635
# [Processing] ith =  636
# [Processing] ith =  637
# [Processing] ith =  638
# [Processing] ith =  639
# [Processing] ith =  640
# [Processing] ith =  641
# [Processing] ith =  642
# [Processing] ith =  643
# [Processing] ith =  644
# [Processing] ith =  645
# [Processing] ith =  646
# [Processing] ith =  647
# [Processing] ith =  648
# [Processing] ith =  649
# [Processing] ith =  650
# [Processing] ith =  651
# [Processing] ith =  652
# [Processing] ith =  653
# [Processing] ith =  654
# [Processing] ith =  655
# [Processing] ith =  656
# [Processing] ith =  657
# [Processing] ith =  658
# [Processing] ith =  659
# [Processing] ith =  660
# [Processing] ith =  661
# [Processing] ith =  662
# [Processing] ith =  663
# [Processing] ith =  664
# [Processing] ith =  665
# [Processing] ith =  666
# [Processing] ith =  667
# [Processing] ith =  668
# [Processing] ith =  669
# [Processing] ith =  670
# [Processing] ith =  671
# [Processing] ith =  672
# [Processing] ith =  673
# [Processing] ith =  674
# [Processing] ith =  675
# [Processing] ith =  676
# [Processing] ith =  677
# [Processing] ith =  678
# [Processing] ith =  679
# [Processing] ith =  680
# [Processing] ith =  681
# [Processing] ith =  682
# [Processing] ith =  683
# [Processing] ith =  684
# [Processing] ith =  685
# [Processing] ith =  686
# [Processing] ith =  687
# [Processing] ith =  688
# [Processing] ith =  689
# [Processing] ith =  690
# [Processing] ith =  691
# [Processing] ith =  692
# [Processing] ith =  693
# [Processing] ith =  694
# [Processing] ith =  695
# [Processing] ith =  696
# [Processing] ith =  697
# [Processing] ith =  698
# [Processing] ith =  699
# [Processing] ith =  700
# [Processing] ith =  701
# [Processing] ith =  702
# [Processing] ith =  703
# [Processing] ith =  704
# [Processing] ith =  705
# [Processing] ith =  706
# [Processing] ith =  707
# [Processing] ith =  708
# [Processing] ith =  709
# [Processing] ith =  710
# [Processing] ith =  711
# [Processing] ith =  712
# [Processing] ith =  713
# [Processing] ith =  714
# [Processing] ith =  715
# [Processing] ith =  716
# [Processing] ith =  717
# [Processing] ith =  718
# [Processing] ith =  719
# [Processing] ith =  720
# [Processing] ith =  721
# [Processing] ith =  722
# [Processing] ith =  723
# [Processing] ith =  724
# [Processing] ith =  725
# [Processing] ith =  726
# [Processing] ith =  727
# [Processing] ith =  728
# [Processing] ith =  729
# [Processing] ith =  730
# [Processing] ith =  731
# [Processing] ith =  732
# [Processing] ith =  733
# [Processing] ith =  734
# [Processing] ith =  735
# [Processing] ith =  736
# [Processing] ith =  737
# [Processing] ith =  738
# [Processing] ith =  739
# [Processing] ith =  740
# [Processing] ith =  741
# [Processing] ith =  742
# [Processing] ith =  743
# [Processing] ith =  744
# [Processing] ith =  745
# [Processing] ith =  746
# [Processing] ith =  747
# [Processing] ith =  748
# [Processing] ith =  749
# [Processing] ith =  750
# [Processing] ith =  751
# [Processing] ith =  752
# [Processing] ith =  753
# [Processing] ith =  754
# [Processing] ith =  755
# [Processing] ith =  756
# [Processing] ith =  757
# [Processing] ith =  758
# [Processing] ith =  759
# [Processing] ith =  760
# [Processing] ith =  761
# [Processing] ith =  762
# [Processing] ith =  763
# [Processing] ith =  764
# [Processing] ith =  765
# [Processing] ith =  766
# [Processing] ith =  767
# [Processing] ith =  768
# [Processing] ith =  769
# [Processing] ith =  770
# [Processing] ith =  771
# [Processing] ith =  772
# [Processing] ith =  773
# [Processing] ith =  774
# [Processing] ith =  775
# [Processing] ith =  776
# [Processing] ith =  777
# [Processing] ith =  778
# [Processing] ith =  779
# [Processing] ith =  780
# [Processing] ith =  781
# [Processing] ith =  782
# [Processing] ith =  783
# [Processing] ith =  784
# [Processing] ith =  785
# [Processing] ith =  786
# [Processing] ith =  787
# [Processing] ith =  788
# [Processing] ith =  789
# [Processing] ith =  790
# [Processing] ith =  791
# [Processing] ith =  792
# [Processing] ith =  793
# [Processing] ith =  794
# [Processing] ith =  795
# [Processing] ith =  796
# [Processing] ith =  797
# [Processing] ith =  798
# [Processing] ith =  799
# [Processing] ith =  800
# [Processing] ith =  801
# [Processing] ith =  802
# [Processing] ith =  803
# [Processing] ith =  804
# [Processing] ith =  805
# [Processing] ith =  806
# [Processing] ith =  807
# [Processing] ith =  808
# [Processing] ith =  809
# [Processing] ith =  810
# [Processing] ith =  811
# [Processing] ith =  812
# [Processing] ith =  813
# [Processing] ith =  814
# [Processing] ith =  815
# [Processing] ith =  816
# [Processing] ith =  817
# [Processing] ith =  818
# [Processing] ith =  819
# [Processing] ith =  820
# [Processing] ith =  821
# [Processing] ith =  822
# [Processing] ith =  823
# [Processing] ith =  824
# [Processing] ith =  825
# [Processing] ith =  826
# [Processing] ith =  827
# [Processing] ith =  828
# [Processing] ith =  829
# [Processing] ith =  830
# [Processing] ith =  831
# [Processing] ith =  832
# [Processing] ith =  833
# [Processing] ith =  834
# [Processing] ith =  835
# [Processing] ith =  836
# [Processing] ith =  837
# [Processing] ith =  838
# [Processing] ith =  839
# [Processing] ith =  840
# [Processing] ith =  841
# [Processing] ith =  842
# [Processing] ith =  843
# [Processing] ith =  844
# [Processing] ith =  845
# [Processing] ith =  846
# [Processing] ith =  847
# [Processing] ith =  848
# [Processing] ith =  849
# [Processing] ith =  850
# [Processing] ith =  851
# [Processing] ith =  852
# [Processing] ith =  853
# [Processing] ith =  854
# [Processing] ith =  855
# [Processing] ith =  856
# [Processing] ith =  857
# [Processing] ith =  858
# [Processing] ith =  859
# [Processing] ith =  860
# [Processing] ith =  861
# [Processing] ith =  862
# [Processing] ith =  863
# [Processing] ith =  864
# [Processing] ith =  865
# [Processing] ith =  866
# [Processing] ith =  867
# [Processing] ith =  868
# [Processing] ith =  869
# [Processing] ith =  870
# [Processing] ith =  871
# [Processing] ith =  872
# [Processing] ith =  873
# [Processing] ith =  874
# [Processing] ith =  875
# [Processing] ith =  876
# [Processing] ith =  877
# [Processing] ith =  878
# [Processing] ith =  879
# [Processing] ith =  880
# [Processing] ith =  881
# [Processing] ith =  882
# [Processing] ith =  883
# [Processing] ith =  884
# [Processing] ith =  885
# [Processing] ith =  886
# [Processing] ith =  887
# [Processing] ith =  888
# [Processing] ith =  889
# [Processing] ith =  890
# [Processing] ith =  891
# [Processing] ith =  892
# [Processing] ith =  893
# [Processing] ith =  894
# [Processing] ith =  895
# [Processing] ith =  896
# [Processing] ith =  897
# [Processing] ith =  898
# [Processing] ith =  899
# [Processing] ith =  900
# [Processing] ith =  901
# [Processing] ith =  902
# [Processing] ith =  903
# [Processing] ith =  904
# [Processing] ith =  905
# [Processing] ith =  906
# [Processing] ith =  907
# [Processing] ith =  908
# [Processing] ith =  909
# [Processing] ith =  910
# [Processing] ith =  911
# [Processing] ith =  912
# [Processing] ith =  913
# [Processing] ith =  914
# [Processing] ith =  915
# [Processing] ith =  916
# [Processing] ith =  917
# [Processing] ith =  918
# [Processing] ith =  919
# [Processing] ith =  920
# [Processing] ith =  921
# [Processing] ith =  922
# [Processing] ith =  923
# [Processing] ith =  924
# [Processing] ith =  925
# [Processing] ith =  926
# [Processing] ith =  927
# [Processing] ith =  928
# [Processing] ith =  929
# [Processing] ith =  930
# [Processing] ith =  931
# [Processing] ith =  932
# [Processing] ith =  933
# [Processing] ith =  934
# [Processing] ith =  935
# [Processing] ith =  936
# [Processing] ith =  937
# [Processing] ith =  938
# [Processing] ith =  939
# [Processing] ith =  940
# [Processing] ith =  941
# [Processing] ith =  942
# [Processing] ith =  943
# [Processing] ith =  944
# [Processing] ith =  945
# [Processing] ith =  946
# [Processing] ith =  947
# [Processing] ith =  948
# [Processing] ith =  949
# [Processing] ith =  950
# [Processing] ith =  951
# [Processing] ith =  952
# [Processing] ith =  953
# [Processing] ith =  954
# [Processing] ith =  955
# [Processing] ith =  956
# [Processing] ith =  957
# [Processing] ith =  958
# [Processing] ith =  959
# [Processing] ith =  960
# [Processing] ith =  961
# [Processing] ith =  962
# [Processing] ith =  963
# [Processing] ith =  964
# [Processing] ith =  965
# [Processing] ith =  966
# [Processing] ith =  967
# [Processing] ith =  968
# [Processing] ith =  969
# [Processing] ith =  970
# [Processing] ith =  971
# [Processing] ith =  972
# [Processing] ith =  973
# [Processing] ith =  974
# [Processing] ith =  975
# [Processing] ith =  976
# [Processing] ith =  977
# [Processing] ith =  978
# [Processing] ith =  979
# [Processing] ith =  980
# [Processing] ith =  981
# [Processing] ith =  982
# [Processing] ith =  983
# [Processing] ith =  984
# [Processing] ith =  985
# [Processing] ith =  986
# [Processing] ith =  987
# [Processing] ith =  988
# [Processing] ith =  989
# [Processing] ith =  990
# [Processing] ith =  991
# [Processing] ith =  992
# [Processing] ith =  993
# [Processing] ith =  994
# [Processing] ith =  995
# [Processing] ith =  996
# [Processing] ith =  997
# [Processing] ith =  998
# [Processing] ith =  999
